# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance 
from sklearn.utils import validation
from sklearn.metrics import pairwise
from scipy.sparse import issparse
import random

# %%
def _return_float_dtype(X, Y):
    """
    1. If dtype of X and Y is float32, then dtype float32 is returned.
    2. Else dtype float is returned.
    """
    if not issparse(X) and not isinstance(X, np.ndarray):
        X = np.asarray(X)

    if Y is None:
        Y_dtype = X.dtype
    elif not issparse(Y) and not isinstance(Y, np.ndarray):
        Y = np.asarray(Y)
        Y_dtype = Y.dtype
    else:
        Y_dtype = Y.dtype

    if X.dtype == Y_dtype == np.float32:
        dtype = np.float32
    elif X.dtype == np.object and not issparse(X):
        dtype = np.float
        for col in range(X.shape[1]):
            if not np.issubdtype(type(X[0, col]), np.number):
                dtype = np.object
                break
    else:
        dtype = np.float

    return X, Y, dtype


def check_pairwise_arrays(X, Y, precomputed=False, dtype=None):
    X, Y, dtype_float = _return_float_dtype(X, Y)

    warn_on_dtype = dtype is not None
    estimator = 'check_pairwise_arrays'
    if dtype is None:
        dtype = dtype_float


    if Y is X or Y is None:
        X = Y = validation.check_array(X, accept_sparse='csr', dtype=dtype,
                            warn_on_dtype=warn_on_dtype, estimator=estimator)
    else:
        X = validation.check_array(X, accept_sparse='csr', dtype=dtype,
                        warn_on_dtype=warn_on_dtype, estimator=estimator)
        Y = validation.check_array(Y, accept_sparse='csr', dtype=dtype,
                        warn_on_dtype=warn_on_dtype, estimator=estimator)

    if precomputed:
        if X.shape[1] != Y.shape[0]:
            raise ValueError("Precomputed metric requires shape "
                             "(n_queries, n_indexed). Got (%d, %d) "
                             "for %d indexed." %
                             (X.shape[0], X.shape[1], Y.shape[0]))
    elif X.shape[1] != Y.shape[1]:
        raise ValueError("Incompatible dimension for X and Y matrices: "
                         "X.shape[1] == %d while Y.shape[1] == %d" % (
                             X.shape[1], Y.shape[1]))

    return X, Y

# %%
def gower_distances(X, Y=None, w=None, categorical_features=None):
    """
    Computes the gower distances between X and Y

    Read more in the :ref:`User Guide <metrics>`.

    Parameters
    ----------
    X : array-like, shape (n_samples, n_features)

    Y : array-like, shape (n_samples, n_features)

    w:  array-like, shape (n_features)
    According the Gower formula, w is an attribute weight.

    categorical_features: array-like, shape (n_features)
    Indicates with True/False wheter a column is a categorical attribute.
    This is useful when categorical atributes are represented as integer
    values.

    Returns
    -------
    similarities : ndarray, shape (n_samples, )

    Notes
    ------
    Gower is a similarity measure for categorical, boolean and numerical mixed
    data.

    """

    X, Y = check_pairwise_arrays(X, Y, dtype=(np.object, None)[issparse(X) or
                                                               issparse(Y)])

    rows, cols = X.shape

    if categorical_features is None:
        categorical_features = []
        for col in range(cols):
            if np.issubdtype(type(X[0, col]), np.number):
                categorical_features.append(False)
            else:
                categorical_features.append(True)
    # Calculates the normalized ranges and max values of numeric values
    ranges_of_numeric = [0.0] * cols
    max_of_numeric = [0.0] * cols
    for col in range(cols):
        if not categorical_features[col]:
            max = None
            min = None
            if issparse(X):
                col_array = X.getcol(col)
                max = col_array.max() + 0.0
                min = col_array.min() + 0.0
            else:
                col_array = X[:, col].astype(np.double)
                max = np.nanmax(col_array)
                min = np.nanmin(col_array)

            if np.isnan(max):
                max = 0.0
            if np.isnan(min):
                min = 0.0
            max_of_numeric[col] = max
            ranges_of_numeric[col] = (1 - min / max) if (max != 0) else 0.0

    if w is None:
        w = [1] * cols

    yrows, ycols = Y.shape

    dm = np.zeros((rows, yrows), dtype=np.double)

    for i in range(0, rows):
        j_start = i

        # for non square results
        if rows != yrows:
            j_start = 0

        for j in range(j_start, yrows):
            sum_sij = 0.0
            sum_wij = 0.0
            for col in range(cols):
                value_xi = X[i, col]
                value_xj = Y[j, col]

                if not categorical_features[col]:
                    if (max_of_numeric[col] != 0):
                        value_xi = value_xi / max_of_numeric[col]
                        value_xj = value_xj / max_of_numeric[col]
                    else:
                        value_xi = 0
                        value_xj = 0

                    if ranges_of_numeric[col] != 0:
                        sij = abs(value_xi - value_xj) / ranges_of_numeric[col]
                    else:
                        sij = 0
                    wij = (w[col], 0)[np.isnan(value_xi) or np.isnan(value_xj)]
                else:
                    sij = (1.0, 0.0)[value_xi == value_xj]
                    wij = (w[col], 0)[value_xi is None and value_xj is None]
                sum_sij += (wij * sij)
                sum_wij += wij

            if sum_wij != 0:
                dm[i, j] = (sum_sij / sum_wij)
                if j < rows and i < yrows:
                    dm[j, i] = dm[i, j]

    return dm

# %%
def gower_distances(X, Y=None, w=None, categorical_features=None):
    """
    Computes the gower distances between X and Y

    Read more in the :ref:`User Guide <metrics>`.

    Parameters
    ----------
    X : array-like, shape (n_samples, n_features)

    Y : array-like, shape (n_samples, n_features)

    w:  array-like, shape (n_features)
    According the Gower formula, w is an attribute weight.

    categorical_features: array-like, shape (n_features)
    Indicates with True/False wheter a column is a categorical attribute.
    This is useful when categorical atributes are represented as integer
    values.

    Returns
    -------
    similarities : ndarray, shape (n_samples, )

    Notes
    ------
    Gower is a similarity measure for categorical, boolean and numerical mixed
    data.

    """

    X, Y = check_pairwise_arrays(X, Y, dtype=(np.object, None)[issparse(X) or
                                                               issparse(Y)])

    rows, cols = X.shape

    if categorical_features is None:
        categorical_features = []
        for col in range(cols):
            if np.issubdtype(type(X[0, col]), np.number):
                categorical_features.append(False)
            else:
                categorical_features.append(True)
    # Calculates the normalized ranges and max values of numeric values
    ranges_of_numeric = [0.0] * cols
    max_of_numeric = [0.0] * cols
    for col in range(cols):
        if not categorical_features[col]:
            max = None
            min = None
            if issparse(X):
                col_array = X.getcol(col)
                max = col_array.max() + 0.0
                min = col_array.min() + 0.0
            else:
                col_array = X[:, col].astype(np.double)
                max = np.nanmax(col_array)
                min = np.nanmin(col_array)

            if np.isnan(max):
                max = 0.0
            if np.isnan(min):
                min = 0.0
            max_of_numeric[col] = max
            ranges_of_numeric[col] = (1 - min / max) if (max != 0) else 0.0

    if w is None:
        w = [1] * cols

    yrows, ycols = Y.shape

    dm = np.zeros((rows, yrows), dtype=np.double)

    for i in range(0, rows):
        j_start = i

        # for non square results
        if rows != yrows:
            j_start = 0

        for j in range(j_start, yrows):
            sum_sij = 0.0
            sum_wij = 0.0
            for col in range(cols):
                value_xi = X[i, col]
                value_xj = Y[j, col]

                if not categorical_features[col]:
                    if (max_of_numeric[col] != 0):
                        value_xi = value_xi / max_of_numeric[col]
                        value_xj = value_xj / max_of_numeric[col]
                    else:
                        value_xi = 0
                        value_xj = 0

                    if ranges_of_numeric[col] != 0:
                        sij = abs(value_xi - value_xj) / ranges_of_numeric[col]
                    else:
                        sij = 0
                    wij = (w[col], 0)[np.isnan(value_xi) or np.isnan(value_xj)]
                else:
                    sij = (1.0, 0.0)[value_xi == value_xj]
                    wij = (w[col], 0)[value_xi is None and value_xj is None]
                sum_sij += (wij * sij)
                sum_wij += wij

            if sum_wij != 0:
                dm[i, j] = (sum_sij / sum_wij)
                if j < rows and i < yrows:
                    dm[j, i] = dm[i, j]

    return dm

# %%
HotelUnclustered= pd.read_csv("Hotel_Reviews.csv",usecols=[5,7,8,10,11,12,14,15,16])

# %%
import re
HotelUnclustered['days_since_review'] = HotelUnclustered['days_since_review'].apply(lambda x: int(''.join(filter(str.isdigit, x))))
HotelUnclustered
# Out:
#               Reviewer_Nationality  Review_Total_Negative_Word_Counts  \
# 0                          Russia                                 397
# 1                         Ireland                                   0
# 2                       Australia                                  42
# 3                  United Kingdom                                 210
# 4                     New Zealand                                 140
# 5                          Poland                                  17
# 6                  United Kingdom                                  33
# 7                  United Kingdom                                  11
# 8                         Belgium                                  34
# 9                          Norway                                  15
# 10                 United Kingdom                                   5
# 11                         France                                  75
# 12                 United Kingdom                                  28
# 13                          Italy                                   0
# 14                         Canada                                  35
# 15                          Italy                                   0
# 16                 United Kingdom                                  38
# 17                        Ireland                                  59
# 18                    Netherlands                                   0
# 19                      Australia                                  73
# 20                 United Kingdom                                  40
# 21                         France                                  92
# 22                        Germany                                 364
# 23                        Ireland                                  22
# 24                 United Kingdom                                   3
# 25       United States of America                                  57
# 26                 United Kingdom                                  51
# 27                         France                                  31
# 28       United States of America                                  53
# 29                        Hungary                                  24
# ...                            ...                                ...
# 515708     Bosnia and Herzegovina                                   0
# 515709   United States of America                                   0
# 515710                       Iraq                                   3
# 515711                    Hungary                                  11
# 515712                     Israel                                  11
# 515713                     Norway                                   2
# 515714             United Kingdom                                  16
# 515715             United Kingdom                                   8
# 515716                      Egypt                                   8
# 515717                      Egypt                                   0
# 515718                   Thailand                                   4
# 515719                   Slovenia                                   0
# 515720                    Croatia                                   3
# 515721                    Hungary                                  10
# 515722             United Kingdom                                  19
# 515723                    Croatia                                   0
# 515724                      India                                   0
# 515725                     Russia                                   5
# 515726                     Kosovo                                  21
# 515727             United Kingdom                                  10
# 515728                      Qatar                                   2
# 515729                     Brazil                                   0
# 515730                     Israel                                  20
# 515731                    Germany                                  12
# 515732                     Kuwait                                   0
# 515733                     Kuwait                                  14
# 515734                    Estonia                                  11
# 515735                      Egypt                                  19
# 515736                     Mexico                                   0
# 515737                    Hungary                                  13
#
#         Total_Number_of_Reviews  Review_Total_Positive_Word_Counts  \
# 0                          1403                                 11
# 1                          1403                                105
# 2                          1403                                 21
# 3                          1403                                 26
# 4                          1403                                  8
# 5                          1403                                 20
# 6                          1403                                 18
# 7                          1403                                 19
# 8                          1403                                  0
# 9                          1403                                 50
# 10                         1403                                101
# 11                         1403                                  4
# 12                         1403                                  6
# 13                         1403                                 59
# 14                         1403                                 15
# 15                         1403                                 82
# 16                         1403                                 14
# 17                         1403                                 64
# 18                         1403                                 33
# 19                         1403                                 48
# 20                         1403                                 17
# 21                         1403                                 75
# 22                         1403                                 37
# 23                         1403                                 51
# 24                         1403                                130
# 25                         1403                                 43
# 26                         1403                                134
# 27                         1403                                  6
# 28                         1403                                 22
# 29                         1403                                 49
# ...                         ...                                ...
# 515708                     2823                                 22
# 515709                     2823                                 13
# 515710                     2823                                  5
# 515711                     2823                                  8
# 515712                     2823                                 10
# 515713                     2823                                  8
# 515714                     2823                                 14
# 515715                     2823                                  9
# 515716                     2823                                 12
# 515717                     2823                                 23
# 515718                     2823                                 12
# 515719                     2823                                  5
# 515720                     2823                                  9
# 515721                     2823                                  8
# 515722                     2823                                  2
# 515723                     2823                                 23
# 515724                     2823                                  9
# 515725                     2823                                  3
# 515726                     2823                                  5
# 515727                     2823                                 15
# 515728                     2823                                  2
# 515729                     2823                                 27
# 515730                     2823                                  3
# 515731                     2823                                  3
# 515732                     2823                                 18
# 515733                     2823                                  2
# 515734                     2823                                 11
# 515735                     2823                                  0
# 515736                     2823                                 25
# 515737                     2823                                  6
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                                7             2.9
# 1                                                7             7.5
# 2                                                9             7.1
# 3                                                1             3.8
# 4                                                3             6.7
# 5                                                1             6.7
# 6                                                6             4.6
# 7                                                1            10.0
# 8                                                3             6.5
# 9                                                1             7.9
# 10                                               2            10.0
# 11                                              12             5.8
# 12                                               7             4.6
# 13                                               6             9.2
# 14                                               1             8.8
# 15                                              26            10.0
# 16                                               8             6.3
# 17                                               2             7.5
# 18                                               4             7.1
# 19                                              16             7.5
# 20                                               1             6.3
# 21                                              12             3.8
# 22                                              21             5.4
# 23                                               1             9.6
# 24                                               2             9.6
# 25                                               4             8.3
# 26                                               2             9.6
# 27                                              25             8.3
# 28                                               4             8.3
# 29                                               2             9.2
# ...                                            ...             ...
# 515708                                          10             8.8
# 515709                                           6             7.9
# 515710                                           5             9.2
# 515711                                          37            10.0
# 515712                                          10             8.8
# 515713                                           1             7.1
# 515714                                           1             9.6
# 515715                                           1             8.8
# 515716                                          14             7.1
# 515717                                           1             7.9
# 515718                                          40             9.2
# 515719                                          14             8.3
# 515720                                           1             9.2
# 515721                                           3             6.7
# 515722                                          72             6.3
# 515723                                           1             8.8
# 515724                                           7             8.3
# 515725                                          30             7.1
# 515726                                          34             5.4
# 515727                                          12             5.8
# 515728                                           1             4.2
# 515729                                           7            10.0
# 515730                                           2             6.7
# 515731                                           1             7.5
# 515732                                           6            10.0
# 515733                                           8             7.0
# 515734                                          12             5.8
# 515735                                           3             2.5
# 515736                                           3             8.8
# 515737                                           1             8.3
#
#         days_since_review        lat        lng
# 0                       0  52.360576   4.915968
# 1                       0  52.360576   4.915968
# 2                       3  52.360576   4.915968
# 3                       3  52.360576   4.915968
# 4                      10  52.360576   4.915968
# 5                      10  52.360576   4.915968
# 6                      17  52.360576   4.915968
# 7                      17  52.360576   4.915968
# 8                      25  52.360576   4.915968
# 9                      26  52.360576   4.915968
# 10                     27  52.360576   4.915968
# 11                     28  52.360576   4.915968
# 12                     28  52.360576   4.915968
# 13                     30  52.360576   4.915968
# 14                     30  52.360576   4.915968
# 15                     31  52.360576   4.915968
# 16                     31  52.360576   4.915968
# 17                     34  52.360576   4.915968
# 18                     35  52.360576   4.915968
# 19                     44  52.360576   4.915968
# 20                     45  52.360576   4.915968
# 21                     52  52.360576   4.915968
# 22                     54  52.360576   4.915968
# 23                     66  52.360576   4.915968
# 24                     68  52.360576   4.915968
# 25                     70  52.360576   4.915968
# 26                     70  52.360576   4.915968
# 27                     73  52.360576   4.915968
# 28                     74  52.360576   4.915968
# 29                     79  52.360576   4.915968
# ...                   ...        ...        ...
# 515708                461  48.203745  16.335677
# 515709                461  48.203745  16.335677
# 515710                462  48.203745  16.335677
# 515711                466  48.203745  16.335677
# 515712                471  48.203745  16.335677
# 515713                473  48.203745  16.335677
# 515714                476  48.203745  16.335677
# 515715                491  48.203745  16.335677
# 515716                549  48.203745  16.335677
# 515717                578  48.203745  16.335677
# 515718                579  48.203745  16.335677
# 515719                602  48.203745  16.335677
# 515720                603  48.203745  16.335677
# 515721                604  48.203745  16.335677
# 515722                616  48.203745  16.335677
# 515723                627  48.203745  16.335677
# 515724                646  48.203745  16.335677
# 515725                650  48.203745  16.335677
# 515726                675  48.203745  16.335677
# 515727                676  48.203745  16.335677
# 515728                676  48.203745  16.335677
# 515729                677  48.203745  16.335677
# 515730                683  48.203745  16.335677
# 515731                696  48.203745  16.335677
# 515732                697  48.203745  16.335677
# 515733                704  48.203745  16.335677
# 515734                712  48.203745  16.335677
# 515735                715  48.203745  16.335677
# 515736                717  48.203745  16.335677
# 515737                725  48.203745  16.335677
#
# [515738 rows x 9 columns]

# %%
HotelUnclustered

# %%
def kMedoids(D, k, tmax=100):
    # determine dimensions of distance matrix D
    m, n = D.shape

    if k > n:
        raise Exception('too many medoids')
    # randomly initialize an array of k medoid indices
    M = np.arange(n)
    np.random.shuffle(M)
    M = np.sort(M[:k])

    # create a copy of the array of medoid indices
    Mnew = np.copy(M)

    # initialize a dictionary to represent clusters
    C = {}
    for t in range(tmax):
        # determine clusters, i. e. arrays of data indices
        J = np.argmin(D[:,M], axis=1)
        for kappa in range(k):
            C[kappa] = np.where(J==kappa)[0]
        # update cluster medoids
        for kappa in range(k):
            J = np.mean(D[np.ix_(C[kappa],C[kappa])],axis=1)
            j = np.argmin(J)
            Mnew[kappa] = C[kappa][j]
        np.sort(Mnew)
        # check for convergence
        if np.array_equal(M, Mnew):
            break
        M = np.copy(Mnew)
    else:
        # final update of cluster memberships
        J = np.argmin(D[:,M], axis=1)
        for kappa in range(k):
            C[kappa] = np.where(J==kappa)[0]

    # return results
    return M, C

# %%
HotelUnclustered_100_indices=np.random.choice(len(HotelUnclustered), 500,replace=False)

# %%
selected_reviews=HotelUnclustered.loc[HotelUnclustered_100_indices,:]

# %%
selected_reviews
# Out:
#               Reviewer_Nationality  Review_Total_Negative_Word_Counts  \
# 462084             United Kingdom                                  12
# 182816                      Japan                                 131
# 4176               United Kingdom                                   0
# 508669             United Kingdom                                  13
# 353141             United Kingdom                                   5
# 2375                        India                                  51
# 130287             United Kingdom                                  29
# 289214             United Kingdom                                  10
# 122755                  Hong Kong                                  49
# 347083                   Maldives                                   6
# 448628             United Kingdom                                   2
# 38661                 Switzerland                                  68
# 341563   United States of America                                   0
# 151298             United Kingdom                                   8
# 261334             United Kingdom                                  11
# 118935   United States of America                                  17
# 265417             United Kingdom                                  25
# 184172                    Ireland                                   6
# 61276              United Kingdom                                   0
# 374165                  Australia                                  13
# 256685             United Kingdom                                   0
# 20773              United Kingdom                                  43
# 191508               Saudi Arabia                                  10
# 246617                      Italy                                   3
# 434964   United States of America                                   2
# 99458                    Maldives                                  14
# 213013             United Kingdom                                   3
# 187197             United Kingdom                                  23
# 246219             United Kingdom                                   2
# 213463       United Arab Emirates                                   0
# ...                            ...                                ...
# 78807                    Guernsey                                   0
# 475825                    Romania                                 103
# 483354                    Hungary                                  14
# 254519             United Kingdom                                  33
# 53101                     Bahrain                                   0
# 270861             United Kingdom                                   0
# 321604             United Kingdom                                  74
# 185399                   Thailand                                  45
# 99560                   Australia                                   0
# 445499             United Kingdom                                  14
# 429444                  Indonesia                                  30
# 422148             United Kingdom                                  35
# 357279             United Kingdom                                  38
# 114482             United Kingdom                                   7
# 175469             United Kingdom                                   4
# 410008                     Mexico                                   3
# 314317                  Australia                                   9
# 502568                     France                                  39
# 365246             United Kingdom                                  13
# 379430                     Israel                                  34
# 346534             United Kingdom                                   7
# 203563       United Arab Emirates                                  15
# 475722                    Denmark                                   5
# 45031                      Turkey                                  11
# 359979                    Ireland                                   7
# 289497                    Austria                                   5
# 135734             United Kingdom                                  37
# 199477             Czech Republic                                   8
# 176576             United Kingdom                                   6
# 360555   United States of America                                   6
#
#         Total_Number_of_Reviews  Review_Total_Positive_Word_Counts  \
# 462084                     2027                                 14
# 182816                      768                                  7
# 4176                       3150                                 40
# 508669                     1193                                 19
# 353141                     1375                                  0
# 2375                       4380                                 16
# 130287                     1114                                 10
# 289214                     2692                                 24
# 122755                     1008                                 12
# 347083                     2586                                  4
# 448628                     1207                                  3
# 38661                      2418                                 25
# 341563                      803                                 12
# 151298                      983                                 19
# 261334                     1774                                 56
# 118935                      761                                 18
# 265417                     1871                                  8
# 184172                     5394                                  8
# 61276                       812                                 20
# 374165                      460                                  3
# 256685                      683                                 23
# 20773                      1608                                 15
# 191508                     3117                                  0
# 246617                     1266                                  3
# 434964                      631                                  4
# 99458                       729                                  9
# 213013                      900                                  0
# 187197                     2147                                 12
# 246219                     1708                                 17
# 213463                     3609                                 12
# ...                         ...                                ...
# 78807                      1470                                  9
# 475825                     5742                                 21
# 483354                      974                                 32
# 254519                     1733                                 10
# 53101                      2898                                 11
# 270861                      372                                  2
# 321604                     2726                                  0
# 185399                      347                                 10
# 99560                       268                                 22
# 445499                     3773                                  6
# 429444                     1560                                 23
# 422148                     4530                                 30
# 357279                     1827                                 83
# 114482                     6977                                  2
# 175469                     1271                                  4
# 410008                     3510                                 10
# 314317                     1594                                 20
# 502568                     2085                                  0
# 365246                     1463                                  5
# 379430                     3748                                 26
# 346534                     1992                                  4
# 203563                     1055                                 32
# 475722                     1197                                  2
# 45031                      2543                                 69
# 359979                      390                                  4
# 289497                     2692                                 11
# 135734                     3973                                  9
# 199477                     1705                                 14
# 176576                     1500                                  9
# 360555                     1957                                 63
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 462084                                           7             8.8
# 182816                                           2             5.0
# 4176                                             1             9.6
# 508669                                          31             8.3
# 353141                                           8             9.0
# 2375                                             2             9.5
# 130287                                          30             7.9
# 289214                                           6             8.3
# 122755                                           2             7.9
# 347083                                           5             9.2
# 448628                                          21             9.6
# 38661                                            7             5.8
# 341563                                          13             8.8
# 151298                                           1             8.8
# 261334                                           3            10.0
# 118935                                           3             8.3
# 265417                                           4             8.8
# 184172                                           2            10.0
# 61276                                            3            10.0
# 374165                                           7             7.9
# 256685                                           2            10.0
# 20773                                            1             8.8
# 191508                                           5             5.4
# 246617                                           2            10.0
# 434964                                           1            10.0
# 99458                                           16             7.0
# 213013                                           3             8.3
# 187197                                           2             8.3
# 246219                                           4            10.0
# 213463                                          13             9.6
# ...                                            ...             ...
# 78807                                            1             9.6
# 475825                                          11             6.3
# 483354                                           7             8.3
# 254519                                           7             7.1
# 53101                                            2             9.6
# 270861                                           1            10.0
# 321604                                           3             9.6
# 185399                                          36             8.8
# 99560                                            8            10.0
# 445499                                          11             6.7
# 429444                                           6             8.3
# 422148                                          21             7.9
# 357279                                           2             9.2
# 114482                                           1             7.9
# 175469                                           1             8.8
# 410008                                           4             8.8
# 314317                                           4             9.2
# 502568                                           6             7.1
# 365246                                           3            10.0
# 379430                                           5             8.8
# 346534                                          15             6.3
# 203563                                           3            10.0
# 475722                                           5             3.3
# 45031                                           25             8.3
# 359979                                          13             7.5
# 289497                                           8             9.6
# 135734                                           1             6.7
# 199477                                           5             6.3
# 176576                                           1             8.8
# 360555                                           1            10.0
#
#         days_since_review        lat        lng
# 462084                548  52.361381   4.883259
# 182816                459  51.512676  -0.186783
# 4176                  582  51.522622  -0.125160
# 508669                527  51.509133  -0.130189
# 353141                177  48.202110  16.372084
# 2375                  352  51.514218  -0.180903
# 130287                449  51.498882  -0.106289
# 289214                382  48.203568  16.356445
# 122755                692  51.517330  -0.118097
# 347083                438  52.358881   4.988604
# 448628                442  48.208222  16.375184
# 38661                 281  51.511993  -0.178279
# 341563                297  52.365387   4.893198
# 151298                115  48.874046   2.300196
# 261334                506  51.520106  -0.122139
# 118935                 30  51.520327  -0.124589
# 265417                270  51.529860  -0.144462
# 184172                185  51.498673  -0.137687
# 61276                 150  51.493475  -0.215326
# 374165                  5  41.389058   2.156595
# 256685                239  48.842736   2.367217
# 20773                 560  51.499026  -0.142745
# 191508                627  51.510574  -0.150995
# 246617                318  48.850650   2.275087
# 434964                721  41.396247   2.160955
# 99458                 365  48.847346   2.283241
# 213013                263  51.504533  -0.219117
# 187197                597  51.531979  -0.061598
# 246219                322  51.494775  -0.177789
# 213463                509  51.515367  -0.178327
# ...                   ...        ...        ...
# 78807                 410  51.494806  -0.192653
# 475825                125  45.472065   9.077787
# 483354                594  45.462297   9.181470
# 254519                105  51.519586  -0.158480
# 53101                 571  51.515632  -0.175737
# 270861                178  52.350456   4.877019
# 321604                238  51.507377   0.038657
# 185399                639  48.868359   2.300212
# 99560                  18  48.850307   2.345061
# 445499                539  52.292457   4.944434
# 429444                445  51.501315  -0.217446
# 422148                718  52.341943   4.875960
# 357279                115  51.480672  -0.007137
# 114482                692  51.519569  -0.170521
# 175469                505  51.513931  -0.121989
# 410008                709  45.484514   9.205753
# 314317                331  41.388801   2.165374
# 502568                322  52.358382   4.898878
# 365246                506  51.511945  -0.179939
# 379430                706  48.175628  16.420096
# 346534                114  52.309684   4.942261
# 203563                660  48.854787   2.308482
# 475722                520  45.480250   9.149493
# 45031                 394  51.512246  -0.075733
# 359979                300  41.382789   2.171564
# 289497                607  48.203568  16.356445
# 135734                667  48.880278   2.284385
# 199477                114  51.504575  -0.082675
# 176576                297  51.521012  -0.262862
# 360555                373  41.384322   2.171289
#
# [500 rows x 9 columns]

# %%
selected_reviews.isnull().any()
# Out:
# Reviewer_Nationality                          False
# Review_Total_Negative_Word_Counts             False
# Total_Number_of_Reviews                       False
# Review_Total_Positive_Word_Counts             False
# Total_Number_of_Reviews_Reviewer_Has_Given    False
# Reviewer_Score                                False
# days_since_review                             False
# lat                                            True
# lng                                            True
# dtype: bool

# %%
D = gower_distances(selected_reviews)
print(D)

# %%
from sklearn.manifold import MDS
import matplotlib.pyplot as plt
model = MDS(n_components=2, dissimilarity='precomputed', random_state=1)
out = model.fit_transform(D)
plt.scatter(out[:, 0], out[:, 1])
plt.axis('equal');
plt.show()

# %%
M, C = kMedoids(D, 2)
selected_reviews.iloc[89,:]
for point_idx in M:
    print( selected_reviews.iloc[point_idx,:] )

# %%
print('')
print('clustering result:')
for label in C:
    for point_idx in C[label]:
        print('label {0}:　{1}'.format(label, selected_reviews.iloc[point_idx,:]))

# %%
#!pip3 install requests
import requests
import json
import pandas as pd

# %%
Hotel_Reviews=pd.read_csv("Hotel_Reviews.csv",usecols=['Hotel_Name','lat','lng']).drop_duplicates()
Hotel_Reviews
# Out:
#                                           Hotel_Name        lat        lng
# 0                                        Hotel Arena  52.360576   4.915968
# 405                                 K K Hotel George  51.491888  -0.194971
# 971                          Apex Temple Court Hotel  51.513734  -0.108751
# 2008                The Park Grand London Paddington  51.514218  -0.180903
# 3778                             Monhotel Lounge SPA  48.874348   2.289733
# 3813                              Kube Hotel Ice Bar  48.886570   2.358833
# 3832                            The Principal London  51.522622  -0.125160
# 5257                   Park Plaza County Hall London  51.501400  -0.116009
# 7480                                     One Aldwych  51.511783  -0.119417
# 7616                                 Splendid Etoile  48.874707   2.293676
# 7743                       Hotel Trianon Rive Gauche  48.848768   2.341038
# 7961               InterContinental London Park Lane  51.503863  -0.150413
# 8121                 Novotel Suites Paris Nord 18 me  48.901594   2.359778
# 8301                   Grand Royale London Hyde Park  51.510995  -0.186342
# 11259                     Milestone Hotel Kensington  51.502043  -0.186654
# 11345                Crowne Plaza London Kings Cross  51.526385  -0.113604
# 12352                                   Select Hotel  48.848305   2.342560
# 12608                               H tel De Vend me  48.866856   2.328634
# 12697                     Pullman Paris Centre Bercy  48.831520   2.387080
# 12921                            Gardette Park Hotel  48.861027   2.378897
# 13100                                  Hotel Panache  48.873254   2.343239
# 13182                         H tel des Ducs D Anjou  48.859823   2.347111
# 13290            Hotel Scribe Paris Opera by Sofitel  48.870418   2.329683
# 13425                            Novotel London West  51.491959  -0.220096
# 14708                                Haymarket Hotel  51.508460  -0.131138
# 14829                 Intercontinental London The O2  51.502435  -0.000250
# 17380                            H tel Juliana Paris  48.861937   2.304030
# 17549                                Hotel L Antoine  48.852422   2.374383
# 17720                                        Belfast  48.875644   2.293879
# 17806                         Shangri La Hotel Paris  48.863714   2.293476
# ...                                              ...        ...        ...
# 499054                              Acevi Villarroel  41.385378   2.156723
# 499406                              Hotel Arkadenhof  48.230701  16.355219
# 499434                        Hotel Vondel Amsterdam  52.362566   4.877922
# 499956            Hotel Pension Baron am Schottentor        NaN        NaN
# 500179                                 Hotel Atlanta        NaN        NaN
# 500568          Park Inn by Radisson Uno City Vienna  48.234080  16.421009
# 500929                                NH Danube City  48.235379  16.421974
# 501153                        Strandhotel Alte Donau  48.239002  16.429233
# 501194                 ARCOTEL Kaiserwasser Superior  48.231915  16.417026
# 501337                    Mercure Hotel Raphael Wien  48.191929  16.339139
# 501488                     Arthotel ANA Boutique Six  48.194191  16.346258
# 501878               Austria Trend Hotel Anatol Wien  48.194577  16.346356
# 502028                      Hotel Kaiserin Elisabeth  48.207235  16.372238
# 502416                   Boutique Hotel Notting Hill  52.358382   4.898878
# 503073                    Crowne Plaza London Ealing  51.540394  -0.369758
# 503486                             Good Hotel London  51.508420   0.025322
# 504027          Park Plaza Westminster Bridge London  51.500961  -0.116591
# 508196        Hotel du Vin Cannizaro House Wimbledon  51.424241  -0.229350
# 508485                     Amsterdam Canal Residence  52.359478   4.895853
# 508552  Thistle Trafalgar Square The Royal Trafalgar  51.509133  -0.130189
# 509019                        Corinthia Hotel London  51.504558  -0.126258
# 509232              The Student Hotel Amsterdam City  52.354665   4.913164
# 510808                             Hotel Prinz Eugen  48.187726  16.378145
# 511319                        Hotel Erzherzog Rainer  48.195323  16.367288
# 511920                              Das Triest Hotel  48.197404  16.367300
# 511962                    Suite Hotel 900 m zur Oper  48.193523  16.366915
# 512401                                 Hotel Amadeus  48.210447  16.371578
# 512545                                  The Berkeley  51.502091  -0.157780
# 512645                 Holiday Inn London Kensington  51.499981  -0.192879
# 515413                         Atlantis Hotel Vienna  48.203745  16.335677
#
# [1494 rows x 3 columns]

# %%
Hotel_Reviews['landmark_count']='-'

# %%
ex=Hotel_Reviews.lng[500179]
np.isnan(ex)

# %%
def landmarksCount(lat,lng):
    url='https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox='+str(lat)+','+str(lng)+',500'
    r = requests.get(url)
    jsonobj=json.loads(r.text)
    if len(jsonobj['Response']['View'])>0:
        return(len(jsonobj['Response']['View'][0]['Result']))
    else:
        return 0

# %%
landmarksCount(52.360576,4.915968)
# Out:
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=52.360576,4.915968,500
# 6

# %%
for i in Hotel_Reviews.index:
    lat = Hotel_Reviews.lat[i]
    lng = Hotel_Reviews.lng[i]
    if np.isnan(lat) or np.isnan(lng):
           continue
    else:  
            try:       
                Hotel_Reviews['landmark_count'][i]=landmarksCount(lat,lng)
            except:
                print("error at",i,lat,lng)
# Out:
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=52.3605759,4.9159683,500
# C:\Users\Anant\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4918878,-0.1949706,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5137335,-0.1087512,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5142184,-0.1809032,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8743481,2.2897334,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.88657,2.3588332,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5226217,-0.1251602,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5014001,-0.1160092,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5117832,-0.1194172,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.874707,2.2936761,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8487675,2.3410376,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5038632,-0.1504132,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.9015941,2.3597783,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5109945,-0.1863417,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5020425,-0.1866541,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5263854,-0.1136042,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8483053,2.3425596,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8668564,2.3286339,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8315204,2.3870797,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8610265,2.3788974,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8732543,2.343239,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8598229,2.347111,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8704175,2.3296832,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4919588,-0.2200956,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5084595,-0.1311382,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5024348,-0.0002497,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8619373,2.3040298,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8524215,2.3743832,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8756435,2.2938788,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8637135,2.2934759,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8460269,2.2788281,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4980052,-0.1643238,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5167472,-0.135965,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4916378,-0.1832833,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8780363,2.2864907,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5147387,-0.1341108,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5127625,-0.0997157,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4943077,-0.1755579,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5145986,-0.1270336,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4990259,-0.1427453,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5106538,-0.0773676,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8673199,2.3656296,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8656973,2.2829776,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8735418,2.302442,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8555319,2.3621212,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.88366,2.3313845,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8789432,2.3448623,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8491427,2.3397118,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8734851,2.3485111,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8376887,2.3063102,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8699103,2.2973386,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8766269,2.3432886,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8661705,2.331561,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8729676,2.3081178,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.510843,-0.1314287,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4611219,-0.2756216,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5286766,-0.1283489,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.495179,-0.183827,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4925138,-0.1787917,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5254162,-0.0772849,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4891226,-0.1205639,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4956657,-0.1452793,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5014191,-0.1625805,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8848583,2.2997023,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8688962,2.2827459,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8494851,2.2955063,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5108439,-0.1839074,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5209191,-0.1566567,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8756604,2.3252075,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4925478,-0.1780611,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5426054,-0.0072708,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5426351,-0.0073272,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5054544,-0.2262216,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5188555,-0.1319172,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8468064,2.3714789,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8427564,2.3305636,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8708508,2.3515882,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4936161,-0.1592347,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.502485,-0.1539265,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8728324,2.3193886,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.871723,2.3235377,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8732706,2.3450746,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8761376,2.3572681,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8581186,2.3529369,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8725794,2.3075779,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4959227,-0.1702917,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8405612,2.2991035,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8550466,2.304583,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4945522,-0.1861213,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4990953,-0.1132136,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8687425,2.3541761,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4948465,-0.1187481,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.504716,-0.1475618,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4945144,-0.1866172,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5090985,-0.0157302,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8663359,2.2867935,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.870961,2.3267678,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8865626,2.3329648,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8724588,2.3378004,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8715828,2.3224853,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5208575,-0.0779503,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5119933,-0.1782794,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5166755,-0.0697897,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8489839,2.348383,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8684165,2.336869,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8685093,2.3067895,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.881407,2.3274204,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8713699,2.3181191,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8665788,2.3084447,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8663444,2.2881979,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8644627,2.3318473,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5266618,-0.1296571,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8675886,2.3531018,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8730823,2.309659,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5220869,-0.1082443,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8848292,2.3035189,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5421476,-0.1703073,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.51046,-0.1875844,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.520378,-0.1303414,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8639318,2.3658744,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8693409,2.3310263,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8562272,2.3351758,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8178079,2.3293636,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8738557,2.3444232,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8490691,2.3697484,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8513515,2.3375084,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5210085,-0.1230966,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5122457,-0.0757326,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5241386,-0.1380807,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8753446,2.3167161,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5163841,-0.1635764,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.517839,-0.1424476,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5132069,-0.1807816,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5109079,-0.1238221,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8751845,2.3013214,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8493499,2.3430569,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8668589,2.3028215,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8686931,2.325211,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8560685,2.3236846,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8438352,2.3280708,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4938733,-0.1824963,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5131428,-0.1576714,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.861711,2.340674,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5128032,-0.07586,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4903724,-0.1459218,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.875551,2.2835191,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8531641,2.3344097,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5161139,-0.1749521,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.515632,-0.175737,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4944849,-0.1884174,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5012329,-0.1859937,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5184158,-0.1348509,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4975621,-0.145551,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8196885,2.3263505,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4943935,-0.1750169,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.520181,-0.1256957,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8679466,2.3289593,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8532269,2.3457159,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.868414,2.3213247,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8690596,2.2971078,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8797331,2.3206003,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8420669,2.3304091,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8652582,2.3329632,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8516619,2.2979395,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8328764,2.3572531,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8550236,2.3350786,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5147071,-0.1578291,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5100362,-0.190657,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5069446,-0.1415776,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5278465,-0.0889473,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8453774,2.3256427,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5561548,-0.2141824,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.853688,2.3322667,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4934752,-0.2153256,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.843707,2.3155631,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5171671,-0.1290534,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8654874,2.3348924,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8542681,2.3078116,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8728351,2.3362507,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5150534,-0.1739974,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8795369,2.3202966,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8726335,2.3048084,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8705741,2.3264194,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4930905,-0.1755022,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4946905,-0.1910197,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8793427,2.3577745,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5019097,-0.0232208,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8870573,2.3143297,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8864673,2.2948911,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8871283,2.314205,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5265189,-0.1303689,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4968406,-0.1675498,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4999683,-0.1599927,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8713239,2.2937849,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8585193,2.3077243,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8315962,2.3399796,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5215257,-0.1533039,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.871309,2.3277079,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8720593,2.3236802,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8644382,2.3359148,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.838484,2.3150904,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8908018,2.3380204,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8535089,2.3425787,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5015721,-0.1628511,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4778583,-0.0137463,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5241452,-0.1609907,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8746128,2.3056956,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8750848,2.3048372,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.520943,-0.1004581,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4954976,-0.1893691,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4913737,-0.1214194,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8555664,2.2926243,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.529257,-0.168358,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8663208,2.3450399,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8678432,2.3033075,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8691686,2.3337818,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8803752,2.319591,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8709627,2.3154141,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4948059,-0.1926525,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5032524,-0.078179,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8237487,2.324056,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5143624,-0.1394483,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4907493,-0.1934627,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5144381,-0.1558337,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8710605,2.2933537,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8605125,2.3106533,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.583236,-0.216868,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5122429,-0.1045036,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.845743,2.34493,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8690198,2.2891278,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8478399,2.342254,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8713421,2.3280723,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8592264,2.340996,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8382943,2.3210421,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8603483,2.3440535,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8722588,2.3257608,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8717649,2.2983855,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5001979,-0.1795357,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5172398,-0.1220324,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4950098,-0.1906195,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5027022,-0.1882164,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5244224,-0.0764614,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8721062,2.3451384,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5203469,-0.1260893,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5056956,-0.101525,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.511521,-0.290706,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8448902,2.252833,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8475112,2.3022198,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.49398,-0.143372,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.498905,-0.1339093,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5191009,-0.1592,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8637503,2.3320406,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8442949,2.3730938,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8349272,2.3295913,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8722884,2.3090359,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8690126,2.3368708,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.8814056,2.3282568,500
# ...
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4565757,9.1684824,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4837173,9.1649371,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4701334,9.1897405,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4881471,9.2016609,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.5138582,9.1194759,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4589731,9.0687506,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4829817,9.2041911,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4670579,9.1427822,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.465237,9.191247,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4655368,9.1914986,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.467298,9.1846982,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4672309,9.184154,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4630441,9.183607,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4657568,9.1916674,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4574655,9.1919138,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.470238,9.195347,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4714062,9.1965303,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4691663,9.1984454,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.5331372,9.1711019,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4648822,9.1893265,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4657842,9.1895321,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.463579,9.1869092,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4779041,9.2094965,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.501946,9.2277569,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4769167,9.196665,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4851799,9.1831189,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4709657,9.1566242,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4654912,9.1889612,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4510425,9.1606536,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.488764,9.183057,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.5000245,9.1428722,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.5147974,9.116606,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.500667,9.1445874,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4611287,9.1542675,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4853717,9.2115837,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4847398,9.2072916,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4635445,9.2068649,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4510397,9.1920911,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4508673,9.1948659,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4947129,9.1418864,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.494861,9.141551,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4921089,9.1476806,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.5266395,9.2131549,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4471408,9.2070051,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4472099,9.2090967,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4872511,9.2237385,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.480968,9.189977,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.502453,9.2218364,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.50054,9.2208089,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4725167,9.1439198,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4736557,9.2066824,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.5257221,9.2150033,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.506502,9.1965192,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=45.4770906,9.2054208,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=52.3663727,4.8930505,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=52.365823,4.893243,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=41.3766732,2.1524478,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=41.4047934,2.1288527,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=41.3853781,2.1567228,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.2307014,16.3552189,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=52.3625662,4.8779225,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.2340799,16.4210093,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.2353789,16.4219737,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.2390022,16.4292329,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.231915,16.417026,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.1919288,16.3391395,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.1941905,16.3462578,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.1945774,16.346356,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.2072348,16.372238,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=52.3583821,4.8988777,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5403942,-0.3697581,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5084195,0.0253216,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5009609,-0.1165913,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.4242413,-0.2293503,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=52.3594783,4.895853,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.509133,-0.130189,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5045583,-0.1262584,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=52.3546649,4.9131641,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.1877258,16.3781454,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.1953229,16.3672882,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.1974036,16.3673003,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.1935235,16.3669145,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.2104468,16.3715781,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.5020912,-0.1577795,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=51.499981,-0.1928791,500
# https://reverse.geocoder.cit.api.here.com/6.2/reversegeocode.json?app_id=6P8bp4So17PsN2isu0RY&app_code=uXbjRVdq9Bd0k2RsH641SA&gen=8&mode=retrieveLandmarks&prox=48.2037451,16.3356767,500

# %%
Hotel_Reviews.to_csv("landmarks_count.csv")
