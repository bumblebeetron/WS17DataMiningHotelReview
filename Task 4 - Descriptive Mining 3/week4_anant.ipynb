# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance 
from sklearn.utils import validation
from sklearn.metrics import pairwise
from scipy.sparse import issparse
import random

# %%
def _return_float_dtype(X, Y):
    """
    1. If dtype of X and Y is float32, then dtype float32 is returned.
    2. Else dtype float is returned.
    """
    if not issparse(X) and not isinstance(X, np.ndarray):
        X = np.asarray(X)

    if Y is None:
        Y_dtype = X.dtype
    elif not issparse(Y) and not isinstance(Y, np.ndarray):
        Y = np.asarray(Y)
        Y_dtype = Y.dtype
    else:
        Y_dtype = Y.dtype

    if X.dtype == Y_dtype == np.float32:
        dtype = np.float32
    elif X.dtype == np.object and not issparse(X):
        dtype = np.float
        for col in range(X.shape[1]):
            if not np.issubdtype(type(X[0, col]), np.number):
                dtype = np.object
                break
    else:
        dtype = np.float

    return X, Y, dtype


def check_pairwise_arrays(X, Y, precomputed=False, dtype=None):
    X, Y, dtype_float = _return_float_dtype(X, Y)

    warn_on_dtype = dtype is not None
    estimator = 'check_pairwise_arrays'
    if dtype is None:
        dtype = dtype_float


    if Y is X or Y is None:
        X = Y = validation.check_array(X, accept_sparse='csr', dtype=dtype,
                            warn_on_dtype=warn_on_dtype, estimator=estimator)
    else:
        X = validation.check_array(X, accept_sparse='csr', dtype=dtype,
                        warn_on_dtype=warn_on_dtype, estimator=estimator)
        Y = validation.check_array(Y, accept_sparse='csr', dtype=dtype,
                        warn_on_dtype=warn_on_dtype, estimator=estimator)

    if precomputed:
        if X.shape[1] != Y.shape[0]:
            raise ValueError("Precomputed metric requires shape "
                             "(n_queries, n_indexed). Got (%d, %d) "
                             "for %d indexed." %
                             (X.shape[0], X.shape[1], Y.shape[0]))
    elif X.shape[1] != Y.shape[1]:
        raise ValueError("Incompatible dimension for X and Y matrices: "
                         "X.shape[1] == %d while Y.shape[1] == %d" % (
                             X.shape[1], Y.shape[1]))

    return X, Y

# %%
def gower_distances(X, Y=None, w=None, categorical_features=None):
    """
    Computes the gower distances between X and Y

    Read more in the :ref:`User Guide <metrics>`.

    Parameters
    ----------
    X : array-like, shape (n_samples, n_features)

    Y : array-like, shape (n_samples, n_features)

    w:  array-like, shape (n_features)
    According the Gower formula, w is an attribute weight.

    categorical_features: array-like, shape (n_features)
    Indicates with True/False wheter a column is a categorical attribute.
    This is useful when categorical atributes are represented as integer
    values.

    Returns
    -------
    similarities : ndarray, shape (n_samples, )

    Notes
    ------
    Gower is a similarity measure for categorical, boolean and numerical mixed
    data.

    """

    X, Y = check_pairwise_arrays(X, Y, dtype=(np.object, None)[issparse(X) or
                                                               issparse(Y)])

    rows, cols = X.shape

    if categorical_features is None:
        categorical_features = []
        for col in range(cols):
            if np.issubdtype(type(X[0, col]), np.number):
                categorical_features.append(False)
            else:
                categorical_features.append(True)
    # Calculates the normalized ranges and max values of numeric values
    ranges_of_numeric = [0.0] * cols
    max_of_numeric = [0.0] * cols
    for col in range(cols):
        if not categorical_features[col]:
            max = None
            min = None
            if issparse(X):
                col_array = X.getcol(col)
                max = col_array.max() + 0.0
                min = col_array.min() + 0.0
            else:
                col_array = X[:, col].astype(np.double)
                max = np.nanmax(col_array)
                min = np.nanmin(col_array)

            if np.isnan(max):
                max = 0.0
            if np.isnan(min):
                min = 0.0
            max_of_numeric[col] = max
            ranges_of_numeric[col] = (1 - min / max) if (max != 0) else 0.0

    if w is None:
        w = [1] * cols

    yrows, ycols = Y.shape

    dm = np.zeros((rows, yrows), dtype=np.double)

    for i in range(0, rows):
        j_start = i

        # for non square results
        if rows != yrows:
            j_start = 0

        for j in range(j_start, yrows):
            sum_sij = 0.0
            sum_wij = 0.0
            for col in range(cols):
                value_xi = X[i, col]
                value_xj = Y[j, col]

                if not categorical_features[col]:
                    if (max_of_numeric[col] != 0):
                        value_xi = value_xi / max_of_numeric[col]
                        value_xj = value_xj / max_of_numeric[col]
                    else:
                        value_xi = 0
                        value_xj = 0

                    if ranges_of_numeric[col] != 0:
                        sij = abs(value_xi - value_xj) / ranges_of_numeric[col]
                    else:
                        sij = 0
                    wij = (w[col], 0)[np.isnan(value_xi) or np.isnan(value_xj)]
                else:
                    sij = (1.0, 0.0)[value_xi == value_xj]
                    wij = (w[col], 0)[value_xi is None and value_xj is None]
                sum_sij += (wij * sij)
                sum_wij += wij

            if sum_wij != 0:
                dm[i, j] = (sum_sij / sum_wij)
                if j < rows and i < yrows:
                    dm[j, i] = dm[i, j]

    return dm

# %%
def gower_distances(X, Y=None, w=None, categorical_features=None):
    """
    Computes the gower distances between X and Y

    Read more in the :ref:`User Guide <metrics>`.

    Parameters
    ----------
    X : array-like, shape (n_samples, n_features)

    Y : array-like, shape (n_samples, n_features)

    w:  array-like, shape (n_features)
    According the Gower formula, w is an attribute weight.

    categorical_features: array-like, shape (n_features)
    Indicates with True/False wheter a column is a categorical attribute.
    This is useful when categorical atributes are represented as integer
    values.

    Returns
    -------
    similarities : ndarray, shape (n_samples, )

    Notes
    ------
    Gower is a similarity measure for categorical, boolean and numerical mixed
    data.

    """

    X, Y = check_pairwise_arrays(X, Y, dtype=(np.object, None)[issparse(X) or
                                                               issparse(Y)])

    rows, cols = X.shape

    if categorical_features is None:
        categorical_features = []
        for col in range(cols):
            if np.issubdtype(type(X[0, col]), np.number):
                categorical_features.append(False)
            else:
                categorical_features.append(True)
    # Calculates the normalized ranges and max values of numeric values
    ranges_of_numeric = [0.0] * cols
    max_of_numeric = [0.0] * cols
    for col in range(cols):
        if not categorical_features[col]:
            max = None
            min = None
            if issparse(X):
                col_array = X.getcol(col)
                max = col_array.max() + 0.0
                min = col_array.min() + 0.0
            else:
                col_array = X[:, col].astype(np.double)
                max = np.nanmax(col_array)
                min = np.nanmin(col_array)

            if np.isnan(max):
                max = 0.0
            if np.isnan(min):
                min = 0.0
            max_of_numeric[col] = max
            ranges_of_numeric[col] = (1 - min / max) if (max != 0) else 0.0

    if w is None:
        w = [1] * cols

    yrows, ycols = Y.shape

    dm = np.zeros((rows, yrows), dtype=np.double)

    for i in range(0, rows):
        j_start = i

        # for non square results
        if rows != yrows:
            j_start = 0

        for j in range(j_start, yrows):
            sum_sij = 0.0
            sum_wij = 0.0
            for col in range(cols):
                value_xi = X[i, col]
                value_xj = Y[j, col]

                if not categorical_features[col]:
                    if (max_of_numeric[col] != 0):
                        value_xi = value_xi / max_of_numeric[col]
                        value_xj = value_xj / max_of_numeric[col]
                    else:
                        value_xi = 0
                        value_xj = 0

                    if ranges_of_numeric[col] != 0:
                        sij = abs(value_xi - value_xj) / ranges_of_numeric[col]
                    else:
                        sij = 0
                    wij = (w[col], 0)[np.isnan(value_xi) or np.isnan(value_xj)]
                else:
                    sij = (1.0, 0.0)[value_xi == value_xj]
                    wij = (w[col], 0)[value_xi is None and value_xj is None]
                sum_sij += (wij * sij)
                sum_wij += wij

            if sum_wij != 0:
                dm[i, j] = (sum_sij / sum_wij)
                if j < rows and i < yrows:
                    dm[j, i] = dm[i, j]

    return dm

# %%
HotelUnclustered= pd.read_csv("Hotel_Reviews.csv",usecols=[5,7,8,10,11,12,15,16])

# %%
def kMedoids(D, k, tmax=100):
    # determine dimensions of distance matrix D
    m, n = D.shape

    if k > n:
        raise Exception('too many medoids')
    # randomly initialize an array of k medoid indices
    M = np.arange(n)
    np.random.shuffle(M)
    M = np.sort(M[:k])

    # create a copy of the array of medoid indices
    Mnew = np.copy(M)

    # initialize a dictionary to represent clusters
    C = {}
    for t in range(tmax):
        # determine clusters, i. e. arrays of data indices
        J = np.argmin(D[:,M], axis=1)
        for kappa in range(k):
            C[kappa] = np.where(J==kappa)[0]
        # update cluster medoids
        for kappa in range(k):
            J = np.mean(D[np.ix_(C[kappa],C[kappa])],axis=1)
            j = np.argmin(J)
            Mnew[kappa] = C[kappa][j]
        np.sort(Mnew)
        # check for convergence
        if np.array_equal(M, Mnew):
            break
        M = np.copy(Mnew)
    else:
        # final update of cluster memberships
        J = np.argmin(D[:,M], axis=1)
        for kappa in range(k):
            C[kappa] = np.where(J==kappa)[0]

    # return results
    return M, C

# %%
HotelUnclustered_100_indices=np.random.choice(len(HotelUnclustered), 100,replace=False)

# %%
selected_reviews=HotelUnclustered.loc[HotelUnclustered_100_indices,:]

# %%
selected_reviews
# Out:
#               Reviewer_Nationality  Review_Total_Negative_Word_Counts  \
# 409509                  Australia                                  21
# 230837             United Kingdom                                   3
# 118151                     Poland                                   0
# 497564                Switzerland                                  38
# 134571   United States of America                                  71
# 187559             United Kingdom                                  13
# 33594    United States of America                                   0
# 141407             United Kingdom                                  16
# 420529   United States of America                                  57
# 130824             United Kingdom                                  29
# 80843                     Germany                                   0
# 260290             United Kingdom                                   9
# 156977             United Kingdom                                   3
# 508495                  Sri Lanka                                  26
# 436175             United Kingdom                                  42
# 447069                     Israel                                  21
# 476657               Saudi Arabia                                  58
# 74650              United Kingdom                                  35
# 141699   United States of America                                   0
# 190264               Saudi Arabia                                  12
# 327536   United States of America                                  16
# 248627                     Canada                                  19
# 144769             Cayman Islands                                   9
# 411056             United Kingdom                                   2
# 209650             United Kingdom                                  62
# 314296                     Brazil                                  38
# 331949                Netherlands                                   0
# 206727             United Kingdom                                   0
# 285481                     Latvia                                   5
# 374539             United Kingdom                                  20
# ...                            ...                                ...
# 367123               Saudi Arabia                                   5
# 61267              United Kingdom                                   0
# 247208             United Kingdom                                   3
# 48628    United States of America                                  18
# 261893                  Australia                                  11
# 77514    United States of America                                   7
# 144808             United Kingdom                                   3
# 248033             United Kingdom                                   8
# 296417   United States of America                                   3
# 212311                    Belgium                                   5
# 96016                      Kuwait                                   0
# 415469             United Kingdom                                  49
# 184451                      Italy                                   0
# 363815             United Kingdom                                  29
# 85525                     Finland                                  19
# 287262             United Kingdom                                  66
# 124150             United Kingdom                                  40
# 125584                      Spain                                  15
# 457511               Saudi Arabia                                  27
# 428954       United Arab Emirates                                  18
# 80190        United Arab Emirates                                  21
# 227156             United Kingdom                                  55
# 285426                      Italy                                   4
# 36458              United Kingdom                                  32
# 291570             United Kingdom                                  84
# 142819             United Kingdom                                  11
# 268837                    Germany                                   0
# 38940                      Canada                                   3
# 83909              United Kingdom                                  39
# 431324                Netherlands                                   4
#
#         Total_Number_of_Reviews  Review_Total_Positive_Word_Counts  \
# 409509                     3510                                 10
# 230837                     2665                                 32
# 118151                     4426                                  6
# 497564                     4231                                  0
# 134571                     1193                                  2
# 187559                     2147                                  8
# 33594                       615                                 30
# 141407                     6596                                 65
# 420529                      909                                 14
# 130824                     2751                                 19
# 80843                      1295                                  9
# 260290                      346                                  4
# 156977                     4065                                 12
# 508495                      255                                 53
# 436175                     2768                                 12
# 447069                     5177                                  4
# 476657                      740                                 22
# 74650                      4684                                  3
# 141699                     6596                                113
# 190264                      561                                  4
# 327536                     1589                                  4
# 248627                     2494                                 40
# 144769                     2516                                 24
# 411056                     1925                                  4
# 209650                     2541                                 15
# 314296                     1594                                  7
# 331949                     1266                                 29
# 206727                      525                                 29
# 285481                     4153                                  8
# 374539                      931                                  4
# ...                         ...                                ...
# 367123                     3754                                  8
# 61267                       812                                  7
# 247208                      311                                  5
# 48628                      1519                                  8
# 261893                     1774                                 13
# 77514                      1294                                  9
# 144808                     2516                                 28
# 248033                     1592                                  7
# 296417                     2474                                  0
# 212311                      858                                 12
# 96016                       635                                 35
# 415469                     4527                                 16
# 184451                     5394                                  4
# 363815                     2562                                 42
# 85525                      2319                                141
# 287262                     1593                                 89
# 124150                     1164                                 27
# 125584                     3826                                 21
# 457511                      492                                 15
# 428954                     3010                                 14
# 80190                      1573                                  6
# 227156                     2037                                 73
# 285426                     4153                                 10
# 36458                      1047                                 21
# 291570                      824                                 39
# 142819                     6596                                  4
# 268837                     3078                                  4
# 38940                      2418                                  4
# 83909                      1016                                 16
# 431324                      974                                  9
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score        lat  \
# 409509                                          14             9.6  45.484514
# 230837                                           6             9.2  51.495369
# 118151                                          20             9.6  51.494254
# 497564                                           1             4.2  52.366373
# 134571                                           1             5.4  48.852836
# 187559                                           3             7.5  51.531979
# 33594                                            2             9.2  48.842756
# 141407                                           3            10.0  51.512974
# 420529                                           3             9.6  52.372835
# 130824                                           1             7.5  51.520795
# 80843                                           14             9.2  51.514438
# 260290                                           1             7.9  48.849758
# 156977                                           1            10.0  51.516288
# 508495                                           2             8.3  52.359478
# 436175                                          10             7.1  51.508354
# 447069                                          66             6.3  48.214662
# 476657                                          37             7.5  45.485189
# 74650                                            7            10.0  51.491374
# 141699                                           2             9.6  51.512974
# 190264                                           4             5.8  51.420266
# 327536                                           1            10.0  41.399177
# 248627                                           1             8.3  51.506935
# 144769                                          16             8.8  51.498123
# 411056                                          13             9.6  52.378102
# 209650                                           1             6.7  48.830302
# 314296                                           2             5.4  41.388801
# 331949                                           1             9.2  41.391626
# 206727                                           4             9.2  51.457299
# 285481                                           1             7.5  41.386529
# 374539                                           1             8.8  41.391062
# ...                                            ...             ...        ...
# 367123                                           4             7.5  45.463068
# 61267                                            1            10.0  51.493475
# 247208                                           3             8.3  51.505219
# 48628                                            1             8.8  51.513207
# 261893                                           1             8.8  51.520106
# 77514                                            1             9.2  51.529257
# 144808                                           2            10.0  51.498123
# 248033                                          11            10.0  51.506935
# 296417                                           1             5.8  51.529142
# 212311                                          10            10.0  48.868947
# 96016                                           10            10.0  51.497320
# 415469                                           1             5.8  41.375029
# 184451                                          49             9.6  51.498673
# 363815                                          17             8.3  51.511945
# 85525                                            1             9.2  51.505696
# 287262                                           1             9.2  51.517966
# 124150                                           7             9.6  51.513460
# 125584                                          17            10.0  51.504348
# 457511                                           2             7.5  51.505909
# 428954                                          18             9.2  48.185431
# 80190                                            1             7.5  51.490749
# 227156                                           4             9.2  51.563476
# 285426                                           5             9.6  41.386529
# 36458                                            1             7.5  51.494847
# 291570                                          23             8.3  48.204576
# 142819                                           4             7.9  51.512974
# 268837                                           3             7.9  48.206227
# 38940                                            1             7.5  51.511993
# 83909                                            2             7.1  51.495010
# 431324                                          17             6.7  52.361758
#
#               lng
# 409509   9.205753
# 230837  -0.181897
# 118151  -0.141476
# 497564   4.893050
# 134571   2.344080
# 187559  -0.061598
# 33594    2.330564
# 141407  -0.183743
# 420529   4.883326
# 130824  -0.131084
# 80843   -0.155834
# 260290   2.309521
# 156977  -0.172108
# 508495   4.895853
# 436175   0.019886
# 447069  16.362799
# 476657   9.198015
# 74650   -0.121419
# 141699  -0.183743
# 190264  -0.211268
# 327536   2.165613
# 248627  -0.126012
# 144769  -0.179969
# 411056   4.914251
# 209650   2.284287
# 314296   2.165374
# 331949   2.171638
# 206727  -0.205543
# 285481   2.168292
# 374539   2.159337
# ...           ...
# 367123   9.197937
# 61267   -0.215326
# 247208  -0.088166
# 48628   -0.180782
# 261893  -0.122139
# 77514   -0.168358
# 144808  -0.179969
# 248033  -0.126012
# 296417  -0.137278
# 212311   2.302656
# 96016   -0.156256
# 415469   2.149117
# 184451  -0.137687
# 363815  -0.179939
# 85525   -0.101525
# 287262  -0.123434
# 124150  -0.183308
# 125584  -0.033444
# 457511  -0.140380
# 428954  16.404884
# 80190   -0.193463
# 227156  -0.204276
# 285426   2.168292
# 36458   -0.118748
# 291570  16.356366
# 142819  -0.183743
# 268837  16.383377
# 38940   -0.178279
# 83909   -0.190619
# 431324   4.878005
#
# [100 rows x 8 columns]

# %%
D = gower_distances(selected_reviews)
print(D)
# Out:
# [[ 0.          0.34725221  0.32407954 ...,  0.3833225   0.41171445
#    0.36952229]
#  [ 0.34725221  0.          0.2157494  ...,  0.20013174  0.14641063
#    0.29605951]
#  [ 0.32407954  0.2157494   0.         ...,  0.2447275   0.33378307
#    0.30311365]
#  ...,
#  [ 0.3833225   0.20013174  0.2447275  ...,  0.          0.22183371
#    0.24902378]
#  [ 0.41171445  0.14641063  0.33378307 ...,  0.22183371  0.          0.26933941]
#  [ 0.36952229  0.29605951  0.30311365 ...,  0.24902378  0.26933941  0.        ]]

# %%
M, C = kMedoids(D, 2)
selected_reviews.iloc[89,:]
for point_idx in M:
    print( selected_reviews.iloc[point_idx,:] )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-b5e72d664692> in <module>()
#       2 selected_reviews.iloc[89,:]
#       3 for point_idx in M:
# ----> 4     print( selected_reviews.iloc[point_idx,'Name'] )
#       5
#       6 print('')
#
# C:\Users\Anant\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1292
#    1293         if type(key) is tuple:
# -> 1294             return self._getitem_tuple(key)
#    1295         else:
#    1296             return self._getitem_axis(key, axis=0)
#
# C:\Users\Anant\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1542     def _getitem_tuple(self, tup):
#    1543
# -> 1544         self._has_valid_tuple(tup)
#    1545         try:
#    1546             return self._getitem_lowerdim(tup)
#
# C:\Users\Anant\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     142             if not self._has_valid_type(k, i):
#     143                 raise ValueError("Location based indexing can only have [%s] "
# --> 144                                  "types" % self._valid_types)
#     145
#     146     def _should_validate_iterable(self, axis=0):
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
print('')
print('clustering result:')
for label in C:
    for point_idx in C[label]:
        print('label {0}:　{1}'.format(label, selected_reviews.iloc[point_idx,:]))
# Out:
# clustering result:
# label 0:　Reviewer_Nationality                           Poland
# Review_Total_Negative_Word_Counts                    0
# Total_Number_of_Reviews                           4426
# Review_Total_Positive_Word_Counts                    6
# Total_Number_of_Reviews_Reviewer_Has_Given          20
# Reviewer_Score                                     9.6
# lat                                            51.4943
# lng                                          -0.141476
# Name: 118151, dtype: object
# label 0:　Reviewer_Nationality                           Switzerland
# Review_Total_Negative_Word_Counts                        38
# Total_Number_of_Reviews                                4231
# Review_Total_Positive_Word_Counts                         0
# Total_Number_of_Reviews_Reviewer_Has_Given                1
# Reviewer_Score                                          4.2
# lat                                                 52.3664
# lng                                                 4.89305
# Name: 497564, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                     71
# Total_Number_of_Reviews                                             1193
# Review_Total_Positive_Word_Counts                                      2
# Total_Number_of_Reviews_Reviewer_Has_Given                             1
# Reviewer_Score                                                       5.4
# lat                                                              48.8528
# lng                                                              2.34408
# Name: 134571, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                      0
# Total_Number_of_Reviews                                              615
# Review_Total_Positive_Word_Counts                                     30
# Total_Number_of_Reviews_Reviewer_Has_Given                             2
# Reviewer_Score                                                       9.2
# lat                                                              48.8428
# lng                                                              2.33056
# Name: 33594, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                     57
# Total_Number_of_Reviews                                              909
# Review_Total_Positive_Word_Counts                                     14
# Total_Number_of_Reviews_Reviewer_Has_Given                             3
# Reviewer_Score                                                       9.6
# lat                                                              52.3728
# lng                                                              4.88333
# Name: 420529, dtype: object
# label 0:　Reviewer_Nationality                           Germany
# Review_Total_Negative_Word_Counts                     0
# Total_Number_of_Reviews                            1295
# Review_Total_Positive_Word_Counts                     9
# Total_Number_of_Reviews_Reviewer_Has_Given           14
# Reviewer_Score                                      9.2
# lat                                             51.5144
# lng                                           -0.155834
# Name: 80843, dtype: object
# label 0:　Reviewer_Nationality                           Israel
# Review_Total_Negative_Word_Counts                   21
# Total_Number_of_Reviews                           5177
# Review_Total_Positive_Word_Counts                    4
# Total_Number_of_Reviews_Reviewer_Has_Given          66
# Reviewer_Score                                     6.3
# lat                                            48.2147
# lng                                            16.3628
# Name: 447069, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                      0
# Total_Number_of_Reviews                                             6596
# Review_Total_Positive_Word_Counts                                    113
# Total_Number_of_Reviews_Reviewer_Has_Given                             2
# Reviewer_Score                                                       9.6
# lat                                                               51.513
# lng                                                            -0.183743
# Name: 141699, dtype: object
# label 0:　Reviewer_Nationality                           Saudi Arabia
# Review_Total_Negative_Word_Counts                         12
# Total_Number_of_Reviews                                  561
# Review_Total_Positive_Word_Counts                          4
# Total_Number_of_Reviews_Reviewer_Has_Given                 4
# Reviewer_Score                                           5.8
# lat                                                  51.4203
# lng                                                -0.211268
# Name: 190264, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                     16
# Total_Number_of_Reviews                                             1589
# Review_Total_Positive_Word_Counts                                      4
# Total_Number_of_Reviews_Reviewer_Has_Given                             1
# Reviewer_Score                                                        10
# lat                                                              41.3992
# lng                                                              2.16561
# Name: 327536, dtype: object
# label 0:　Reviewer_Nationality                           Canada
# Review_Total_Negative_Word_Counts                   19
# Total_Number_of_Reviews                           2494
# Review_Total_Positive_Word_Counts                   40
# Total_Number_of_Reviews_Reviewer_Has_Given           1
# Reviewer_Score                                     8.3
# lat                                            51.5069
# lng                                          -0.126012
# Name: 248627, dtype: object
# label 0:　Reviewer_Nationality                           Cayman Islands
# Review_Total_Negative_Word_Counts                            9
# Total_Number_of_Reviews                                   2516
# Review_Total_Positive_Word_Counts                           24
# Total_Number_of_Reviews_Reviewer_Has_Given                  16
# Reviewer_Score                                             8.8
# lat                                                    51.4981
# lng                                                  -0.179969
# Name: 144769, dtype: object
# label 0:　Reviewer_Nationality                           Netherlands
# Review_Total_Negative_Word_Counts                         0
# Total_Number_of_Reviews                                1266
# Review_Total_Positive_Word_Counts                        29
# Total_Number_of_Reviews_Reviewer_Has_Given                1
# Reviewer_Score                                          9.2
# lat                                                 41.3916
# lng                                                 2.17164
# Name: 331949, dtype: object
# label 0:　Reviewer_Nationality                           Latvia
# Review_Total_Negative_Word_Counts                    5
# Total_Number_of_Reviews                           4153
# Review_Total_Positive_Word_Counts                    8
# Total_Number_of_Reviews_Reviewer_Has_Given           1
# Reviewer_Score                                     7.5
# lat                                            41.3865
# lng                                            2.16829
# Name: 285481, dtype: object
# label 0:　Reviewer_Nationality                           Greece
# Review_Total_Negative_Word_Counts                   12
# Total_Number_of_Reviews                           4426
# Review_Total_Positive_Word_Counts                   24
# Total_Number_of_Reviews_Reviewer_Has_Given           2
# Reviewer_Score                                     9.6
# lat                                            51.4943
# lng                                          -0.141476
# Name: 117824, dtype: object
# label 0:　Reviewer_Nationality                           Germany
# Review_Total_Negative_Word_Counts                    16
# Total_Number_of_Reviews                            4568
# Review_Total_Positive_Word_Counts                    10
# Total_Number_of_Reviews_Reviewer_Has_Given            1
# Reviewer_Score                                      8.3
# lat                                             45.4769
# lng                                             9.19666
# Name: 492159, dtype: object
# label 0:　Reviewer_Nationality                           Italy
# Review_Total_Negative_Word_Counts                   0
# Total_Number_of_Reviews                          8177
# Review_Total_Positive_Word_Counts                  14
# Total_Number_of_Reviews_Reviewer_Has_Given          4
# Reviewer_Score                                    8.8
# lat                                           52.3511
# lng                                           4.84116
# Name: 312276, dtype: object
# label 0:　Reviewer_Nationality                           Belgium
# Review_Total_Negative_Word_Counts                     3
# Total_Number_of_Reviews                            2336
# Review_Total_Positive_Word_Counts                    12
# Total_Number_of_Reviews_Reviewer_Has_Given            3
# Reviewer_Score                                       10
# lat                                             41.3791
# lng                                             2.15612
# Name: 292785, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                     68
# Total_Number_of_Reviews                                              619
# Review_Total_Positive_Word_Counts                                     13
# Total_Number_of_Reviews_Reviewer_Has_Given                             2
# Reviewer_Score                                                       7.5
# lat                                                              48.8608
# lng                                                              2.34276
# Name: 194382, dtype: object
# label 0:　Reviewer_Nationality                           Netherlands
# Review_Total_Negative_Word_Counts                         0
# Total_Number_of_Reviews                                1532
# Review_Total_Positive_Word_Counts                        28
# Total_Number_of_Reviews_Reviewer_Has_Given                6
# Reviewer_Score                                          8.8
# lat                                                  51.506
# lng                                               -0.151078
# Name: 197441, dtype: object
# label 0:　Reviewer_Nationality                           Philippines
# Review_Total_Negative_Word_Counts                         0
# Total_Number_of_Reviews                                1694
# Review_Total_Positive_Word_Counts                         5
# Total_Number_of_Reviews_Reviewer_Has_Given                2
# Reviewer_Score                                          9.2
# lat                                                 51.5082
# lng                                               -0.126196
# Name: 466242, dtype: object
# label 0:　Reviewer_Nationality                           Sweden
# Review_Total_Negative_Word_Counts                    8
# Total_Number_of_Reviews                            618
# Review_Total_Positive_Word_Counts                   15
# Total_Number_of_Reviews_Reviewer_Has_Given          36
# Reviewer_Score                                     7.5
# lat                                             51.512
# lng                                          -0.176241
# Name: 364696, dtype: object
# label 0:　Reviewer_Nationality                           Czech Republic
# Review_Total_Negative_Word_Counts                           10
# Total_Number_of_Reviews                                   3557
# Review_Total_Positive_Word_Counts                            8
# Total_Number_of_Reviews_Reviewer_Has_Given                   2
# Reviewer_Score                                             5.8
# lat                                                    48.2319
# lng                                                    16.4129
# Name: 315321, dtype: object
# label 0:　Reviewer_Nationality                           Ireland
# Review_Total_Negative_Word_Counts                     5
# Total_Number_of_Reviews                            3754
# Review_Total_Positive_Word_Counts                    10
# Total_Number_of_Reviews_Reviewer_Has_Given           44
# Reviewer_Score                                      9.6
# lat                                             45.4631
# lng                                             9.19794
# Name: 367338, dtype: object
# label 0:　Reviewer_Nationality                           Netherlands
# Review_Total_Negative_Word_Counts                         0
# Total_Number_of_Reviews                                1145
# Review_Total_Positive_Word_Counts                         9
# Total_Number_of_Reviews_Reviewer_Has_Given                7
# Reviewer_Score                                           10
# lat                                                 48.8483
# lng                                                 2.34256
# Name: 12522, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                      0
# Total_Number_of_Reviews                                             2494
# Review_Total_Positive_Word_Counts                                      3
# Total_Number_of_Reviews_Reviewer_Has_Given                            12
# Reviewer_Score                                                       9.6
# lat                                                              51.5069
# lng                                                            -0.126012
# Name: 249168, dtype: object
# label 0:　Reviewer_Nationality                           United Arab Emirates
# Review_Total_Negative_Word_Counts                                 23
# Total_Number_of_Reviews                                         7371
# Review_Total_Positive_Word_Counts                                 20
# Total_Number_of_Reviews_Reviewer_Has_Given                         1
# Reviewer_Score                                                   8.8
# lat                                                          45.4839
# lng                                                          9.20341
# Name: 404846, dtype: object
# label 0:　Reviewer_Nationality                           Qatar
# Review_Total_Negative_Word_Counts                   7
# Total_Number_of_Reviews                          1120
# Review_Total_Positive_Word_Counts                   4
# Total_Number_of_Reviews_Reviewer_Has_Given          2
# Reviewer_Score                                    5.4
# lat                                            48.864
# lng                                           2.33526
# Name: 414041, dtype: object
# label 0:　Reviewer_Nationality                            France
# Review_Total_Negative_Word_Counts                     8
# Total_Number_of_Reviews                            2543
# Review_Total_Positive_Word_Counts                     2
# Total_Number_of_Reviews_Reviewer_Has_Given           10
# Reviewer_Score                                      7.9
# lat                                             51.5122
# lng                                          -0.0757326
# Name: 44740, dtype: object
# label 0:　Reviewer_Nationality                           Spain
# Review_Total_Negative_Word_Counts                   0
# Total_Number_of_Reviews                          2336
# Review_Total_Positive_Word_Counts                  51
# Total_Number_of_Reviews_Reviewer_Has_Given          1
# Reviewer_Score                                    9.2
# lat                                           41.3791
# lng                                           2.15612
# Name: 292666, dtype: object
# label 0:　Reviewer_Nationality                           New Zealand
# Review_Total_Negative_Word_Counts                         0
# Total_Number_of_Reviews                                2045
# Review_Total_Positive_Word_Counts                        13
# Total_Number_of_Reviews_Reviewer_Has_Given                2
# Reviewer_Score                                          9.6
# lat                                                 41.3834
# lng                                                  2.1794
# Name: 478608, dtype: object
# label 0:　Reviewer_Nationality                           France
# Review_Total_Negative_Word_Counts                    8
# Total_Number_of_Reviews                           3598
# Review_Total_Positive_Word_Counts                    0
# Total_Number_of_Reviews_Reviewer_Has_Given           1
# Reviewer_Score                                     7.1
# lat                                            48.1953
# lng                                            16.3673
# Name: 511908, dtype: object
# label 0:　Reviewer_Nationality                           Kuwait
# Review_Total_Negative_Word_Counts                   10
# Total_Number_of_Reviews                           3117
# Review_Total_Positive_Word_Counts                   15
# Total_Number_of_Reviews_Reviewer_Has_Given           1
# Reviewer_Score                                     8.3
# lat                                            51.5106
# lng                                          -0.150995
# Name: 190977, dtype: object
# label 0:　Reviewer_Nationality                           Sweden
# Review_Total_Negative_Word_Counts                   24
# Total_Number_of_Reviews                           1884
# Review_Total_Positive_Word_Counts                   20
# Total_Number_of_Reviews_Reviewer_Has_Given           1
# Reviewer_Score                                     7.1
# lat                                            51.4948
# lng                                          -0.177206
# Name: 232844, dtype: object
# label 0:　Reviewer_Nationality                           China
# Review_Total_Negative_Word_Counts                   0
# Total_Number_of_Reviews                          3078
# Review_Total_Positive_Word_Counts                   9
# Total_Number_of_Reviews_Reviewer_Has_Given          6
# Reviewer_Score                                    7.9
# lat                                           48.2062
# lng                                           16.3834
# Name: 268865, dtype: object
# label 0:　Reviewer_Nationality                           Austria
# Review_Total_Negative_Word_Counts                     0
# Total_Number_of_Reviews                            1543
# Review_Total_Positive_Word_Counts                    59
# Total_Number_of_Reviews_Reviewer_Has_Given            1
# Reviewer_Score                                      9.2
# lat                                             45.4799
# lng                                              9.1963
# Name: 404302, dtype: object
# label 0:　Reviewer_Nationality                           Switzerland
# Review_Total_Negative_Word_Counts                        10
# Total_Number_of_Reviews                                2341
# Review_Total_Positive_Word_Counts                        22
# Total_Number_of_Reviews_Reviewer_Has_Given               18
# Reviewer_Score                                          8.3
# lat                                                 48.2341
# lng                                                  16.421
# Name: 500580, dtype: object
# label 0:　Reviewer_Nationality                           Saudi Arabia
# Review_Total_Negative_Word_Counts                          0
# Total_Number_of_Reviews                                 3944
# Review_Total_Positive_Word_Counts                         23
# Total_Number_of_Reviews_Reviewer_Has_Given                 3
# Reviewer_Score                                           9.2
# lat                                                  41.3989
# lng                                                  2.20242
# Name: 425826, dtype: object
# label 0:　Reviewer_Nationality                           United Arab Emirates
# Review_Total_Negative_Word_Counts                                 11
# Total_Number_of_Reviews                                         5742
# Review_Total_Positive_Word_Counts                                  0
# Total_Number_of_Reviews_Reviewer_Has_Given                         3
# Reviewer_Score                                                     5
# lat                                                          45.4721
# lng                                                          9.07779
# Name: 476186, dtype: object
# label 0:　Reviewer_Nationality                           Saudi Arabia
# Review_Total_Negative_Word_Counts                          5
# Total_Number_of_Reviews                                 3754
# Review_Total_Positive_Word_Counts                          8
# Total_Number_of_Reviews_Reviewer_Has_Given                 4
# Reviewer_Score                                           7.5
# lat                                                  45.4631
# lng                                                  9.19794
# Name: 367123, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                     18
# Total_Number_of_Reviews                                             1519
# Review_Total_Positive_Word_Counts                                      8
# Total_Number_of_Reviews_Reviewer_Has_Given                             1
# Reviewer_Score                                                       8.8
# lat                                                              51.5132
# lng                                                            -0.180782
# Name: 48628, dtype: object
# label 0:　Reviewer_Nationality                           Australia
# Review_Total_Negative_Word_Counts                      11
# Total_Number_of_Reviews                              1774
# Review_Total_Positive_Word_Counts                      13
# Total_Number_of_Reviews_Reviewer_Has_Given              1
# Reviewer_Score                                        8.8
# lat                                               51.5201
# lng                                             -0.122139
# Name: 261893, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                      7
# Total_Number_of_Reviews                                             1294
# Review_Total_Positive_Word_Counts                                      9
# Total_Number_of_Reviews_Reviewer_Has_Given                             1
# Reviewer_Score                                                       9.2
# lat                                                              51.5293
# lng                                                            -0.168358
# Name: 77514, dtype: object
# label 0:　Reviewer_Nationality                           United States of America
# Review_Total_Negative_Word_Counts                                      3
# Total_Number_of_Reviews                                             2474
# Review_Total_Positive_Word_Counts                                      0
# Total_Number_of_Reviews_Reviewer_Has_Given                             1
# Reviewer_Score                                                       5.8
# lat                                                              51.5291
# lng                                                            -0.137278
# Name: 296417, dtype: object
# label 0:　Reviewer_Nationality                            Italy
# Review_Total_Negative_Word_Counts                    0
# Total_Number_of_Reviews                           5394
# Review_Total_Positive_Word_Counts                    4
# Total_Number_of_Reviews_Reviewer_Has_Given          49
# Reviewer_Score                                     9.6
# lat                                            51.4987
# lng                                          -0.137687
# Name: 184451, dtype: object
# label 0:　Reviewer_Nationality                           Finland
# Review_Total_Negative_Word_Counts                    19
# Total_Number_of_Reviews                            2319
# Review_Total_Positive_Word_Counts                   141
# Total_Number_of_Reviews_Reviewer_Has_Given            1
# Reviewer_Score                                      9.2
# lat                                             51.5057
# lng                                           -0.101525
# Name: 85525, dtype: object
# label 0:　Reviewer_Nationality                           United Arab Emirates
# Review_Total_Negative_Word_Counts                                 18
# Total_Number_of_Reviews                                         3010
# Review_Total_Positive_Word_Counts                                 14
# Total_Number_of_Reviews_Reviewer_Has_Given                        18
# Reviewer_Score                                                   9.2
# lat                                                          48.1854
# lng                                                          16.4049
# Name: 428954, dtype: object
# label 0:　Reviewer_Nationality                           United Arab Emirates
# Review_Total_Negative_Word_Counts                                 21
# Total_Number_of_Reviews                                         1573
# Review_Total_Positive_Word_Counts                                  6
# Total_Number_of_Reviews_Reviewer_Has_Given                         1
# Reviewer_Score                                                   7.5
# lat                                                          51.4907
# lng                                                        -0.193463
# Name: 80190, dtype: object
# label 0:　Reviewer_Nationality                           Italy
# Review_Total_Negative_Word_Counts                   4
# Total_Number_of_Reviews                          4153
# Review_Total_Positive_Word_Counts                  10
# Total_Number_of_Reviews_Reviewer_Has_Given          5
# Reviewer_Score                                    9.6
# lat                                           41.3865
# lng                                           2.16829
# Name: 285426, dtype: object
# label 0:　Reviewer_Nationality                           Germany
# Review_Total_Negative_Word_Counts                     0
# Total_Number_of_Reviews                            3078
# Review_Total_Positive_Word_Counts                     4
# Total_Number_of_Reviews_Reviewer_Has_Given            3
# Reviewer_Score                                      7.9
# lat                                             48.2062
# lng                                             16.3834
# Name: 268837, dtype: object
# label 0:　Reviewer_Nationality                           Canada
# Review_Total_Negative_Word_Counts                    3
# Total_Number_of_Reviews                           2418
# Review_Total_Positive_Word_Counts                    4
# Total_Number_of_Reviews_Reviewer_Has_Given           1
# Reviewer_Score                                     7.5
# lat                                             51.512
# lng                                          -0.178279
# Name: 38940, dtype: object
# label 0:　Reviewer_Nationality                           Netherlands
# Review_Total_Negative_Word_Counts                         4
# Total_Number_of_Reviews                                 974
# Review_Total_Positive_Word_Counts                         9
# Total_Number_of_Reviews_Reviewer_Has_Given               17
# Reviewer_Score                                          6.7
# lat                                                 52.3618
# lng                                                 4.87801
# Name: 431324, dtype: object
# label 1:　Reviewer_Nationality                           Australia
# Review_Total_Negative_Word_Counts                      21
# Total_Number_of_Reviews                              3510
# Review_Total_Positive_Word_Counts                      10
# Total_Number_of_Reviews_Reviewer_Has_Given             14
# Reviewer_Score                                        9.6
# lat                                               45.4845
# lng                                               9.20575
# Name: 409509, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            3
# Total_Number_of_Reviews                                   2665
# Review_Total_Positive_Word_Counts                           32
# Total_Number_of_Reviews_Reviewer_Has_Given                   6
# Reviewer_Score                                             9.2
# lat                                                    51.4954
# lng                                                  -0.181897
# Name: 230837, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           13
# Total_Number_of_Reviews                                   2147
# Review_Total_Positive_Word_Counts                            8
# Total_Number_of_Reviews_Reviewer_Has_Given                   3
# Reviewer_Score                                             7.5
# lat                                                     51.532
# lng                                                  -0.061598
# Name: 187559, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           16
# Total_Number_of_Reviews                                   6596
# Review_Total_Positive_Word_Counts                           65
# Total_Number_of_Reviews_Reviewer_Has_Given                   3
# Reviewer_Score                                              10
# lat                                                     51.513
# lng                                                  -0.183743
# Name: 141407, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           29
# Total_Number_of_Reviews                                   2751
# Review_Total_Positive_Word_Counts                           19
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             7.5
# lat                                                    51.5208
# lng                                                  -0.131084
# Name: 130824, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            9
# Total_Number_of_Reviews                                    346
# Review_Total_Positive_Word_Counts                            4
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             7.9
# lat                                                    48.8498
# lng                                                    2.30952
# Name: 260290, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            3
# Total_Number_of_Reviews                                   4065
# Review_Total_Positive_Word_Counts                           12
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                              10
# lat                                                    51.5163
# lng                                                  -0.172108
# Name: 156977, dtype: object
# label 1:　Reviewer_Nationality                           Sri Lanka
# Review_Total_Negative_Word_Counts                      26
# Total_Number_of_Reviews                               255
# Review_Total_Positive_Word_Counts                      53
# Total_Number_of_Reviews_Reviewer_Has_Given              2
# Reviewer_Score                                        8.3
# lat                                               52.3595
# lng                                               4.89585
# Name: 508495, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           42
# Total_Number_of_Reviews                                   2768
# Review_Total_Positive_Word_Counts                           12
# Total_Number_of_Reviews_Reviewer_Has_Given                  10
# Reviewer_Score                                             7.1
# lat                                                    51.5084
# lng                                                  0.0198855
# Name: 436175, dtype: object
# label 1:　Reviewer_Nationality                           Saudi Arabia
# Review_Total_Negative_Word_Counts                         58
# Total_Number_of_Reviews                                  740
# Review_Total_Positive_Word_Counts                         22
# Total_Number_of_Reviews_Reviewer_Has_Given                37
# Reviewer_Score                                           7.5
# lat                                                  45.4852
# lng                                                  9.19801
# Name: 476657, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           35
# Total_Number_of_Reviews                                   4684
# Review_Total_Positive_Word_Counts                            3
# Total_Number_of_Reviews_Reviewer_Has_Given                   7
# Reviewer_Score                                              10
# lat                                                    51.4914
# lng                                                  -0.121419
# Name: 74650, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            2
# Total_Number_of_Reviews                                   1925
# Review_Total_Positive_Word_Counts                            4
# Total_Number_of_Reviews_Reviewer_Has_Given                  13
# Reviewer_Score                                             9.6
# lat                                                    52.3781
# lng                                                    4.91425
# Name: 411056, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           62
# Total_Number_of_Reviews                                   2541
# Review_Total_Positive_Word_Counts                           15
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             6.7
# lat                                                    48.8303
# lng                                                    2.28429
# Name: 209650, dtype: object
# label 1:　Reviewer_Nationality                           Brazil
# Review_Total_Negative_Word_Counts                   38
# Total_Number_of_Reviews                           1594
# Review_Total_Positive_Word_Counts                    7
# Total_Number_of_Reviews_Reviewer_Has_Given           2
# Reviewer_Score                                     5.4
# lat                                            41.3888
# lng                                            2.16537
# Name: 314296, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            0
# Total_Number_of_Reviews                                    525
# Review_Total_Positive_Word_Counts                           29
# Total_Number_of_Reviews_Reviewer_Has_Given                   4
# Reviewer_Score                                             9.2
# lat                                                    51.4573
# lng                                                  -0.205543
# Name: 206727, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           20
# Total_Number_of_Reviews                                    931
# Review_Total_Positive_Word_Counts                            4
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             8.8
# lat                                                    41.3911
# lng                                                    2.15934
# Name: 374539, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           12
# Total_Number_of_Reviews                                   2359
# Review_Total_Positive_Word_Counts                           22
# Total_Number_of_Reviews_Reviewer_Has_Given                   5
# Reviewer_Score                                              10
# lat                                                    41.4047
# lng                                                    2.17271
# Name: 435118, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            4
# Total_Number_of_Reviews                                   3583
# Review_Total_Positive_Word_Counts                            6
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             9.2
# lat                                                    48.8454
# lng                                                     2.3753
# Name: 90742, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           23
# Total_Number_of_Reviews                                    812
# Review_Total_Positive_Word_Counts                            9
# Total_Number_of_Reviews_Reviewer_Has_Given                   2
# Reviewer_Score                                              10
# lat                                                    51.4935
# lng                                                  -0.215326
# Name: 61186, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            0
# Total_Number_of_Reviews                                   4802
# Review_Total_Positive_Word_Counts                            8
# Total_Number_of_Reviews_Reviewer_Has_Given                   2
# Reviewer_Score                                              10
# lat                                                    51.5278
# lng                                                 -0.0889473
# Name: 58973, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            0
# Total_Number_of_Reviews                                    136
# Review_Total_Positive_Word_Counts                           43
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                              10
# lat                                                    51.5033
# lng                                                  -0.078179
# Name: 78928, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           25
# Total_Number_of_Reviews                                    830
# Review_Total_Positive_Word_Counts                           52
# Total_Number_of_Reviews_Reviewer_Has_Given                   2
# Reviewer_Score                                             9.2
# lat                                                    51.5161
# lng                                                 -0.0624458
# Name: 194534, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            0
# Total_Number_of_Reviews                                   1786
# Review_Total_Positive_Word_Counts                           14
# Total_Number_of_Reviews_Reviewer_Has_Given                  10
# Reviewer_Score                                             9.6
# lat                                                    51.4967
# lng                                                  -0.206472
# Name: 169672, dtype: object
# label 1:　Reviewer_Nationality                           Belgium
# Review_Total_Negative_Word_Counts                    37
# Total_Number_of_Reviews                            3221
# Review_Total_Positive_Word_Counts                     0
# Total_Number_of_Reviews_Reviewer_Has_Given            9
# Reviewer_Score                                      9.5
# lat                                             48.2062
# lng                                              16.371
# Name: 354076, dtype: object
# label 1:　Reviewer_Nationality                           Hungary
# Review_Total_Negative_Word_Counts                    31
# Total_Number_of_Reviews                            1785
# Review_Total_Positive_Word_Counts                    33
# Total_Number_of_Reviews_Reviewer_Has_Given           23
# Reviewer_Score                                      8.8
# lat                                             45.5148
# lng                                             9.11661
# Name: 493039, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           24
# Total_Number_of_Reviews                                   1039
# Review_Total_Positive_Word_Counts                           84
# Total_Number_of_Reviews_Reviewer_Has_Given                   8
# Reviewer_Score                                              10
# lat                                                    51.5077
# lng                                                  -0.137873
# Name: 253804, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            2
# Total_Number_of_Reviews                                   1592
# Review_Total_Positive_Word_Counts                            7
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                              10
# lat                                                    51.5218
# lng                                                 -0.0856081
# Name: 107633, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            0
# Total_Number_of_Reviews                                   1271
# Review_Total_Positive_Word_Counts                            7
# Total_Number_of_Reviews_Reviewer_Has_Given                  12
# Reviewer_Score                                             8.8
# lat                                                    51.5139
# lng                                                  -0.121989
# Name: 175589, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            0
# Total_Number_of_Reviews                                   2298
# Review_Total_Positive_Word_Counts                            8
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             9.6
# lat                                                    51.5122
# lng                                                  -0.131838
# Name: 228968, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           60
# Total_Number_of_Reviews                                   2995
# Review_Total_Positive_Word_Counts                            5
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                               5
# lat                                                    51.5241
# lng                                                  -0.125807
# Name: 301030, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           14
# Total_Number_of_Reviews                                   1114
# Review_Total_Positive_Word_Counts                           41
# Total_Number_of_Reviews_Reviewer_Has_Given                   5
# Reviewer_Score                                              10
# lat                                                    51.4989
# lng                                                  -0.106289
# Name: 130323, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            0
# Total_Number_of_Reviews                                    812
# Review_Total_Positive_Word_Counts                            7
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                              10
# lat                                                    51.4935
# lng                                                  -0.215326
# Name: 61267, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            3
# Total_Number_of_Reviews                                    311
# Review_Total_Positive_Word_Counts                            5
# Total_Number_of_Reviews_Reviewer_Has_Given                   3
# Reviewer_Score                                             8.3
# lat                                                    51.5052
# lng                                                  -0.088166
# Name: 247208, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            3
# Total_Number_of_Reviews                                   2516
# Review_Total_Positive_Word_Counts                           28
# Total_Number_of_Reviews_Reviewer_Has_Given                   2
# Reviewer_Score                                              10
# lat                                                    51.4981
# lng                                                  -0.179969
# Name: 144808, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                            8
# Total_Number_of_Reviews                                   1592
# Review_Total_Positive_Word_Counts                            7
# Total_Number_of_Reviews_Reviewer_Has_Given                  11
# Reviewer_Score                                              10
# lat                                                    51.5069
# lng                                                  -0.126012
# Name: 248033, dtype: object
# label 1:　Reviewer_Nationality                           Belgium
# Review_Total_Negative_Word_Counts                     5
# Total_Number_of_Reviews                             858
# Review_Total_Positive_Word_Counts                    12
# Total_Number_of_Reviews_Reviewer_Has_Given           10
# Reviewer_Score                                       10
# lat                                             48.8689
# lng                                             2.30266
# Name: 212311, dtype: object
# label 1:　Reviewer_Nationality                           Kuwait
# Review_Total_Negative_Word_Counts                    0
# Total_Number_of_Reviews                            635
# Review_Total_Positive_Word_Counts                   35
# Total_Number_of_Reviews_Reviewer_Has_Given          10
# Reviewer_Score                                      10
# lat                                            51.4973
# lng                                          -0.156256
# Name: 96016, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           49
# Total_Number_of_Reviews                                   4527
# Review_Total_Positive_Word_Counts                           16
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             5.8
# lat                                                     41.375
# lng                                                    2.14912
# Name: 415469, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           29
# Total_Number_of_Reviews                                   2562
# Review_Total_Positive_Word_Counts                           42
# Total_Number_of_Reviews_Reviewer_Has_Given                  17
# Reviewer_Score                                             8.3
# lat                                                    51.5119
# lng                                                  -0.179939
# Name: 363815, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           66
# Total_Number_of_Reviews                                   1593
# Review_Total_Positive_Word_Counts                           89
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             9.2
# lat                                                     51.518
# lng                                                  -0.123434
# Name: 287262, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           40
# Total_Number_of_Reviews                                   1164
# Review_Total_Positive_Word_Counts                           27
# Total_Number_of_Reviews_Reviewer_Has_Given                   7
# Reviewer_Score                                             9.6
# lat                                                    51.5135
# lng                                                  -0.183308
# Name: 124150, dtype: object
# label 1:　Reviewer_Nationality                             Spain
# Review_Total_Negative_Word_Counts                    15
# Total_Number_of_Reviews                            3826
# Review_Total_Positive_Word_Counts                    21
# Total_Number_of_Reviews_Reviewer_Has_Given           17
# Reviewer_Score                                       10
# lat                                             51.5043
# lng                                          -0.0334436
# Name: 125584, dtype: object
# label 1:　Reviewer_Nationality                           Saudi Arabia
# Review_Total_Negative_Word_Counts                         27
# Total_Number_of_Reviews                                  492
# Review_Total_Positive_Word_Counts                         15
# Total_Number_of_Reviews_Reviewer_Has_Given                 2
# Reviewer_Score                                           7.5
# lat                                                  51.5059
# lng                                                 -0.14038
# Name: 457511, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           55
# Total_Number_of_Reviews                                   2037
# Review_Total_Positive_Word_Counts                           73
# Total_Number_of_Reviews_Reviewer_Has_Given                   4
# Reviewer_Score                                             9.2
# lat                                                    51.5635
# lng                                                  -0.204276
# Name: 227156, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           32
# Total_Number_of_Reviews                                   1047
# Review_Total_Positive_Word_Counts                           21
# Total_Number_of_Reviews_Reviewer_Has_Given                   1
# Reviewer_Score                                             7.5
# lat                                                    51.4948
# lng                                                  -0.118748
# Name: 36458, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           84
# Total_Number_of_Reviews                                    824
# Review_Total_Positive_Word_Counts                           39
# Total_Number_of_Reviews_Reviewer_Has_Given                  23
# Reviewer_Score                                             8.3
# lat                                                    48.2046
# lng                                                    16.3564
# Name: 291570, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           11
# Total_Number_of_Reviews                                   6596
# Review_Total_Positive_Word_Counts                            4
# Total_Number_of_Reviews_Reviewer_Has_Given                   4
# Reviewer_Score                                             7.9
# lat                                                     51.513
# lng                                                  -0.183743
# Name: 142819, dtype: object
# label 1:　Reviewer_Nationality                           United Kingdom
# Review_Total_Negative_Word_Counts                           39
# Total_Number_of_Reviews                                   1016
# Review_Total_Positive_Word_Counts                           16
# Total_Number_of_Reviews_Reviewer_Has_Given                   2
# Reviewer_Score                                             7.1
# lat                                                     51.495
# lng                                                  -0.190619
# Name: 83909, dtype: object
