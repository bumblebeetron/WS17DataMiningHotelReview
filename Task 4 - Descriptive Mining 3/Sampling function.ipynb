# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

# %%
hotelReviews = pd.read_csv('C:\Users\deniz\Documents\Hotel_Reviews.csv')

# %%
def sampleFromDatFrame(inDataFrame, keyWord, sampleRatio = 0.1, column = 'Hotel_Name'):
    odf = hotelReviews.loc[hotelReviews[column] == keyWord]
    odf = odf.iloc[np.random.choice(odf.shape[0], int(odf.shape[0] * sampleRatio))]
    
    return odf

# %%
sampleFromDatFrame(hotelReviews, 'Hotel Arena')
# Out:
#                                          Hotel_Address  \
# 278   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 320   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 72    s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 96    s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 259   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 0     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 351   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 92    s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 170   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 49    s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 172   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 227   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 6     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 247   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 308   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 290   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...

# %%
hotelNames = list(set(hotelReviews['Hotel_Name']))

# %%
for i in range(len(hotelNames)):
    #print i , len(hotelNames)
    odf = sampleFromDatFrame(hotelReviews, h)
# Out:
# 61.8832179772
