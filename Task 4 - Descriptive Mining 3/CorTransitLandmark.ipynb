# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from pylab import rcParams
from sklearn import preprocessing

import scipy
from scipy.stats.stats import pearsonr

# %%
# %matplotlib inline
pylab.rcParams[ 'figure.figsize' ] = 5 , 4
sns.set_style('whitegrid')

# %%
Transit_Reviews=pd.read_csv("landmarks_count.csv", usecols=['Hotel_Name','landmark_count','Review_Count'])
Transit_Reviews = Transit_Reviews.drop_duplicates()
Transit_Reviews.index = pd.RangeIndex(start=0, stop=len(Transit_Reviews), step=1)
Transit_Reviews.to_csv('landmarks_count.csv')
Transit=pd.read_csv("landmarks_count.csv", usecols=['Hotel_Name','landmark_count','Review_Count'])

# %%
Hotel_Reviews=pd.read_csv("Hotel_Reviews.csv",usecols=['Hotel_Name','Reviewer_Score'])
Hotel_Reviews.head()
# Out:
#     Hotel_Name  Reviewer_Score
# 0  Hotel Arena             2.9
# 1  Hotel Arena             7.5
# 2  Hotel Arena             7.1
# 3  Hotel Arena             3.8
# 4  Hotel Arena             6.7

# %%
Hotel_name=np.array([])
mean_reviewer_score=np.array([])

# %%
Hotels=Hotel_Reviews.Hotel_Name.unique()

# %%
for Hotel in Hotels:
    TEMP=Hotel_Reviews.loc[Hotel_Reviews['Hotel_Name']==Hotel]
    TEMP=TEMP.reset_index()
    Hotel_name=np.append(Hotel_name,Hotel)
    
    mean_reviewer_score=np.append(mean_reviewer_score, TEMP['Reviewer_Score'].mean())

# %%
column1=['Hotel_name','mean_reviewer_score']

# %%
data1=np.column_stack((Hotel_name, mean_reviewer_score))

# %%
HotelReviews=pd.DataFrame(data1, columns=column1)
HotelReviews['mean_reviewer_score']=pd.to_numeric(HotelReviews['mean_reviewer_score'])
HotelReviews=HotelReviews[['mean_reviewer_score']]
HotelReviews
# Out:
#       mean_reviewer_score
# 0                7.836296
# 1                8.602827
# 2                9.298843
# 3                7.711469
# 4                8.848571
# 5                5.852632
# 6                8.029333
# 7                8.369546
# 8                9.144853
# 9                9.142520
# 10               8.330275
# 11               8.292500
# 12               7.029444
# 13               7.615619
# 14               9.572093
# 15               7.958292
# 16               8.961328
# 17               8.385393
# 18               8.758482
# 19               8.141341
# 20               8.489024
# 21               7.820370
# 22               8.777778
# 23               8.242245
# 24               9.590909
# 25               9.451196
# 26               8.577515
# 27               9.142105
# 28               7.752326
# 29               9.102174
# ...                   ...
# 1462             7.651420
# 1463             8.771429
# 1464             8.078544
# 1465             8.030045
# 1466             7.695630
# 1467             8.460111
# 1468             8.254018
# 1469             9.126829
# 1470             8.465035
# 1471             8.231126
# 1472             8.048718
# 1473             8.880667
# 1474             9.217268
# 1475             8.545053
# 1476             8.505811
# 1477             8.122181
# 1478             8.652866
# 1479             8.308997
# 1480             8.408955
# 1481             8.429122
# 1482             9.486854
# 1483             8.820241
# 1484             8.425636
# 1485             8.830616
# 1486             8.045238
# 1487             8.021185
# 1488             8.929861
# 1489             9.064000
# 1490             7.723591
# 1491             7.760000
#
# [1492 rows x 1 columns]

# %%
Connections=pd.concat([Transit_Reviews, HotelReviews], ignore_index=False, axis=1)
Connect = Connections[Connections.landmark_count!='-']

Connect['landmark_count']=Connect['landmark_count'].astype(str).astype(int)
Connect
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#                                         Hotel_Name  landmark_count  \
# 0                                      Hotel Arena               6
# 1                                 K K Hotel George               2
# 2                          Apex Temple Court Hotel               4
# 3                 The Park Grand London Paddington               3
# 4                              Monhotel Lounge SPA               1
# 5                               Kube Hotel Ice Bar               6
# 6                             The Principal London               8
# 7                    Park Plaza County Hall London               6
# 8                                      One Aldwych               6
# 9                                  Splendid Etoile               1
# 10                       Hotel Trianon Rive Gauche               6
# 11               InterContinental London Park Lane               4
# 12                 Novotel Suites Paris Nord 18 me               6
# 13                   Grand Royale London Hyde Park               2
# 14                      Milestone Hotel Kensington               2
# 15                 Crowne Plaza London Kings Cross               2
# 16                                    Select Hotel               9
# 17                                H tel De Vend me               3
# 18                      Pullman Paris Centre Bercy               6
# 19                             Gardette Park Hotel               7
# 20                                   Hotel Panache               1
# 21                          H tel des Ducs D Anjou               7
# 22             Hotel Scribe Paris Opera by Sofitel               3
# 23                             Novotel London West               5
# 24                                 Haymarket Hotel               2
# 25                  Intercontinental London The O2               5
# 26                             H tel Juliana Paris               4
# 27                                 Hotel L Antoine               8
# 28                                         Belfast               1
# 29                          Shangri La Hotel Paris               6
# ...                                            ...             ...
# 1462                                Hotel Vilamar                6
# 1463                                  Vilana Hotel               2
# 1464                              Acevi Villarroel               7
# 1465                              Hotel Arkadenhof              10
# 1466                        Hotel Vondel Amsterdam              10
# 1469          Park Inn by Radisson Uno City Vienna               6
# 1470                                NH Danube City               6
# 1471                        Strandhotel Alte Donau               4
# 1472                 ARCOTEL Kaiserwasser Superior               6
# 1473                    Mercure Hotel Raphael Wien              10
# 1474                     Arthotel ANA Boutique Six               7
# 1475               Austria Trend Hotel Anatol Wien               8
# 1476                      Hotel Kaiserin Elisabeth               1
# 1477                   Boutique Hotel Notting Hill               7
# 1478                    Crowne Plaza London Ealing               5
# 1479                             Good Hotel London               3
# 1480          Park Plaza Westminster Bridge London               6
# 1481        Hotel du Vin Cannizaro House Wimbledon               4
# 1482                     Amsterdam Canal Residence               6
# 1483  Thistle Trafalgar Square The Royal Trafalgar               2
# 1484                        Corinthia Hotel London               6
# 1485              The Student Hotel Amsterdam City               3
# 1486                             Hotel Prinz Eugen               8
# 1487                        Hotel Erzherzog Rainer              10
# 1488                              Das Triest Hotel              10
# 1489                    Suite Hotel 900 m zur Oper              10
# 1490                                 Hotel Amadeus               3
# 1491                                  The Berkeley               5
# 1492                 Holiday Inn London Kensington               2
# 1493                         Atlantis Hotel Vienna               6
#
#       Review_Count  mean_reviewer_score
# 0            405.0             7.836296
# 1            566.0             8.602827
# 2           1037.0             9.298843
# 3           1770.0             7.711469
# 4             35.0             8.848571
# 5             19.0             5.852632
# 6           1425.0             8.029333
# 7           2223.0             8.369546
# 8            136.0             9.144853
# 9            127.0             9.142520
# 10           218.0             8.330275
# 11           160.0             8.292500
# 12           180.0             7.029444
# 13          2958.0             7.615619
# 14            86.0             9.572093
# 15          1007.0             7.958292
# 16           256.0             8.961328
# 17            89.0             8.385393
# 18           224.0             8.758482
# 19           179.0             8.141341
# 20            82.0             8.489024
# 21           108.0             7.820370
# 22           135.0             8.777778
# 23          1283.0             8.242245
# 24           121.0             9.590909
# 25          2551.0             9.451196
# 26           169.0             8.577515
# 27           171.0             9.142105
# 28            86.0             7.752326
# 29            46.0             9.102174
# ...            ...                  ...
# 1462         352.0             7.651420
# 1463          28.0             8.771429
# 1464         522.0             8.078544
# 1465         223.0             8.030045
# 1466         389.0             7.695630
# 1469          41.0             9.126829
# 1470         143.0             8.465035
# 1471         151.0             8.231126
# 1472         390.0             8.048718
# 1473         150.0             8.880667
# 1474         388.0             9.217268
# 1475         657.0             8.545053
# 1476         413.0             8.505811
# 1477         541.0             8.122181
# 1478        4169.0             8.652866
# 1479         289.0             8.308997
# 1480          67.0             8.408955
# 1481         467.0             8.429122
# 1482         213.0             9.486854
# 1483        1576.0             8.820241
# 1484         511.0             8.425636
# 1485         601.0             8.830616
# 1486          42.0             8.045238
# 1487         439.0             8.021185
# 1488         144.0             8.929861
# 1489         100.0             9.064000
# 1490        2768.0             7.723591
# 1491         325.0             7.760000
# 1492           NaN                  NaN
# 1493           NaN                  NaN
#
# [1477 rows x 4 columns]

# %%
bins = [0, 5, 10, 15, 20]

# %%
group_names = ['low', 'average', 'good', 'excellent']

# %%
Connect['transit_groups']=pd.cut(Connect['landmark_count'], bins, labels=group_names)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Connect.head()
# Out:
#                          Hotel_Name  landmark_count  Review_Count  \
# 0                       Hotel Arena               6         405.0
# 1                  K K Hotel George               2         566.0
# 2           Apex Temple Court Hotel               4        1037.0
# 3  The Park Grand London Paddington               3        1770.0
# 4               Monhotel Lounge SPA               1          35.0
#
#    mean_reviewer_score transit_groups
# 0             7.836296        average
# 1             8.602827            low
# 2             9.298843            low
# 3             7.711469            low
# 4             8.848571            low

# %%
plt.hist(Connect['landmark_count'])
plt.xlabel('Number of Transit Points')
plt.ylabel('Number of Hotels')
plt.show()

# %%
meanTransit=Connect['landmark_count'].mean()
stdTransit=Connect['landmark_count'].std()
Connect['scaled_Transit']=(Connect['landmark_count']-meanTransit)/stdTransit

meanScore=Connect['mean_reviewer_score'].mean()
stdScore=Connect['mean_reviewer_score'].std()
Connect['scaled_Score']=(Connect['mean_reviewer_score']-meanScore)/stdScore

meanReview=Connect['Review_Count'].mean()
stdReview=Connect['Review_Count'].std()
Connect['scaled_Review']=(Connect['Review_Count']-meanReview)/stdReview

Connect.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#                          Hotel_Name  landmark_count  Review_Count  \
# 0                       Hotel Arena               6         405.0
# 1                  K K Hotel George               2         566.0
# 2           Apex Temple Court Hotel               4        1037.0
# 3  The Park Grand London Paddington               3        1770.0
# 4               Monhotel Lounge SPA               1          35.0
#
#    mean_reviewer_score transit_groups  scaled_Transit  scaled_Score  \
# 0             7.836296        average        0.528898     -1.013734
# 1             8.602827            low       -0.857406      0.215830
# 2             9.298843            low       -0.164254      1.332284
# 3             7.711469            low       -0.510830     -1.213965
# 4             8.848571            low       -1.203981      0.610020
#
#    scaled_Review
# 0       0.138571
# 1       0.508409
# 2       1.590357
# 3       3.274154
# 4      -0.711368

# %%
Connect=Connect.take([1,2],axis=1)

# %%
correlation= Connect.corr(method="kendall")

sns.heatmap(correlation,annot=True,cbar=True,cmap="YlGnBu")
plt.title("Heat Map of Correlation Test")
plt.show()
