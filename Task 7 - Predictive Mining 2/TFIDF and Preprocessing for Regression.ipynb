# %% [markdown]
# # This is the code for constructing the TF-IDF vector for classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.sparse as sps
import itertools
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from PIL import Image
import re

# %%
hotelReviews = pd.read_csv('C:/Users/deniz/Documents/HotelReviewsCountryCity.csv')
cities = ['Paris', 'Amsterdam', 'London', 'Milan', 'Barcelona', 'Vienna']
nationality = ' United Kingdom '

# %% [markdown]
# ## This parameter represents the threshold for word count.
# ## Note that 3 means reviews with MORE than 3 words will be in the dataset

# %%
wordThreshold = 3

# %% [markdown]
# ## This is the split and Bag-Of-Words Shingling functions
# ## Change k according to your wish. But 3-shingles should work fine for English Language

# %%
def wordSplit(rev, stop_words = stopwords.words('English')):
    s = [item for sublist in [rev.lower().split() for f in re.findall('\d+|\D+',rev.lower())] for item in sublist]
    s = [x for x in s if x not in stop_words]
    return s

def bagOfWordsShingles(review, k=3, stop_words = stopwords.words('English')):
    s = wordSplit(review, stop_words)
    if len(s) < k:
        tokens = ['']
        for s_ in s:
            tokens[0] += s_ + ' '
        tokens[0] = tokens[0][:-1]
        return tokens
        
    tokens = []
    for i in range(len(s) - k + 1):
        bag = ''
        for j in range(i, i + k):
            bag += s[j]+' '
        tokens.append(bag[:-1])
    return tokens

def bagOfWordsShingles2(review, k=3, stop_words = stopwords.words('English')):
    s = wordSplit(review, stop_words)
    tokens = []
    for K in range(0,k):
        for i in range(len(s) - (k-K) + 1):
            bag = ''
            for j in range(i, i + k-K):
                bag += s[j]+' '
            tokens.append(bag[:-1])

    return tokens

# %%
#englishReviews = hotelReviews.loc[(hotelReviews['Reviewer_Nationality']==nationality) & (hotelReviews['City']=='Barcelona')]
englishReviews = hotelReviews.loc[(hotelReviews['Reviewer_Nationality']==nationality)]
#posEnglishReviews = englishReviews.loc[englishReviews['Review_Total_Positive_Word_Counts'] > wordThreshold]
#negEnglishReviews = englishReviews.loc[englishReviews['Review_Total_Negative_Word_Counts'] > wordThreshold]

# %%
posRevs = englishReviews['Positive_Review']
negRevs = englishReviews['Negative_Review']

posRevs = posRevs.reset_index()['Positive_Review']
negRevs = negRevs.reset_index()['Negative_Review']

allReviews = posRevs + negRevs

# %%
labels = np.array(englishReviews['Reviewer_Score'])
featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'),tokenizer=bagOfWordsShingles2, lowercase=True).fit_transform(allReviews)

sps.save_npz('Regression_Features', featureMatrix)
np.savez('Regression_Labels',labels)

# %%
featureMatrix.shape
# Out:
# (245246, 4161106)

# %%
Positive_Processed_Word_Count = []
Negative_Processed_Word_Count = []
Positive_Processed_Words = []
Negative_Processed_Words = []

for i in range(posRevs.shape[0]):
    if i % (posRevs.shape[0]/20) == 0:
        print '    ', 100 * (1.0 * i / posRevs.shape[0]), '% finished'
        
    sPos = wordSplit(posRevs.iloc[i])
    sNeg = wordSplit(negRevs.iloc[i])
    
    Positive_Processed_Word_Count.append(len(sPos))
    Negative_Processed_Word_Count.append(len(sNeg))
    
    Positive_Processed_Words.append(sPos)
    Negative_Processed_Words.append(sNeg)
    
englishReviews['Positive_Processed_Word_Count'] = Positive_Processed_Word_Count
englishReviews['Negative_Processed_Word_Count'] = Negative_Processed_Word_Count
englishReviews['Positive_Processed_Words'] = Positive_Processed_Words
englishReviews['Negative_Processed_Words'] = Negative_Processed_Words
#thrPosEngRevs = posEnglishReviews.loc[posEnglishReviews['Positive_Processed_Word_Count'] > wordThreshold]['Positive_Review']
englishReviews.to_csv('UKReviewsWordCounted.csv')
# Out:
#      0.0 % finished
#      4.99987767385 % finished
#      9.99975534769 % finished
#      14.9996330215 % finished
#      19.9995106954 % finished
#      24.9993883692 % finished
#      29.9992660431 % finished
#      34.9991437169 % finished
#      39.9990213908 % finished
#      44.9988990646 % finished
#      49.9987767385 % finished
#      54.9986544123 % finished
#      59.9985320862 % finished
#      64.99840976 % finished
#      69.9982874338 % finished
#      74.9981651077 % finished
#      79.9980427815 % finished
#      84.9979204554 % finished
#      89.9977981292 % finished
#      94.9976758031 % finished
#      99.9975534769 % finished
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
englishReviews
# Out:
#         Unnamed: 0                                      Hotel_Address  \
# 3                3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 6                6   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 7                7   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 10              10   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 12              12   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 16              16   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 20              20   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 24              24   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 26              26   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 31              31   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 38              38   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 41              41   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 43              43   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 46              46   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 47              47   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 48              48   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 50              50   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 51              51   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 53              53   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 55              55   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 56              56   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 57              57   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 58              58   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 62              62   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 64              64   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 65              65   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 66              66   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 69              69   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 73              73   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 74              74   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...            ...                                                ...
# 515546      515546  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515549      515549  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515566      515566  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515570      515570  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515577      515577  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515579      515579  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515589      515589  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515590      515590  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515609      515609  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515612      515612  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515616      515616  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515619      515619  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515626      515626  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515628      515628  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515631      515631  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515634      515634  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515635      515635  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515644      515644  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515649      515649  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515652      515652  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515656      515656  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515657      515657  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515658      515658  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515660      515660  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515664      515664  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515691      515691  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515714      515714  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515715      515715  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515722      515722  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515727      515727  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 3                                194   7/31/2017            7.7
# 6                                194   7/17/2017            7.7
# 7                                194   7/17/2017            7.7
# 10                               194    7/7/2017            7.7
# 12                               194    7/6/2017            7.7
# 16                               194    7/3/2017            7.7
# 20                               194   6/19/2017            7.7
# 24                               194   5/27/2017            7.7
# 26                               194   5/25/2017            7.7
# 31                               194   5/11/2017            7.7
# 38                               194   4/20/2017            7.7
# 41                               194   4/16/2017            7.7
# 43                               194   4/10/2017            7.7
# 46                               194    4/5/2017            7.7
# 47                               194   3/29/2017            7.7
# 48                               194   3/22/2017            7.7
# 50                               194   3/20/2017            7.7
# 51                               194   3/19/2017            7.7
# 53                               194   3/16/2017            7.7
# 55                               194   2/20/2017            7.7
# 56                               194   2/17/2017            7.7
# 57                               194   2/17/2017            7.7
# 58                               194   2/14/2017            7.7
# 62                               194   1/27/2017            7.7
# 64                               194   1/19/2017            7.7
# 65                               194    1/8/2017            7.7
# 66                               194  12/29/2016            7.7
# 69                               194  12/20/2016            7.7
# 73                               194  12/14/2016            7.7
# 74                               194  12/14/2016            7.7
# ...                              ...         ...            ...
# 515546                           168    1/6/2016            8.1
# 515549                           168  10/26/2015            8.1
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 3                                     210                     1403
# 6                                      33                     1403
# 7                                      11                     1403
# 10                                      5                     1403
# 12                                     28                     1403
# 16                                     38                     1403
# 20                                     40                     1403
# 24                                      3                     1403
# 26                                     51                     1403
# 31                                     61                     1403
# 38                                     93                     1403
# 41                                    139                     1403
# 43                                     15                     1403
# 46                                    315                     1403
# 47                                     41                     1403
# 48                                      0                     1403
# 50                                     29                     1403
# 51                                    105                     1403
# 53                                      0                     1403
# 55                                      0                     1403
# 56                                     58                     1403
# 57                                     46                     1403
# 58                                     31                     1403
# 62                                     45                     1403
# 64                                     15                     1403
# 65                                     37                     1403
# 66                                     40                     1403
# 69                                     46                     1403
# 73                                     59                     1403
# 74                                    155                     1403
# ...                                   ...                      ...
# 515546                                 43                     2823
# 515549                                  0                     2823
# 515566                                 12                     2823
# 515570                                 15                     2823
# 515577                                  0                     2823
# 515579                                 15                     2823
# 515589                                  0                     2823
# 515590                                  0                     2823
# 515609                                  0                     2823
# 515612                                 13                     2823
# 515616                                  5                     2823
# 515619                                  0                     2823
# 515626                                 18                     2823
# 515628                                 16                     2823
# 515631                                  0                     2823
# 515634                                  0                     2823
# 515635                                  2                     2823
# 515644                                 23                     2823
# 515649                                 12                     2823
# 515652                                  6                     2823
# 515656                                  6                     2823
# 515657                                 11                     2823
# 515658                                  5                     2823
# 515660                                  0                     2823
# 515664                                  9                     2823
# 515691                                  0                     2823
# 515714                                 16                     2823
# 515715                                  8                     2823
# 515722                                 19                     2823
# 515727                                 10                     2823
#
#                     ...               \
# 3                   ...
# 6                   ...
# 7                   ...
# 10                  ...
# 12                  ...
# 16                  ...
# 20                  ...
# 24                  ...
# 26                  ...
# 31                  ...
# 38                  ...
# 41                  ...
# 43                  ...
# 46                  ...
# 47                  ...
# 48                  ...
# 50                  ...
# 51                  ...
# 53                  ...
# 55                  ...
# 56                  ...
# 57                  ...
# 58                  ...
# 62                  ...
# 64                  ...
# 65                  ...
# 66                  ...
# 69                  ...
# 73                  ...
# 74                  ...
# ...                 ...
# 515546              ...
# 515549              ...
# 515566              ...
# 515570              ...
# 515577              ...
# 515579              ...
# 515589              ...
# 515590              ...
# 515609              ...
# 515612              ...
# 515616              ...
# 515619              ...
# 515626              ...
# 515628              ...
# 515631              ...
# 515634              ...
# 515635              ...
# 515644              ...
# 515649              ...
# 515652              ...
# 515656              ...
# 515657              ...
# 515658              ...
# 515660              ...
# 515664              ...
# 515691              ...
# 515714              ...
# 515715              ...
# 515722              ...
# 515727              ...
#
#        Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 3                                               1             3.8
# 6                                               6             4.6
# 7                                               1            10.0
# 10                                              2            10.0
# 12                                              7             4.6
# 16                                              8             6.3
# 20                                              1             6.3
# 24                                              2             9.6
# 26                                              2             9.6
# 31                                             14             7.1
# 38                                              2             8.8
# 41                                              8             6.7
# 43                                              8             9.6
# 46                                              7             4.2
# 47                                              2             8.3
# 48                                              3            10.0
# 50                                             11             9.6
# 51                                              1             7.1
# 53                                              4            10.0
# 55                                              2            10.0
# 56                                              1             7.1
# 57                                              2             7.9
# 58                                              3             7.9
# 62                                              1             8.3
# 64                                              1             9.2
# 65                                              4             8.8
# 66                                              7             9.2
# 69                                              1             8.8
# 73                                              1             6.3
# 74                                              7             7.1
# ...                                           ...             ...
# 515546                                         14             5.8
# 515549                                          8             8.3
# 515566                                          1             7.5
# 515570                                          1             5.8
# 515577                                          1             7.5
# 515579                                          8             3.8
# 515589                                          5             9.2
# 515590                                         30             7.9
# 515609                                          2             9.2
# 515612                                          1             7.9
# 515616                                          3             9.2
# 515619                                         18            10.0
# 515626                                          1             7.5
# 515628                                          9             7.5
# 515631                                         24             9.6
# 515634                                          1            10.0
# 515635                                          1             7.9
# 515644                                          7             5.4
# 515649                                          1             9.2
# 515652                                          5             9.2
# 515656                                          1             9.6
# 515657                                         18             9.2
# 515658                                         11            10.0
# 515660                                         24             8.3
# 515664                                         18            10.0
# 515691                                          5            10.0
# 515714                                          1             9.6
# 515715                                          1             8.8
# 515722                                         72             6.3
# 515727                                         12             5.8
#
#                                                      Tags  days_since_review  \
# 3       [' Leisure trip ', ' Solo traveler ', ' Duplex...             3 days
# 6       [' Leisure trip ', ' Group ', ' Duplex Twin Ro...            17 days
# 7       [' Leisure trip ', ' Couple ', ' Duplex Double...            17 days
# 10      [' Leisure trip ', ' Group ', ' Duplex Double ...            27 days
# 12      [' Leisure trip ', ' Solo traveler ', ' Duplex...            28 days
# 16      [' Leisure trip ', ' Family with young childre...            31 days
# 20      [' Leisure trip ', ' Travelers with friends ',...            45 days
# 24      [' Leisure trip ', ' Couple ', ' Duplex Double...            68 days
# 26      [' Leisure trip ', ' Group ', ' Duplex Double ...            70 days
# 31      [' Leisure trip ', ' Group ', ' 2 rooms ', ' S...            84 days
# 38      [' Leisure trip ', ' Couple ', ' Duplex Double...            105 day
# 41      [' Leisure trip ', ' Family with young childre...            109 day
# 43      [' Business trip ', ' Group ', ' 2 rooms ', ' ...            115 day
# 46      [' Leisure trip ', ' Couple ', ' Duplex Double...            120 day
# 47      [' Leisure trip ', ' Couple ', ' Duplex Double...            127 day
# 48      [' Leisure trip ', ' Couple ', ' Duplex Double...            134 day
# 50      [' Leisure trip ', ' Solo traveler ', ' Duplex...            136 day
# 51      [' Leisure trip ', ' Couple ', ' Duplex Double...            137 day
# 53      [' Leisure trip ', ' Couple ', ' Duplex Double...            140 day
# 55      [' Leisure trip ', ' Couple ', ' Duplex Double...            164 day
# 56      [' Business trip ', ' Solo traveler ', ' Duple...            167 day
# 57      [' Leisure trip ', ' Couple ', ' Duplex Double...            167 day
# 58      [' Leisure trip ', ' Couple ', ' Duplex Double...            170 day
# 62      [' Leisure trip ', ' Couple ', ' Duplex Double...            188 day
# 64      [' Leisure trip ', ' Couple ', ' Duplex Double...            196 day
# 65      [' Leisure trip ', ' Family with young childre...            207 day
# 66      [' Leisure trip ', ' Couple ', ' Large King Ro...            217 day
# 69      [' Leisure trip ', ' Couple ', ' Large King Ro...            226 day
# 73      [' Leisure trip ', ' Solo traveler ', ' Duplex...            232 day
# 74      [' Leisure trip ', ' Couple ', ' Duplex Double...            232 day
# ...                                                   ...                ...
# 515546  [' Leisure trip ', ' Couple ', ' Standard Doub...            575 day
# 515549  [' Leisure trip ', ' Group ', ' Standard Tripl...            647 day
# 515566  [' Leisure trip ', ' Family with young childre...            16 days
# 515570  [' Leisure trip ', ' Group ', ' Standard Doubl...            29 days
# 515577  [' Leisure trip ', ' Couple ', ' Superior Doub...            39 days
# 515579  [' Leisure trip ', ' Family with young childre...            46 days
# 515589  [' Leisure trip ', ' Group ', ' Superior Doubl...            65 days
# 515590  [' Leisure trip ', ' Couple ', ' Standard Doub...            66 days
# 515609  [' Leisure trip ', ' Couple ', ' Superior Doub...            154 day
# 515612  [' Leisure trip ', ' Group ', ' Standard Doubl...            171 day
# 515616  [' Business trip ', ' Family with young childr...            181 day
# 515619  [' Leisure trip ', ' Family with young childre...            184 day
# 515626  [' Leisure trip ', ' Group ', ' Standard Doubl...            205 day
# 515628  [' Leisure trip ', ' Family with young childre...            211 day
# 515631  [' Leisure trip ', ' Couple ', ' Standard Doub...            218 day
# 515634  [' Leisure trip ', ' Solo traveler ', ' Standa...            226 day
# 515635  [' Leisure trip ', ' Group ', ' Standard Doubl...            226 day
# 515644  [' Leisure trip ', ' Couple ', ' Standard Doub...            236 day
# 515649  [' Leisure trip ', ' Group ', ' Standard Doubl...            268 day
# 515652  [' Leisure trip ', ' Couple ', ' Standard Doub...            283 day
# 515656  [' Leisure trip ', ' Solo traveler ', ' Standa...            297 day
# 515657  [' Leisure trip ', ' Couple ', ' Superior Doub...            297 day
# 515658  [' Leisure trip ', ' Couple ', ' Superior Doub...            299 day
# 515660  [' Business trip ', ' Couple ', ' Standard Dou...            308 day
# 515664  [' Leisure trip ', ' Couple ', ' Standard Doub...            316 day
# 515691  [' Leisure trip ', ' Solo traveler ', ' Superi...            394 day
# 515714  [' Leisure trip ', ' Family with older childre...            476 day
# 515715  [' Leisure trip ', ' Group ', ' Standard Doubl...            491 day
# 515722  [' Business trip ', ' Solo traveler ', ' Stand...            616 day
# 515727  [' Leisure trip ', ' Couple ', ' Standard Doub...            676 day
#
#               lat        lng      Country       City  \
# 3       52.360576   4.915968  Netherlands  Amsterdam
# 6       52.360576   4.915968  Netherlands  Amsterdam
# 7       52.360576   4.915968  Netherlands  Amsterdam
# 10      52.360576   4.915968  Netherlands  Amsterdam
# 12      52.360576   4.915968  Netherlands  Amsterdam
# 16      52.360576   4.915968  Netherlands  Amsterdam
# 20      52.360576   4.915968  Netherlands  Amsterdam
# 24      52.360576   4.915968  Netherlands  Amsterdam
# 26      52.360576   4.915968  Netherlands  Amsterdam
# 31      52.360576   4.915968  Netherlands  Amsterdam
# 38      52.360576   4.915968  Netherlands  Amsterdam
# 41      52.360576   4.915968  Netherlands  Amsterdam
# 43      52.360576   4.915968  Netherlands  Amsterdam
# 46      52.360576   4.915968  Netherlands  Amsterdam
# 47      52.360576   4.915968  Netherlands  Amsterdam
# 48      52.360576   4.915968  Netherlands  Amsterdam
# 515570                             1                             7
# 515577                             2                             1
# 515579                             4                             9
# 515589                            10                             1
# 515590                             4                             1
# 515609                             3                             1
# 515612                             1                            18
# 515616                             7                             1
# 515619                            12                             1
# 515626                             5                             9
# 515628                             2                            27
# 515631                             3                             1
# 515634                            10                             1
# 515635                             3                             1
# 515644                             3                            33
# 515649                             3                             5
# 515652                            13                             3
# 515656                             7                             3
# 515657                             2                            18
# 515658                             6                             2
# 515660                            12                             1
# 515664                             4                             9
# 515691                             2                             1
# 515714                             7                             5
# 515715                             6                             6
# 515722                             1                            10
# 515727                             8                             5
#
# [245246 rows x 22 columns]

# %%
thrPosEngRevs = englishReviews.loc[englishReviews['Positive_Processed_Word_Count'] > wordThreshold]['Positive_Review']
thrNegEngRevs = englishReviews.loc[englishReviews['Negative_Processed_Word_Count'] > wordThreshold]['Negative_Review']

allReviews = pd.concat([thrPosEngRevs, thrNegEngRevs])
labels = np.hstack([np.ones(thrPosEngRevs.shape[0]), np.zeros(thrNegEngRevs.shape[0])])
featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'),tokenizer=bagOfWordsShingles, lowercase=True).fit_transform(allReviews)

sps.save_npz('UkReviews_Thresholded_BOW3_Features', featureMatrix)
np.savez('UkReviews_Thresholded_BOW3_Labels',labels)

# %%
thrPosEngRevs = englishReviews.loc[englishReviews['Positive_Processed_Word_Count'] > wordThreshold]['Positive_Review']
thrNegEngRevs = englishReviews.loc[englishReviews['Negative_Processed_Word_Count'] > wordThreshold]['Negative_Review']

allReviews = pd.concat([thrPosEngRevs, thrNegEngRevs])
labels = np.hstack([np.ones(thrPosEngRevs.shape[0]), np.zeros(thrNegEngRevs.shape[0])])
featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'),tokenizer=bagOfWordsShingles2, lowercase=True).fit_transform(allReviews)

sps.save_npz('UkReviews_Thresholded_BOW123_Features', featureMatrix)
np.savez('UkReviews_Thresholded_BOW123_Labels',labels)

# %%
thrPosEngRevs = englishReviews['Positive_Review']
thrNegEngRevs = englishReviews['Negative_Review']

allReviews = pd.concat([thrPosEngRevs, thrNegEngRevs])
labels = np.hstack([np.ones(thrPosEngRevs.shape[0]), np.zeros(thrNegEngRevs.shape[0])])
featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'),tokenizer=bagOfWordsShingles, lowercase=True).fit_transform(allReviews)

sps.save_npz('UkReviews_Raw_BOW3_Features', featureMatrix)
np.savez('UkReviews_Raw_BOW3_Labels',labels)

# %%
thrPosEngRevs = englishReviews['Positive_Review']
thrNegEngRevs = englishReviews['Negative_Review']

allReviews = pd.concat([thrPosEngRevs, thrNegEngRevs])
labels = np.hstack([np.ones(thrPosEngRevs.shape[0]), np.zeros(thrNegEngRevs.shape[0])])
featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'),tokenizer=bagOfWordsShingles2, lowercase=True).fit_transform(allReviews)

sps.save_npz('UkReviews_Raw_BOW123_Features', featureMatrix)
np.savez('UkReviews_Raw_BOW123_Labels',labels)
