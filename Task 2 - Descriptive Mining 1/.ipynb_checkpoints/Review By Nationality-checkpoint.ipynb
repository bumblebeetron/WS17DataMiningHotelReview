# %%
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
from collections import Counter
from operator import itemgetter
import matplotlib.pyplot as plt

# %%
hotelReviews = pd.read_csv('C:\Users\deniz\Documents\Hotel_Reviews.csv')
hotel_info = hotelReviews[['Hotel_Name', 'Hotel_Address']]
hotel_info = hotel_info.drop_duplicates()

# %% [markdown]
# # By Manual Analysis, we found that hotels from only these cities and nationalities are represented in the dataset

# %%
cities = ['Paris', 'Amsterdam', 'London', 'Milan', 'Roma', 'Barcelona', 'Vienna']
countries = ['France', 'Netherlands', 'United Kingdom', 'Italy', 'Spain', 'Austria']

# %% [markdown]
# # Extraction of City and Nation of Hotels and appending them to the dataset for ease of access

# %%
Country = []
City = []

for a in hotel_info['Hotel_Address']:
    for c_i in range(len(countries)):
        if countries[c_i] in a:
            Country.append(countries[c_i])
            City.append(cities[c_i])        
hotel_info['Country'] = Country
hotel_info['City'] = City

hotel_info.to_csv('C:\Users\deniz\Documents\Hotel_Info_Country_City.csv')

citiesDict = dict()
countriesDict = dict()

i = 0
for hn in hotel_info['Hotel_Name']:
    citiesDict[hn] = City[i]
    countriesDict[hn] = Country[i]
    i += 1
    
hnCities = []
hnCountries = []
for hName in hotelReviews['Hotel_Name']:
    hnCities.append(citiesDict[hName])
    hnCountries.append(countriesDict[hName])
hotelReviews['Country'] = hnCountries
hotelReviews['City'] = hnCities

hotelReviews.to_csv('C:\Users\deniz\Documents\HotelReviewsCountryCity.csv')

# %% [markdown]
# # Analysis of Bad, Average, Good and Excellent Reviews By City

# %%
hotRevs = hotelReviews[['Hotel_Name', 'City', 'Reviewer_Score', 'Reviewer_Nationality']]
# 0-4: Bad          0
# 4-6: Average      0
# 6-8: Good         0
# 9-10: Excellent   0
reviews = hotRevs['Reviewer_Score']
binRevs = []
for r in reviews:
    if 0.0 < r <= 4:
        binRevs.append(0)
    elif 4 < r <= 6:
        binRevs.append(1)
    elif 6 < r <= 8:
        binRevs.append(2)
    elif 8 < r <= 10.0:
        binRevs.append(3)
hotRevs['Review_Labels'] = binRevs
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
hotRevs
# Out:
#                    Hotel_Name       City  Reviewer_Score  \
# 0                 Hotel Arena  Amsterdam             2.9
# 1                 Hotel Arena  Amsterdam             7.5
# 2                 Hotel Arena  Amsterdam             7.1
# 3                 Hotel Arena  Amsterdam             3.8
# 4                 Hotel Arena  Amsterdam             6.7
# 5                 Hotel Arena  Amsterdam             6.7
# 6                 Hotel Arena  Amsterdam             4.6
# 7                 Hotel Arena  Amsterdam            10.0
# 8                 Hotel Arena  Amsterdam             6.5
# 9                 Hotel Arena  Amsterdam             7.9
# 10                Hotel Arena  Amsterdam            10.0
# 11                Hotel Arena  Amsterdam             5.8
# 12                Hotel Arena  Amsterdam             4.6
# 13                Hotel Arena  Amsterdam             9.2
# 14                Hotel Arena  Amsterdam             8.8
# 15                Hotel Arena  Amsterdam            10.0
# 16                Hotel Arena  Amsterdam             6.3
# 17                Hotel Arena  Amsterdam             7.5
# 18                Hotel Arena  Amsterdam             7.1
# 19                Hotel Arena  Amsterdam             7.5
# 20                Hotel Arena  Amsterdam             6.3
# 21                Hotel Arena  Amsterdam             3.8
# 22                Hotel Arena  Amsterdam             5.4
# 23                Hotel Arena  Amsterdam             9.6
# 24                Hotel Arena  Amsterdam             9.6
# 25                Hotel Arena  Amsterdam             8.3
# 26                Hotel Arena  Amsterdam             9.6
# 27                Hotel Arena  Amsterdam             8.3
# 28                Hotel Arena  Amsterdam             8.3
# 29                Hotel Arena  Amsterdam             9.2
# ...                       ...        ...             ...
# 515708  Atlantis Hotel Vienna  Barcelona             8.8
# 515709  Atlantis Hotel Vienna  Barcelona             7.9
# 515710  Atlantis Hotel Vienna  Barcelona             9.2
# 515711  Atlantis Hotel Vienna  Barcelona            10.0
# 515712  Atlantis Hotel Vienna  Barcelona             8.8
# 515713  Atlantis Hotel Vienna  Barcelona             7.1
# 515714  Atlantis Hotel Vienna  Barcelona             9.6
# 515715  Atlantis Hotel Vienna  Barcelona             8.8
# 515716  Atlantis Hotel Vienna  Barcelona             7.1
# 515717  Atlantis Hotel Vienna  Barcelona             7.9
# 515718  Atlantis Hotel Vienna  Barcelona             9.2
# 515719  Atlantis Hotel Vienna  Barcelona             8.3
# 515720  Atlantis Hotel Vienna  Barcelona             9.2
# 515721  Atlantis Hotel Vienna  Barcelona             6.7
# 515722  Atlantis Hotel Vienna  Barcelona             6.3
# 515723  Atlantis Hotel Vienna  Barcelona             8.8
# 515724  Atlantis Hotel Vienna  Barcelona             8.3
# 515725  Atlantis Hotel Vienna  Barcelona             7.1
# 515726  Atlantis Hotel Vienna  Barcelona             5.4
# 515727  Atlantis Hotel Vienna  Barcelona             5.8
# 515728  Atlantis Hotel Vienna  Barcelona             4.2
# 515729  Atlantis Hotel Vienna  Barcelona            10.0
# 515730  Atlantis Hotel Vienna  Barcelona             6.7
# 515731  Atlantis Hotel Vienna  Barcelona             7.5
# 515732  Atlantis Hotel Vienna  Barcelona            10.0
# 515733  Atlantis Hotel Vienna  Barcelona             7.0
# 515734  Atlantis Hotel Vienna  Barcelona             5.8
# 515735  Atlantis Hotel Vienna  Barcelona             2.5
# 515736  Atlantis Hotel Vienna  Barcelona             8.8
# 515737  Atlantis Hotel Vienna  Barcelona             8.3
#
#               Reviewer_Nationality  Review_Labels
# 0                          Russia               0
# 1                         Ireland               2
# 2                       Australia               2
# 3                  United Kingdom               0
# 4                     New Zealand               2
# 5                          Poland               2
# 6                  United Kingdom               1
# 7                  United Kingdom               3
# 8                         Belgium               2
# 9                          Norway               2
# 10                 United Kingdom               3
# 11                         France               1
# 12                 United Kingdom               1
# 13                          Italy               3
# 14                         Canada               3
# 15                          Italy               3
# 16                 United Kingdom               2
# 17                        Ireland               2
# 18                    Netherlands               2
# 19                      Australia               2
# 20                 United Kingdom               2
# 21                         France               0
# 22                        Germany               1
# 23                        Ireland               3
# 24                 United Kingdom               3
# 25       United States of America               3
# 26                 United Kingdom               3
# 27                         France               3
# 28       United States of America               3
# 29                        Hungary               3
# ...                            ...            ...
# 515708     Bosnia and Herzegovina               3
# 515709   United States of America               2
# 515710                       Iraq               3
# 515711                    Hungary               3
# 515712                     Israel               3
# 515713                     Norway               2
# 515714             United Kingdom               3
# 515715             United Kingdom               3
# 515716                      Egypt               2
# 515717                      Egypt               2
# 515718                   Thailand               3
# 515719                   Slovenia               3
# 515720                    Croatia               3
# 515721                    Hungary               2
# 515722             United Kingdom               2
# 515723                    Croatia               3
# 515724                      India               3
# 515725                     Russia               2
# 515726                     Kosovo               1
# 515727             United Kingdom               1
# 515728                      Qatar               1
# 515729                     Brazil               3
# 515730                     Israel               2
# 515731                    Germany               2
# 515732                     Kuwait               3
# 515733                     Kuwait               2
# 515734                    Estonia               1
# 515735                      Egypt               0
# 515736                     Mexico               3
# 515737                    Hungary               3
#
# [515738 rows x 5 columns]

# %%
def reviewDistbyCity(allCities, hotRevs, nation = ''):
    ctyDF = pd.DataFrame(index=allCities, columns=['Bad', 'Average','Good', 'Excellent'])

    for c in allCities:
        if nation is '':
            c_Mat = hotRevs.loc[hotRevs['City'] == c]
        else:
            c_Mat = hotRevs.loc[(hotRevs['City'] == c)].loc[hotRevs['Reviewer_Nationality'] == nation]
        
        rArr = np.array(c_Mat['Review_Labels'])
        badR = 1.0 * sum(rArr == 0)
        avgR = 1.0 * sum(rArr == 1)
        goodR = 1.0 * sum(rArr == 2)
        excR = 1.0 * sum(rArr  == 3)

        #binRevs = [ np.round(10000 * badR / rArr.shape[0]) / 100, 
        #            np.round(10000 * avgR / rArr.shape[0]) / 100,
        #            np.round(10000 * goodR / rArr.shape[0]) / 100,
        #            np.round(10000 * excR / rArr.shape[0]) / 100]

        binRevs = [ np.round(100 * badR / rArr.shape[0]),
                    np.round(100 * avgR / rArr.shape[0]),
                    np.round(100 * goodR / rArr.shape[0]),
                    np.round(100 * excR / rArr.shape[0])]


        ctyDF['Bad'][c] = binRevs[0]
        ctyDF['Average'][c] = binRevs[1]
        ctyDF['Good'][c] = binRevs[2]
        ctyDF['Excellent'][c] = binRevs[3]

    fig_size = plt.rcParams["figure.figsize"]
 
    fig_size[0] = 15
    fig_size[1] = 7
    ctyDF.plot.bar()
    
    figName = 'City by Percentage of Reviews'
    if nation is not '':
        figName = figName + ' by '+nation+'Nationales'
    plt.title('Distribution of Reviews by City')
    plt.savefig(figName)
    plt.show()

# %%
reviewDistbyCity(cities, hotRevs, nation='')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-21-ef52943be102> in <module>()
# ----> 1 reviewDistbyCity(cities, hotRevs, nation='')
#
# <ipython-input-20-036c45ccc5a6> in reviewDistbyCity(allCities, hotRevs, nation)
#      20         #            np.round(10000 * excR / rArr.shape[0]) / 100]
#      21
# ---> 22         binRevs = [ np.round(100 * badR / rArr.shape[0]),
#      23                     np.round(100 * avgR / rArr.shape[0]),
#      24                     np.round(100 * goodR / rArr.shape[0]),
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# # Average score of Hotels or Cities or Nations by Reviewer Nationality

# %%
def plotRelat(hotelReviews, Type = 'Hotel_Name', Nationality = ' United Kingdom ', Threshold = 100):

    df = hotelReviews[[Type, 'Reviewer_Nationality', 'Reviewer_Score']]
    df = df.loc[df['Reviewer_Nationality'] == Nationality]

    relatNames = list(set(df[Type]))

    print 'Review Data'
    reviewData = []
    for rn in relatNames:
        ratings = np.array(df.loc[df[Type] == rn]['Reviewer_Score'])
        if ratings.shape[0] >= Threshold:
            reviewData.append([rn, np.mean(ratings), np.std(ratings), ratings.shape[0]])
    
    print 'Relative Names and Reviews'
    relNames = []
    relRevs = []
    relStds = []
    for i in reversed(sorted(reviewData, key=itemgetter(1))):
        relNames.append(i[0])
        relRevs.append(i[1])
        relStds.append(i[2])
    
    print 'Plotting'
    
    objects = relNames
    y_pos = np.arange(len(relNames))
    performance = relRevs

    fig_size = plt.rcParams["figure.figsize"]
 
    fig_size[0] = 15
    fig_size[1] = 7

    plt.ylim([0,11])
    plt.bar(y_pos, performance, align='center', alpha=0.5, yerr = relStds)
    plt.xticks(y_pos, objects)
    plt.ylabel('Mean Reviews')
    plt.title('Reviews of'+Nationality+' Nationales by '+Type)

    plt.savefig('Reviews of'+Nationality+' Nationales by '+Type)
    plt.clf()
    #plt.show()

# %% [markdown]
# # Analysis of Cities and Nations by Reviewer Nationalities

# %%
Nats = [' United Kingdom ', ' United States of America ', ' Australia ', ' Ireland ']

for n in Nats:
    #plotRelat(hotelReviews, Type = 'Country', Nationality=n, Threshold=0)
    plotRelat(hotelReviews, Type = 'City', Nationality=n, Threshold=0)
# Out:
# Review Data
# Relative Names and Reviews
# Plotting
# Review Data
# Relative Names and Reviews
# Plotting
# Review Data
# Relative Names and Reviews
# Plotting
# Review Data
# Relative Names and Reviews
# Plotting

# %% [markdown]
# # Average Rating of Hotels From Each City

# %%
cityMeans = []
cityStds = []
for c in allCities:
    hrc = hotelReviews.loc[hotelReviews['City'] == c][['Hotel_Name','Average_Score']]
    hrc = hrc.drop_duplicates()
    cityMeans.append(np.mean(hrc['Average_Score']))
    cityStds.append(np.std(hrc['Average_Score']))
    
fig_size = plt.rcParams["figure.figsize"]
 
fig_size[0] = 15
fig_size[1] = 7

objects = allCities
y_pos = np.arange(len(allCities))
performance = cityMeans

plt.ylim([0,10])
plt.bar(y_pos, performance, align='center', alpha=0.5, yerr=cityStds)
plt.xticks(y_pos, objects)
plt.ylabel('Mean Reviews')
plt.title('Average Hotel Reviews by City')
plt.savefig('Average Hotel Reviews by City')
plt.show()

# %%
cntMeans = []
for c in allCountries:
    hrc = hotelReviews.loc[hotelReviews['Country'] == c][['Hotel_Name','Average_Score']]
    hrc = hrc.drop_duplicates()
    cntMeans.append(np.mean(hrc['Average_Score']))

fig_size = plt.rcParams["figure.figsize"]
 
fig_size[0] = 12
fig_size[1] = 12

objects = allCountries
y_pos = np.arange(len(allCountries))
performance = cntMeans

plt.ylim([0,10])
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Mean Reviews')
plt.title('Average Hotel Reviews by Country')
plt.savefig('Average Hotel Reviews by Country')
plt.show()
