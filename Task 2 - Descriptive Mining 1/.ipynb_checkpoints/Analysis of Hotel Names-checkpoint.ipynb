# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
hotelReviews = pd.read_csv('C:\Users\deniz\Documents\Hotel_Reviews.csv')
hotNames = list(hotelReviews['Hotel_Name'])
hotNames = [i.lower() for i in hotNames]
hotelReviews['Hotel_Name'] = hotNames

# %%
hotNames = hotelReviews['Hotel_Name']
hotNames = hotNames.drop_duplicates()
hotNames = list(hotNames)

# %%
buzzWords = ['Hotel', 'Plaza', 'Grand', 'Suites', 'Spa',
             'Paris', 'Amsterdam', 'London', 'Milan', 'Milano','Roma', 'Barcelona', 'Vienna', 'Wien',
             'Saint', 'City', 'Elys', 'Champs', 'Eiffel', 'Kensington', 'Palace'
             'France', 'Netherlands', 'United Kingdom', 'Italy', 'Spain', 'Austria', 'The', 'tel', 'Park', 'catalonia']
buzzWords = [i.lower() for i in buzzWords]

allWords = []
for h in hotNames:
    #if 'marble' in h.lower().split():
    #    print h
    wordsInName = h.lower().split()
    for w in wordsInName:
        if len(w) > 2 and not w.isdigit() and w not in buzzWords:
            allWords.append(w)

# %%
cnt = Counter(allWords)
cnt.most_common()
# Out:
# [('western', 55),
#  ('best', 55),
#  ('mercure', 50),
#  ('hilton', 43),
#  ('inn', 31),
#  ('novotel', 26),
#  ('marriott', 25),
#  ('holiday', 25),
#  ('collection', 24),
#  ('royal', 22),
#  ('palace', 21),
#  ('villa', 20),
#  ('opera', 18),
#  ('house', 18),
#  ('hotels', 17),
#  ('doubletree', 17),
#  ('square', 16),
#  ('premier', 15),
#  ('tour', 15),
#  ('radisson', 15),
#  ('germain', 15),
#  ('hyde', 15),
#  ('des', 14),
#  ('blu', 14),
#  ('sofitel', 14),
#  ('grange', 14),
#  ('sup', 13),
#  ('montparnasse', 13),
#  ('boutique', 13),
#  ('centre', 13),
#  ('trend', 12),
#  ('luxury', 11),
#  ('h10', 11),
#  ('relais', 11),
#  ('melia', 10),
#  ('plus', 10),
#  ('west', 10),
#  ('starhotels', 10),
#  ('crowne', 10),
#  ('tower', 10),
#  ('gare', 10),
#  ('maison', 10),
#  ('garden', 10),
#  ('les', 10),
#  ('paddington', 9),
#  ('elegancia', 9),
#  ('france', 9),
#  ('club', 9),
#  ('montmartre', 9),
#  ('porte', 9),
#  ('lane', 9),
#  ('edwardian', 9),
#  ('gran', 9),
#  ('hyatt', 8),
#  ('renaissance', 8),
#  ('mayfair', 8),
#  ('design', 8),
#  ('street', 7),
#  ('eurostars', 7),
#  ('arch', 7),
#  ('bloomsbury', 7),
#  ('bridge', 7),
#  ('victoria', 7),
#  ('mgallery', 7),
#  ('place', 7),
#  ('palais', 7),
#  ('court', 7),
#  ('arc', 7),
#  ('esprit', 7),
#  ('diagonal', 7),
#  ('triomphe', 7),
#  ('petit', 6),
#  ('bastille', 6),
#  ('intercontinental', 6),
#  ('louvre', 6),
#  ('etoile', 6),
#  ('marble', 6),
#  ('art', 6),
#  ('elysees', 6),
#  ('chelsea', 6),
#  ('shoreditch', 6),
#  ('center', 6),
#  ('rooms', 6),
#  ('versailles', 6),
#  ('james', 6),
#  ('townhouse', 6),
#  ('lifestyle', 6),
#  ('four', 5),
#  ('golden', 5),
#  ('room', 5),
#  ('tulip', 5),
#  ('millennium', 5),
#  ('faubourg', 5),
#  ('una', 5),
#  ('indigo', 5),
#  ('ramblas', 5),
#  ('port', 5),
#  ('happyculture', 5),
#  ('mar', 5),
#  ('hall', 5),
#  ('george', 5),
#  ('central', 5),
#  ('pullman', 5),
#  ('grands', 5),
#  ('duomo', 5),
#  ('hill', 5),
#  ('trafalgar', 5),
#  ('thistle', 5),
#  ('collezione', 5),
#  ('carlton', 5),
#  ('astotel', 5),
#  ('wharf', 5),
#  ('autograph', 5),
#  ('mate', 5),
#  ('south', 5),
#  ('grosvenor', 4),
#  ('lodge', 4),
#  ('citizenm', 4),
#  ('canary', 4),
#  ('shaftesbury', 4),
#  ('soho', 4),
#  ('only', 4),
#  ('mandarin', 4),
#  ('residence', 4),
#  ('regency', 4),
#  ('casa', 4),
#  ('bercy', 4),
#  ('rive', 4),
#  ('zentrum', 4),
#  ('arena', 4),
#  ('gauche', 4),
#  ('notre', 4),
#  ('vendome', 4),
#  ('knightsbridge', 4),
#  ('ritz', 4),
#  ('dame', 4),
#  ('quarters', 4),
#  ('montcalm', 4),
#  ('sants', 4),
#  ('adults', 4),
#  ('honor', 4),
#  ('hampshire', 4),
#  ('das', 4),
#  ('oriental', 4),
#  ('waterloo', 4),
#  ('marais', 4),
#  ('waldorf', 4),
#  ('vincci', 4),
#  ('lyon', 4),
#  ('wembley', 4),
#  ('cross', 4),
#  ('paul', 4),
#  ('aparthotel', 4),
#  ('boulevards', 4),
#  ('bcn', 4),
#  ('gardens', 4),
#  ('pulitzer', 3),
#  ('end', 3),
#  ('gate', 3),
#  ('ayre', 3),
#  ('expo', 3),
#  ('pancras', 3),
#  ('lancaster', 3),
#  ('nadler', 3),
#  ('majestic', 3),
#  ('san', 3),
#  ('barcel', 3),
#  ('seven', 3),
#  ('metropolitan', 3),
#  ('greenwich', 3),
#  ('jumeirah', 3),
#  ('hoxton', 3),
#  ('catalunya', 3),
#  ('excel', 3),
#  ('notting', 3),
#  ('international', 3),
#  ('apex', 3),
#  ('one', 3),
#  ('and', 3),
#  ('ana', 3),
#  ('tryp', 3),
#  ('piccadilly', 3),
#  ('ilunion', 3),
#  ('regent', 3),
#  ('world', 3),
#  ('apartments', 3),
#  ('regina', 3),
#  ('albar', 3),
#  ('zetter', 3),
#  ('holborn', 3),
#  ('nord', 3),
#  ('alma', 3),
#  ('tribute', 3),
#  ('arthotel', 3),
#  ('lazare', 3),
#  ('monceau', 3),
#  ('station', 3),
#  ('seraphine', 3),
#  ('urban', 3),
#  ('seasons', 3),
#  ('palazzo', 3),
#  ('dorchester', 3),
#  ('pigalle', 3),
#  ('silken', 3),
#  ('mokinba', 3),
#  ('sheraton', 3),
#  ('canal', 3),
#  ('antares', 3),
#  ('mercer', 3),
#  ('coeur', 3),
#  ('suite', 3),
#  ('derby', 3),
#  ('astoria', 3),
#  ('portfolio', 3),
#  ('courtyard', 3),
#  ('vend', 3),
#  ('kings', 3),
#  ('madeleine', 3),
#  ('riverside', 3),
#  ('gruppo', 3),
#  ('westminster', 3),
#  ('minihotel', 2),
#  ('atahotel', 2),
#  ('blue', 2),
#  ('new', 2),
#  ('forum', 2),
#  ('bankside', 2),
#  ('sunotel', 2),
#  ('passeig', 2),
#  ('daniel', 2),
#  ('villette', 2),
#  ('amarante', 2),
#  ('baglioni', 2),
#  ('staybridge', 2),
#  ('maria', 2),
#  ('maitrise', 2),
#  ('fleming', 2),
#  ('bush', 2),
#  ('bar', 2),
#  ('uno', 2),
#  ('shangri', 2),
#  ('portobello', 2),
#  ('catedral', 2),
#  ('jules', 2),
#  ('county', 2),
#  ('buckingham', 2),
#  ('ramada', 2),
#  ('concorde', 2),
#  ('ridien', 2),
#  ('cavendish', 2),
#  ('ealing', 2),
#  ('olympia', 2),
#  ('ville', 2),
#  ('axel', 2),
#  ('franklin', 2),
#  ('bulgari', 2),
#  ('hesperia', 2),
#  ('amadi', 2),
#  ('guoman', 2),
#  ('chiswick', 2),
#  ('arbor', 2),
#  ('antoine', 2),
#  ('docklands', 2),
#  ('michel', 2),
#  ('courthouse', 2),
#  ('teaux', 2),
#  ('hcc', 2),
#  ('orl', 2),
#  ('marina', 2),
#  ('first', 2),
#  ('white', 2),
#  ('bilderberg', 2),
#  ('duquesa', 2),
#  ('ans', 2),
#  ('windsor', 2),
#  ('jardins', 2),
#  ('madison', 2),
#  ('fourside', 2),
#  ('nell', 2),
#  ('museumsquartier', 2),
#  ('amba', 2),
#  ('clayton', 2),
#  ('como', 2),
#  ('senator', 2),
#  ('arts', 2),
#  ('monsieur', 2),
#  ('rembrandt', 2),
#  ('westin', 2),
#  ('rubens', 2),
#  ('sansi', 2),
#  ('styles', 2),
#  ('danube', 2),
#  ('kaiser', 2),
#  ('royale', 2),
#  ('italie', 2),
#  ('regents', 2),
#  ('original', 2),
#  ('sch', 2),
#  ('morgans', 2),
#  ('pavillon', 2),
#  ('small', 2),
#  ('vale', 2),
#  ('legend', 2),
#  ('der', 2),
#  ('dei', 2),
#  ('del', 2),
#  ('pont', 2),
#  ('marylebone', 2),
#  ('acta', 2),
#  ('avenue', 2),
#  ('style', 2),
#  ('olivia', 2),
#  ('westcord', 2),
#  ('meridien', 2),
#  ('blanc', 2),
#  ('leading', 2),
#  ('parc', 2),
#  ('rochester', 2),
#  ('marceau', 2),
#  ('exe', 2),
#  ('vaugirard', 2),
#  ('helzear', 2),
#  ('andaz', 2),
#  ('ohla', 2),
#  ('secret', 2),
#  ('ria', 2),
#  ('maida', 2),
#  ('ambassador', 2),
#  ('atenea', 2),
#  ('claridge', 2),
#  ('prince', 2),
#  ('anna', 2),
#  ('maillot', 2),
#  ('pestana', 2),
#  ('towers', 2),
#  ('islington', 2),
#  ('bianca', 2),
#  ('phine', 2),
#  ('leonardo', 2),
#  ('vondel', 2),
#  ('ibis', 2),
#  ('sina', 2),
#  ('great', 2),
#  ('ducs', 2),
#  ('copthorne', 2),
#  ('nbrunn', 2),
#  ('trocad', 2),
#  ('sir', 2),
#  ('six', 2),
#  ('bassano', 2),
#  ('taj', 2),
#  ('ferdinand', 2),
#  ('cristal', 2),
#  ('savoy', 2),
#  ('manoir', 2),
#  ('superior', 2),
#  ('falkensteiner', 2),
#  ('forest', 2),
#  ('whitechapel', 2),
#  ('stratford', 2),
#  ('bourgogne', 2),
#  ('republique', 2),
#  ('princess', 2),
#  ('yard', 2),
#  ('timhotel', 2),
#  ('sacr', 2),
#  ('galles', 2),
#  ('bel', 2),
#  ('haussmann', 2),
#  ('centro', 2),
#  ('montana', 2),
#  ('gallery', 2),
#  ('abba', 2),
#  ('monumento', 2),
#  ('euston', 2),
#  ('panth', 2),
#  ('jos', 2),
#  ('bristol', 2),
#  ('warwick', 2),
#  ('vinci', 2),
#  ('belvedere', 2),
#  ('napoleon', 2),
#  ('arcotel', 2),
#  ('nation', 2),
#  ('sky', 2),
#  ('eixample', 2),
#  ('adi', 2),
#  ('georges', 2),
#  ('balmoral', 2),
#  ('langham', 2),
#  ('cadet', 2),
#  ('washington', 2),
#  ('van', 2),
#  ('museum', 2),
#  ('imperial', 2),
#  ('apollo', 2),
#  ('marquis', 2),
#  ('balmes', 2),
#  ('raphael', 2),
#  ('pension', 2),
#  ('trocadero', 2),
#  ('zenit', 2),
#  ('aeroporto', 1),
#  ('elisabeth', 1),
#  ('nottingham', 1),
#  ('mirage', 1),
#  ('mansion', 1),
#  ('dukes', 1),
#  ('monfort', 1),
#  ('every', 1),
#  ('25hours', 1),
#  ('manin', 1),
#  ('cavalieri', 1),
#  ('school', 1),
#  ('paume', 1),
#  ('parigi', 1),
#  ('azimut', 1),
#  ('sanderson', 1),
#  ('conservatorium', 1),
#  ('ned', 1),
#  ('liberty', 1),
#  ('icaria', 1),
#  ('bermondsey', 1),
#  ('admiral', 1),
#  ('ako', 1),
#  ('bespoke', 1),
#  ('chateau', 1),
#  ('capricorno', 1),
#  ('marianne', 1),
#  ('gardette', 1),
#  ('mimi', 1),
#  ('sloane', 1),
#  ('atrium', 1),
#  ('straf', 1),
#  ('qualys', 1),
#  ('diputacio', 1),
#  ('oscar', 1),
#  ('georgian', 1),
#  ('shepherds', 1),
#  ('henri', 1),
#  ('serras', 1),
#  ('henry', 1),
#  ('ofelias', 1),
#  ('onix', 1),
#  ('arenberg', 1),
#  ('india', 1),
#  ('arvor', 1),
#  ('hof', 1),
#  ('bonaparte', 1),
#  ('hor', 1),
#  ('gallitzinberg', 1),
#  ('montfleuri', 1),
#  ('lam', 1),
#  ('elizabeth', 1),
#  ('bretagne', 1),
#  ('montague', 1),
#  ('tourville', 1),
#  ('waterfront', 1),
#  ('president', 1),
#  ('souci', 1),
#  ('splendid', 1),
#  ('chambiges', 1),
#  ('green', 1),
#  ('mornington', 1),
#  ('hollmann', 1),
#  ('cannizaro', 1),
#  ('boltons', 1),
#  ('rekord', 1),
#  ('wittmore', 1),
#  ('bryson', 1),
#  ('hidden', 1),
#  ('tourist', 1),
#  ('cristoforo', 1),
#  ('haymarket', 1),
#  ('silver', 1),
#  ('astor', 1),
#  ('sans', 1),
#  ('danubius', 1),
#  ('carlos', 1),
#  ('doelen', 1),
#  ('bonay', 1),
#  ('zuid', 1),
#  ('bourdonnais', 1),
#  ('fairmont', 1),
#  ('unbound', 1),
#  ('raffles', 1),
#  ('evenia', 1),
#  ('fouquet', 1),
#  ('forte', 1),
#  ('schani', 1),
#  ('amstel', 1),
#  ('westside', 1),
#  ('mbit', 1),
#  ('ath', 1),
#  ('gloucester', 1),
#  ('mademoiselle', 1),
#  ('vittoria', 1),
#  ('marigny', 1),
#  ('opernring', 1),
#  ('carlyle', 1),
#  ('goralska', 1),
#  ('nolinski', 1),
#  ('wimberger', 1),
#  ('albert', 1),
#  ('helen', 1),
#  ('newhotel', 1),
#  ('xanadu', 1),
#  ('covent', 1),
#  ('tres', 1),
#  ('powers', 1),
#  ('fashion', 1),
#  ('ral', 1),
#  ('concordia', 1),
#  ('estr', 1),
#  ('beauchamps', 1),
#  ('snob', 1),
#  ('sporthotel', 1),
#  ('landmark', 1),
#  ('boltzmann', 1),
#  ('bradford', 1),
#  ('matins', 1),
#  ('magasins', 1),
#  ('tech', 1),
#  ('enterprise', 1),
#  ('inntel', 1),
#  ('dames', 1),
#  ('amiral', 1),
#  ('orleans', 1),
#  ('cumberland', 1),
#  ('gioia', 1),
#  ('centraal', 1),
#  ('chamberlain', 1),
#  ('fontaine', 1),
#  ('brera', 1),
#  ('fields', 1),
#  ('baviera', 1),
#  ('monumental', 1),
#  ('hauptbahnhof', 1),
#  ('dupond', 1),
#  ('fair', 1),
#  ('athenee', 1),
#  ('clef', 1),
#  ('almirante', 1),
#  ('oceania', 1),
#  ('delphi', 1),
#  ('monhotel', 1),
#  ('rosellon', 1),
#  ('nesplein', 1),
#  ('doppio', 1),
#  ('corinthia', 1),
#  ('omm', 1),
#  ('olimpica', 1),
#  ('ham', 1),
#  ('coq', 1),
#  ('normandie', 1),
#  ('und', 1),
#  ('col', 1),
#  ('lanterne', 1),
#  ('linate', 1),
#  ('levante', 1),
#  ('tophams', 1),
#  ('conference', 1),
#  ('raffaello', 1),
#  ('tamise', 1),
#  ('stadium', 1),
#  ('idol', 1),
#  ('este', 1),
#  ('schloss', 1),
#  ('sanctum', 1),
#  ('lavoisier', 1),
#  ('viii', 1),
#  ('appartement', 1),
#  ('amour', 1),
#  ('amastan', 1),
#  ('belle', 1),
#  ('platine', 1),
#  ('schiller', 1),
#  ('nig', 1),
#  ('vieux', 1),
#  ('dylan', 1),
#  ('u232', 1),
#  ('bellechasse', 1),
#  ('capitol', 1),
#  ('navigli', 1),
#  ('belloy', 1),
#  ('gencia', 1),
#  ('belfast', 1),
#  ('sunflower', 1),
#  ('metropole', 1),
#  ('terrass', 1),
#  ('east', 1),
#  ('blakes', 1),
#  ('rathbone', 1),
#  ('sussex', 1),
#  ('donau', 1),
#  ('bailey', 1),
#  ('malmaison', 1),
#  ('berna', 1),
#  ('picasso', 1),
#  ('arai', 1),
#  ('atmospheres', 1),
#  ('cluny', 1),
#  ('adria', 1),
#  ('mihotel', 1),
#  ('acad', 1),
#  ('old', 1),
#  ('crown', 1),
#  ('maxim', 1),
#  ('born', 1),
#  ('couture', 1),
#  ('chasse', 1),
#  ('ice', 1),
#  ('theresia', 1),
#  ('rossello', 1),
#  ('bains', 1),
#  ('portello', 1),
#  ('huber', 1),
#  ('saxe', 1),
#  ('charing', 1),
#  ('thoumieux', 1),
#  ('pla', 1),
#  ('zur', 1),
#  ('erzherzog', 1),
#  ('wilhelminenberg', 1),
#  ('caspe', 1),
#  ('lapin', 1),
#  ('echiquier', 1),
#  ('emilia', 1),
#  ('jacques', 1),
#  ('otel', 1),
#  ('ananas', 1),
#  ('hallmark', 1),
#  ('licien', 1),
#  ('orsay', 1),
#  ('gis', 1),
#  ('fabric', 1),
#  ('panorama', 1),
#  ('anderson', 1),
#  ('joseph', 1),
#  ('head', 1),
#  ('corendon', 1),
#  ('vitality', 1),
#  ('peninsula', 1),
#  ('westbourne', 1),
#  ('verdi', 1),
#  ('acevi', 1),
#  ('parkring', 1),
#  ('chigwell', 1),
#  ('pelham', 1),
#  ('inclusive', 1),
#  ('peres', 1),
#  ('fuster', 1),
#  ('balzac', 1),
#  ('ship', 1),
#  ('parkhotel', 1),
#  ('kipling', 1),
#  ('schubertring', 1),
#  ('noailles', 1),
#  ('bellevue', 1),
#  ('football', 1),
#  ('andreola', 1),
#  ('marconi', 1),
#  ('pradey', 1),
#  ('juliette', 1),
#  ('egerton', 1),
#  ('glam', 1),
#  ('altstadt', 1),
#  ('roy', 1),
#  ('mill', 1),
#  ('carrobbio', 1),
#  ('providence', 1),
#  ('mermoz', 1),
#  ('passage', 1),
#  ('brown', 1),
#  ('minist', 1),
#  ('spiegeln', 1),
#  ('henrietta', 1),
#  ('scandinavia', 1),
#  ('level', 1),
#  ('die', 1),
#  ('teau', 1),
#  ('guitart', 1),
#  ('cortina', 1),
#  ('camperio', 1),
#  ('alfa', 1),
#  ('grums', 1),
#  ('corner', 1),
#  ('lowndes', 1),
#  ('dikker', 1),
#  ('meli', 1),
#  ('rookery', 1),
#  ('dieci', 1),
#  ('pershing', 1),
#  ('morgan', 1),
#  ('vanderbilt', 1),
#  ('galileo', 1),
#  ('noir', 1),
#  ('buci', 1),
#  ('montebianco', 1),
#  ('rydges', 1),
#  ('wein', 1),
#  ('alte', 1),
#  ('garnier', 1),
#  ('doria', 1),
#  ('bob', 1),
#  ('margot', 1),
#  ('churchill', 1),
#  ('nevern', 1),
#  ('trianon', 1),
#  ('rosewood', 1),
#  ('pera', 1),
#  ('pere', 1),
#  ('domizil', 1),
#  ('rainers', 1),
#  ('aitana', 1),
#  ('downtown', 1),
#  ('rathauspark', 1),
#  ('gregoire', 1),
#  ('wilhelmshof', 1),
#  ('wandl', 1),
#  ('viennart', 1),
#  ('batty', 1),
#  ('irla', 1),
#  ('sercotel', 1),
#  ('vauxhall', 1),
#  ('monge', 1),
#  ('nyx', 1),
#  ('domenico', 1),
#  ('parco', 1),
#  ('lounge', 1),
#  ('edouard', 1),
#  ('alimara', 1),
#  ('may', 1),
#  ('diva', 1),
#  ('mac', 1),
#  ('mae', 1),
#  ('placide', 1),
#  ('gerard', 1),
#  ('vignon', 1),
#  ('sumner', 1),
#  ('comfort', 1),
#  ('beaumont', 1),
#  ('lyric', 1),
#  ('boutiquehotel', 1),
#  ('cityhotel', 1),
#  ('swann', 1),
#  ('blakemore', 1),
#  ('vueling', 1),
#  ('beim', 1),
#  ('edmond', 1),
#  ('villarroel', 1),
#  ('tuileries', 1),
#  ('borrell', 1),
#  ('savoyen', 1),
#  ('roch', 1),
#  ('granados', 1),
#  ('squara', 1),
#  ('marignan', 1),
#  ('kenilworth', 1),
#  ('living', 1),
#  ('mathurin', 1),
#  ('favart', 1),
#  ('dutch', 1),
#  ('albus', 1),
#  ('philharmonie', 1),
#  ('romana', 1),
#  ('excelsior', 1),
#  ('california', 1),
#  ('advance', 1),
#  ('tigra', 1),
#  ('principe', 1),
#  ('devonport', 1),
#  ('oper', 1),
#  ('centrale', 1),
#  ('acca', 1),
#  ('ring', 1),
#  ('little', 1),
#  ('district', 1),
#  ('fiere', 1),
#  ('fiera', 1),
#  ('coburg', 1),
#  ('quay', 1),
#  ('hub', 1),
#  ('heritage', 1),
#  ('cusani', 1),
#  ('antin', 1),
#  ('amister', 1),
#  ('sers', 1),
#  ('constanza', 1),
#  ('westbahnhof', 1),
#  ('josefshof', 1),
#  ('neuville', 1),
#  ('sixtytwo', 1),
#  ('angel', 1),
#  ('breakfast', 1),
#  ('malte', 1),
#  ('gustave', 1),
#  ('riemergasse', 1),
#  ('threadneedles', 1),
#  ('aulivia', 1),
#  ('bastopol', 1),
#  ('ciutadella', 1),
#  ('lut', 1),
#  ('keppler', 1),
#  ('america', 1),
#  ('queens', 1),
#  ('sall', 1),
#  ('occidental', 1),
#  ('senato', 1),
#  ('montagu', 1),
#  ('kaiserhof', 1),
#  ('leicester', 1),
#  ('fifty', 1),
#  ('okura', 1),
#  ('colombo', 1),
#  ('arioso', 1),
#  ('murmuri', 1),
#  ('cadogan', 1),
#  ('varenne', 1),
#  ('saints', 1),
#  ('goodenough', 1),
#  ('sainte', 1),
#  ('spezia', 1),
#  ('theaterhotel', 1),
#  ('ger', 1),
#  ('tocq', 1),
#  ('boundary', 1),
#  ('prime', 1),
#  ('roger', 1),
#  ('beethoven', 1),
#  ('espa', 1),
#  ('college', 1),
#  ('vita', 1),
#  ('aeropuerto', 1),
#  ('giulia', 1),
#  ('athenaeum', 1),
#  ('tsuba', 1),
#  ('clerkenwell', 1),
#  ('panache', 1),
#  ('castiglione', 1),
#  ('magna', 1),
#  ('come', 1),
#  ('recamier', 1),
#  ('spadari', 1),
#  ('montreuil', 1),
#  ('borella', 1),
#  ('pol', 1),
#  ('atenas', 1),
#  ('minihotels', 1),
#  ('atala', 1),
#  ('marc', 1),
#  ('claris', 1),
#  ('putney', 1),
#  ('barri', 1),
#  ('ndsm', 1),
#  ('innkeeper', 1),
#  ('lalit', 1),
#  ('poliziano', 1),
#  ('rathaus', 1),
#  ('former', 1),
#  ('moli', 1),
#  ('mandeville', 1),
#  ('marcel', 1),
#  ('bagu', 1),
#  ('schoenbrunn', 1),
#  ('wimbledon', 1),
#  ('collectionneur', 1),
#  ('sanpi', 1),
#  ('verneuil', 1),
#  ('kube', 1),
#  ('drayton', 1),
#  ('wellington', 1),
#  ('narcisse', 1),
#  ('jufa', 1),
#  ('gates', 1),
#  ('mirabeau', 1),
#  ('sixteen', 1),
#  ('rosa', 1),
#  ('littr', 1),
#  ('thewesley', 1),
#  ('versa', 1),
#  ('plumes', 1),
#  ('negresco', 1),
#  ('tremoille', 1),
#  ('mon', 1),
#  ('roode', 1),
#  ('amr', 1),
#  ('schlosshotel', 1),
#  ('christine', 1),
#  ('edgware', 1),
#  ('vernet', 1),
#  ('ambassade', 1),
#  ('megaro', 1),
#  ('imlauer', 1),
#  ('vondelpark', 1),
#  ('colonial', 1),
#  ('buddha', 1),
#  ('francois', 1),
#  ('metropolis', 1),
#  ('business', 1),
#  ('leeuw', 1),
#  ('seine', 1),
#  ('lombardia', 1),
#  ('brighton', 1),
#  ('ace', 1),
#  ('biblioth', 1),
#  ('road', 1),
#  ('toren', 1),
#  ('brunelleschi', 1),
#  ('artus', 1),
#  ('uptown', 1),
#  ('your', 1),
#  ('strudlhof', 1),
#  ('diana', 1),
#  ('ares', 1),
#  ('stars', 1),
#  ('moscova', 1),
#  ('bulles', 1),
#  ('gore', 1),
#  ('terminus', 1),
#  ('mailberger', 1),
#  ('connaught', 1),
#  ('nasco', 1),
#  ('neri', 1),
#  ('chambre', 1),
#  ('regente', 1),
#  ('rosell', 1),
#  ('lafayette', 1),
#  ('karma', 1),
#  ('pillows', 1),
#  ('pedralbes', 1),
#  ('podium', 1),
#  ('kingsley', 1),
#  ('havana', 1),
#  ('moonlight', 1),
#  ('adam', 1),
#  ('all', 1),
#  ('messe', 1),
#  ('blanche', 1),
#  ('garibaldi', 1),
#  ('clerici', 1),
#  ('guesthouse', 1),
#  ('victoire', 1),
#  ('esther', 1),
#  ('pertschy', 1),
#  ('hallen', 1),
#  ('vere', 1),
#  ('strand', 1),
#  ('norfolk', 1),
#  ('louis', 1),
#  ('beaumarchais', 1),
#  ('lisa', 1),
#  ('auriga', 1),
#  ('ten', 1),
#  ('dokhan', 1),
#  ('victoires', 1),
#  ('zero', 1),
#  ('vilana', 1),
#  ('rafayel', 1),
#  ('reine', 1),
#  ('casual', 1),
#  ('maritim', 1),
#  ('burgundy', 1),
#  ('eitlj', 1),
#  ('solari', 1),
#  ('berkeley', 1),
#  ('barbizon', 1),
#  ('anjou', 1),
#  ('naviglio', 1),
#  ('amadeus', 1),
#  ('cardona', 1),
#  ('via', 1),
#  ('midmost', 1),
#  ('vin', 1),
#  ('tiziano', 1),
#  ('montalembert', 1),
#  ('meurice', 1),
#  ('viu', 1),
#  ('corte', 1),
#  ('select', 1),
#  ('britannia', 1),
#  ('two', 1),
#  ('strauss', 1),
#  ('amedia', 1),
#  ('torre', 1),
#  ('linden', 1),
#  ('diamond', 1),
#  ('horset', 1),
#  ('leonard', 1),
#  ('portman', 1),
#  ('auvergne', 1),
#  ('riverbank', 1),
#  ('chaplain', 1),
#  ('bedford', 1),
#  ('eden', 1),
#  ('roosevelt', 1),
#  ('avo', 1),
#  ('den', 1),
#  ('casanova', 1),
#  ('strathmore', 1),
#  ...]

# %%
allWords = []
for h in hotNames:
    wordsInName = h.lower().split()
    #twoCombs = [wordsInName[i]+' '+wordsInName[i+1] for i in range(len(wordsInName) - 1)]
    for i in range(len(wordsInName) - 1):
        w = wordsInName[i]
        w_p = wordsInName[i + 1]
        #if len(w) > 2 and not w.isdigit(): and w not in buzzWords:
        #    allWords.append(w)
        if len(w) > 2 and not w.isdigit() and w not in buzzWords and len(w_p) > 2 and not w_p.isdigit() and w_p not in buzzWords:
            allWords.append(w+' '+w_p)
            
cnt = Counter(allWords)
cnt.most_common()
# Out:
# [('best western', 55),
#  ('holiday inn', 25),
#  ('radisson blu', 14),
#  ('western premier', 13),
#  ('western plus', 10),
#  ('blu edwardian', 9),
#  ('luxury collection', 7),
#  ('germain des', 6),
#  ('marriott lifestyle', 6),
#  ('marble arch', 6),
#  ('room mate', 5),
#  ('autograph collection', 5),
#  ('golden tulip', 5),
#  ('starhotels collezione', 5),
#  ('mandarin oriental', 4),
#  ('notre dame', 4),
#  ('club quarters', 4),
#  ('grands boulevards', 4),
#  ('rive gauche', 4),
#  ('adults only', 4),
#  ('canary wharf', 3),
#  ('mokinba hotels', 3),
#  ('hyatt regency', 3),
#  ('arthotel ana', 3),
#  ('notting hill', 3),
#  ('trafalgar square', 3),
#  ('four seasons', 3),
#  ('tower bridge', 3),
#  ('maison albar', 3),
#  ('west end', 3),
#  ('petit palace', 3),
#  ('tribute portfolio', 3),
#  ('gare montparnasse', 3),
#  ('dorchester collection', 2),
#  ('royal garden', 2),
#  ('jos phine', 2),
#  ('centre bercy', 2),
#  ('hilton garden', 2),
#  ('sacr coeur', 2),
#  ('orl ans', 2),
#  ('sch nbrunn', 2),
#  ('design boutique', 2),
#  ('ibis styles', 2),
#  ('western maitrise', 2),
#  ('paddington court', 2),
#  ('leading hotels', 2),
#  ('small luxury', 2),
#  ('montmartre sacr', 2),
#  ('garden inn', 2),
#  ('gruppo minihotel', 2),
#  ('grosvenor house', 2),
#  ('centre tour', 2),
#  ('les jardins', 2),
#  ('zetter townhouse', 2),
#  ('kings cross', 2),
#  ('maida vale', 2),
#  ('county hall', 2),
#  ('garibaldi station', 1),
#  ('vincci bit', 1),
#  ('villa opera', 1),
#  ('providence wharf', 1),
#  ('design hotels', 1),
#  ('canary riverside', 1),
#  ('acad mie', 1),
#  ('docklands riverside', 1),
#  ('poliziano fiera', 1),
#  ('club mayfair', 1),
#  ('townhouse galleria', 1),
#  ('eccleston square', 1),
#  ('del mar', 1),
#  ('h10 urquinaona', 1),
#  ('marais grands', 1),
#  ('felice casati', 1),
#  ('temple court', 1),
#  ('premier faubourg', 1),
#  ('adi doria', 1),
#  ('dei cavalieri', 1),
#  ('mischer kaiser', 1),
#  ('chat noir', 1),
#  ('ronda lesseps', 1),
#  ('copthorne tara', 1),
#  ('der wilhelmshof', 1),
#  ('tamise esprit', 1),
#  ('covent garden', 1),
#  ('rey juan', 1),
#  ('banks mansion', 1),
#  ('wellesley knightsbridge', 1),
#  ('sheraton diana', 1),
#  ('evenia rossello', 1),
#  ('carlton tower', 1),
#  ('das tyrol', 1),
#  ('opera cadet', 1),
#  ('das tigra', 1),
#  ('art otel', 1),
#  ('brighton esprit', 1),
#  ('villa des', 1),
#  ('radisson uno', 1),
#  ('tower knightsbridge', 1),
#  ('number sixteen', 1),
#  ('rembrandt square', 1),
#  ('western aulivia', 1),
#  ('eurohotel diagonal', 1),
#  ('twenty nevern', 1),
#  ('san domenico', 1),
#  ('ana prime', 1),
#  ('fuhrgassl huber', 1),
#  ('marriott opera', 1),
#  ('saints peres', 1),
#  ('serhs rivoli', 1),
#  ('eurostars monumental', 1),
#  ('villa alessandra', 1),
#  ('atahotel contessa', 1),
#  ('boutique six', 1),
#  ('derby alma', 1),
#  ('mercer street', 1),
#  ('grange blooms', 1),
#  ('palais strudlhof', 1),
#  ('montagu place', 1),
#  ('centre east', 1),
#  ('villa lut', 1),
#  ('mac mahon', 1),
#  ('edwardian berkshire', 1),
#  ('grange beauchamp', 1),
#  ('bercy gare', 1),
#  ('des ternes', 1),
#  ('barbizon palace', 1),
#  ('silken ramblas', 1),
#  ('residence henri', 1),
#  ('townhouse marylebone', 1),
#  ('grands magasins', 1),
#  ('del naviglio', 1),
#  ('centre canal', 1),
#  ('maison borella', 1),
#  ('abba garden', 1),
#  ('uptown palace', 1),
#  ('worldhotel cristoforo', 1),
#  ('edgware road', 1),
#  ('silken concordia', 1),
#  ('w12 rooms', 1),
#  ('coburg residenz', 1),
#  ('palazzo moscova', 1),
#  ('palazzo segreti', 1),
#  ('ship inn', 1),
#  ('h10 casa', 1),
#  ('edwardian sussex', 1),
#  ('marriott rive', 1),
#  ('mansart esprit', 1),
#  ('jumeirah lowndes', 1),
#  ('pillows anna', 1),
#  ('house chelsea', 1),
#  ('bretagne montparnasse', 1),
#  ('edwardian hampshire', 1),
#  ('sir albert', 1),
#  ('h10 casanova', 1),
#  ('shermin bed', 1),
#  ('van cleve', 1),
#  ('edwardian vanderbilt', 1),
#  ('bel ami', 1),
#  ('acca palace', 1),
#  ('millennium gloucester', 1),
#  ('thistle hyde', 1),
#  ('prater messe', 1),
#  ('casual luxury', 1),
#  ('santa marta', 1),
#  ('cafe royal', 1),
#  ('seraphine hammersmith', 1),
#  ('casa mimosa', 1),
#  ('grange fitzrovia', 1),
#  ('alte donau', 1),
#  ('opera astotel', 1),
#  ('west hyde', 1),
#  ('points sheraton', 1),
#  ('mill sime', 1),
#  ('vita parcour', 1),
#  ('blakemore hyde', 1),
#  ('malte astotel', 1),
#  ('h10 marina', 1),
#  ('montcalm shoreditch', 1),
#  ('mailberger hof', 1),
#  ('plus alfa', 1),
#  ('charlotte street', 1),
#  ('fairmont rey', 1),
#  ('nig von', 1),
#  ('hoxton shoreditch', 1),
#  ('manchester street', 1),
#  ('ana boutique', 1),
#  ('and residences', 1),
#  ('zenit borrell', 1),
#  ('villa olimpica', 1),
#  ('bourgogne montana', 1),
#  ('oriental hyde', 1),
#  ('place vend', 1),
#  ('premier collection', 1),
#  ('paul rive', 1),
#  ('bel art', 1),
#  ('south place', 1),
#  ('new providence', 1),
#  ('morgan mees', 1),
#  ('devonport house', 1),
#  ('india quay', 1),
#  ('alfa aeropuerto', 1),
#  ('bastille boutet', 1),
#  ('locanda dei', 1),
#  ('egerton house', 1),
#  ('starhotels business', 1),
#  ('monfort relais', 1),
#  ('ambassadors bloomsbury', 1),
#  ('mon amour', 1),
#  ('danube waterfront', 1),
#  ('degli arcimboldi', 1),
#  ('waldorf astoria', 1),
#  ('belle juliette', 1),
#  ('nevern square', 1),
#  ('avenue marceau', 1),
#  ('der riemergasse', 1),
#  ('den vondel', 1),
#  ('negresco princess', 1),
#  ('bilderberg garden', 1),
#  ('montparnasse pasteur', 1),
#  ('villa saxe', 1),
#  ('les bulles', 1),
#  ('tuileries relais', 1),
#  ('h10 metropolitan', 1),
#  ('barcel sants', 1),
#  ('forest hill', 1),
#  ('sercotel amister', 1),
#  ('pelham starhotels', 1),
#  ('vice versa', 1),
#  ('batty langley', 1),
#  ('palazzo parigi', 1),
#  ('victoria palace', 1),
#  ('centrale mgallery', 1),
#  ('adria boutique', 1),
#  ('diana majestic', 1),
#  ('blue square', 1),
#  ('una maison', 1),
#  ('washington mayfair', 1),
#  ('edwardian kenilworth', 1),
#  ('aparthotel mariano', 1),
#  ('mate gerard', 1),
#  ('des saints', 1),
#  ('drayton court', 1),
#  ('grange tower', 1),
#  ('splendid etoile', 1),
#  ('marriott maida', 1),
#  ('may fair', 1),
#  ('fifty four', 1),
#  ('breakfast champagne', 1),
#  ('apex temple', 1),
#  ('justin james', 1),
#  ('gran derby', 1),
#  ('grange buckingham', 1),
#  ('gallia luxury', 1),
#  ('royal palace', 1),
#  ('ramada apollo', 1),
#  ('opera grands', 1),
#  ('pavillon des', 1),
#  ('waldorf madeleine', 1),
#  ('well and', 1),
#  ('teau monfort', 1),
#  ('gran via', 1),
#  ('von ungarn', 1),
#  ('severin esprit', 1),
#  ('les dames', 1),
#  ('san siro', 1),
#  ('bed breakfast', 1),
#  ('sans souci', 1),
#  ('plus seraphine', 1),
#  ('sloterdijk station', 1),
#  ('royal horseguards', 1),
#  ('blue tower', 1),
#  ('trianon rive', 1),
#  ('h10 art', 1),
#  ('palace boqueria', 1),
#  ('des academies', 1),
#  ('abac restaurant', 1),
#  ('andreola central', 1),
#  ('victor hugo', 1),
#  ('les rives', 1),
#  ('upper diagonal', 1),
#  ('stendhal place', 1),
#  ('royal monceau', 1),
#  ('bcn design', 1),
#  ('allegro nation', 1),
#  ('premier notting', 1),
#  ('mate giulia', 1),
#  ('dei mercanti', 1),
#  ('wilson boutique', 1),
#  ('lyon tgv', 1),
#  ('bermondsey square', 1),
#  ('western seraphine', 1),
#  ('premier kaiserhof', 1),
#  ('acevi villarroel', 1),
#  ('grange white', 1),
#  ('abbey court', 1),
#  ('western mornington', 1),
#  ('h10 cubik', 1),
#  ('ten manchester', 1),
#  ('palais hansen', 1),
#  ('diagonal mar', 1),
#  ('james court', 1),
#  ('condal mar', 1),
#  ('clef tour', 1),
#  ('thistle euston', 1),
#  ('vincci mae', 1),
#  ('bloomsbury palace', 1),
#  ('tulip washington', 1),
#  ('vincci gala', 1),
#  ('sunotel club', 1),
#  ('luxury hotels', 1),
#  ('exe laietana', 1),
#  ('dorchester dorchester', 1),
#  ('bush boutique', 1),
#  ('newhotel roblin', 1),
#  ('olivia balmes', 1),
#  ('langham court', 1),
#  ('nadler victoria', 1),
#  ('des arts', 1),
#  ('united lodge', 1),
#  ('amister art', 1),
#  ('xenia autograph', 1),
#  ('jan luyken', 1),
#  ('intercontinental amstel', 1),
#  ('hotels gran', 1),
#  ('gates diagonal', 1),
#  ('antica locanda', 1),
#  ('eurostars ramblas', 1),
#  ('hotels montebianco', 1),
#  ('monna lisa', 1),
#  ('hoxton holborn', 1),
#  ('sydney house', 1),
#  ('western allegro', 1),
#  ('villa lafayette', 1),
#  ('club central', 1),
#  ('grupotel gran', 1),
#  ('charing cross', 1),
#  ('western mercedes', 1),
#  ('clayton crown', 1),
#  ('liverpool street', 1),
#  ('gobelins place', 1),
#  ('chelsea harbour', 1),
#  ('art gallery', 1),
#  ('des ducs', 1),
#  ('h10 universitat', 1),
#  ('aparthotel adagio', 1),
#  ('astra opera', 1),
#  ('contessa jolanda', 1),
#  ('les matins', 1),
#  ('van den', 1),
#  ('georgian house', 1),
#  ('boqueria garden', 1),
#  ('western palm', 1),
#  ('sansi pedralbes', 1),
#  ('aiglon esprit', 1),
#  ('britannia international', 1),
#  ('royal trafalgar', 1),
#  ('tulip opera', 1),
#  ('nadler soho', 1),
#  ('cadogan gardens', 1),
#  ('torre catalunya', 1),
#  ('copthorne hotels', 1),
#  ('acta city47', 1),
#  ('boutiquehotel das', 1),
#  ('elysees mermoz', 1),
#  ('marceau bastille', 1),
#  ('wein design', 1),
#  ('barcel raval', 1),
#  ('lapin blanc', 1),
#  ('helzear montparnasse', 1),
#  ('amarante beau', 1),
#  ('visconti palace', 1),
#  ('thijs fenice', 1),
#  ('concorde montparnasse', 1),
#  ('palais coburg', 1),
#  ('all inclusive', 1),
#  ('hansen kempinski', 1),
#  ('juan carlos', 1),
#  ('court executive', 1),
#  ('premier trocadero', 1),
#  ('expo porte', 1),
#  ('arcotel wimberger', 1),
#  ('starhotels ritz', 1),
#  ('edwardian bloomsbury', 1),
#  ('villa maillot', 1),
#  ('parkhotel sch', 1),
#  ('casa fuster', 1),
#  ('atahotel linea', 1),
#  ('fira center', 1),
#  ('des lettres', 1),
#  ('franklin roosevelt', 1),
#  ('pigalle sacre', 1),
#  ('washington opera', 1),
#  ('dorset square', 1),
#  ('blu portman', 1),
#  ('lansbury heritage', 1),
#  ('western tour', 1),
#  ('grange rochester', 1),
#  ('como metropolitan', 1),
#  ('schloss wilhelminenberg', 1),
#  ('ohla eixample', 1),
#  ('pancras renaissance', 1),
#  ('ritz carlton', 1),
#  ('arenas atiram', 1),
#  ('kaiserin elisabeth', 1),
#  ('pont mirabeau', 1),
#  ('maria theresia', 1),
#  ('mate anna', 1),
#  ('leicester square', 1),
#  ('avenue baker', 1),
#  ('grange clarendon', 1),
#  ('honor relais', 1),
#  ('pestana arena', 1),
#  ('anna van', 1),
#  ('western delphi', 1),
#  ('inntel hotels', 1),
#  ('thistle holborn', 1),
#  ('ilunion bel', 1),
#  ('villa eugenie', 1),
#  ('tulip bercy', 1),
#  ('villa emilia', 1),
#  ('pol grace', 1),
#  ('strand palace', 1),
#  ('kaiser franz', 1),
#  ('western atlantic', 1),
#  ('western ducs', 1),
#  ('villa madame', 1),
#  ('portello gruppo', 1),
#  ('elysees astotel', 1),
#  ('sir adam', 1),
#  ('jumeirah carlton', 1),
#  ('montreuil vincennes', 1),
#  ('prince regent', 1),
#  ('trend parkhotel', 1),
#  ('centraal station', 1),
#  ('meridien piccadilly', 1),
#  ('acta atrium', 1),
#  ('boutet mgallery', 1),
#  ('spezia gruppo', 1),
#  ('canal house', 1),
#  ('chateau frontenac', 1),
#  ('little palace', 1),
#  ('diagonal port', 1),
#  ('eurostars cristal', 1),
#  ('okko hotels', 1),
#  ('oxford circus', 1),
#  ('port van', 1),
#  ('trafalgar hilton', 1),
#  ('beau manoir', 1),
#  ('mansion all', 1),
#  ('chiswick rooms', 1),
#  ('arena towers', 1),
#  ('ndsm wharf', 1),
#  ('vres montparnasse', 1),
#  ('levante parliament', 1),
#  ('mate aitana', 1),
#  ('maison souquet', 1),
#  ('atiram hotels', 1),
#  ('gartenhotel altmannsdorf', 1),
#  ('kaiserwasser superior', 1),
#  ('lancaster gate', 1),
#  ('sofitel legend', 1),
#  ('melia white', 1),
#  ('vere devonport', 1),
#  ('les plumes', 1),
#  ('montcalm marble', 1),
#  ('maria palace', 1),
#  ('starhotels anderson', 1),
#  ('h10 port', 1),
#  ('triomphe etoile', 1),
#  ('townhouse clerkenwell', 1),
#  ('die port', 1),
#  ('mercure josefshof', 1),
#  ('port royal', 1),
#  ('comfort inn', 1),
#  ('queens gate', 1),
#  ('villa panth', 1),
#  ('nottingham place', 1),
#  ('duminy vendome', 1),
#  ('biblioth que', 1),
#  ('versailles expo', 1),
#  ('vueling bcn', 1),
#  ('maison favart', 1),
#  ('great northern', 1),
#  ('sherlock holmes', 1),
#  ('shepherds bush', 1),
#  ('opera louvre', 1),
#  ('inn fields', 1),
#  ('shaftesbury metropolis', 1),
#  ('abba sants', 1),
#  ('one aldwych', 1),
#  ('splendide royal', 1),
#  ('street duomo', 1),
#  ('one seven', 1),
#  ('porte maillot', 1),
#  ('petit moulin', 1),
#  ('mercure vaugirard', 1),
#  ('neuville arc', 1),
#  ('white house', 1),
#  ('pars small', 1),
#  ('garbi millenni', 1),
#  ('apollofirst boutique', 1),
#  ('unbound collection', 1),
#  ('crayon rouge', 1),
#  ('mate carla', 1),
#  ('port vell', 1),
#  ('margot house', 1),
#  ('arion cityhotel', 1),
#  ('relais madeleine', 1),
#  ('romana residence', 1),
#  ('premier kapital', 1),
#  ('simply rooms', 1),
#  ('pension baron', 1),
#  ('grange strathmore', 1),
#  ('kings head', 1),
#  ('baltimore tour', 1),
#  ('auvergne opera', 1),
#  ('domenico house', 1),
#  ('chesterfield mayfair', 1),
#  ('royal passeig', 1),
#  ('narcisse blanc', 1),
#  ('occidental atenea', 1),
#  ('brent cross', 1),
#  ('palace museum', 1),
#  ('faubourg montmartre', 1),
#  ('camden lock', 1),
#  ('chelsea football', 1),
#  ('edwardian grafton', 1),
#  ('tower hill', 1),
#  ('western antares', 1),
#  ('waldorf trocad', 1),
#  ('imperial riding', 1),
#  ('bianca maria', 1),
#  ('dorsett shepherds', 1),
#  ('marquis faubourg', 1),
#  ('goodenough club', 1),
#  ('westin palace', 1),
#  ('villa montparnasse', 1),
#  ('relais montmartre', 1),
#  ('lyon bastille', 1),
#  ('centre gare', 1),
#  ('bastille marais', 1),
#  ('starhotels echo', 1),
#  ('collectionneur arc', 1),
#  ('cinq codet', 1),
#  ('front maritim', 1),
#  ('mariano cubi', 1),
#  ('pertschy palais', 1),
#  ('edwardian mercer', 1),
#  ('vincci maritimo', 1),
#  ('waldorf hilton', 1),
#  ('angel islington', 1),
#  ('petersbourg opera', 1),
#  ('zur oper', 1),
#  ('pension arenberg', 1),
#  ('ria bcn', 1),
#  ('football club', 1),
#  ('amadi panorama', 1),
#  ('four boutique', 1),
#  ('norfolk towers', 1),
#  ('jumeirah living', 1),
#  ('court notting', 1),
#  ('francois 1er', 1),
#  ('roode leeuw', 1),
#  ('des tuileries', 1),
#  ('ilunion almirante', 1),
#  ('bercy biblioth', 1),
#  ('ice bar', 1),
#  ('grange wellington', 1),
#  ('marlin waterloo', 1),
#  ('cristoforo colombo', 1),
#  ('four points', 1),
#  ('les halles', 1),
#  ('cannizaro house', 1),
#  ('gran rosellon', 1),
#  ('western bretagne', 1),
#  ('alma boutique', 1),
#  ('orsay esprit', 1),
#  ('townhouse duomo', 1),
#  ('livinghotel kaiser', 1),
#  ('landhaus fuhrgassl', 1),
#  ('james albany', 1),
#  ('mercure secession', 1),
#  ('dupond smith', 1),
#  ('atenea mar', 1),
#  ('old ship', 1),
#  ('cristal palace', 1),
#  ('morgans original', 1),
#  ('rivoli rambla', 1),
#  ('opera garnier', 1),
#  ('eurostars bcn', 1),
#  ('riding school', 1),
#  ('museum quarter', 1),
#  ('canal district', 1),
#  ('villa beaumarchais', 1),
#  ('opera ambassador', 1),
#  ('cordial theaterhotel', 1),
#  ('parc trocadero', 1),
#  ('aparthotel atenea', 1),
#  ('das opernring', 1),
#  ('shaftesbury premier', 1),
#  ('shaftesbury hyde', 1),
#  ('western nouvel', 1),
#  ('and apartments', 1),
#  ('blanche fontaine', 1),
#  ('casa camper', 1),
#  ('maison ath', 1),
#  ('nouvel orl', 1),
#  ('mercedes arc', 1),
#  ('vin cannizaro', 1),
#  ('flemings mayfair', 1),
#  ('executive rooms', 1),
#  ('lane dorchester', 1),
#  ('lazare monceau', 1),
#  ('arena atlas', 1),
#  ('pont royal', 1),
#  ('eurostars embassy', 1),
#  ('westcord fashion', 1),
#  ('royal ramblas', 1),
#  ('carlyle brera', 1),
#  ('villa royale', 1),
#  ('bcn urban', 1),
#  ('edwardian new', 1),
#  ('dutch design', 1),
#  ('sanctum soho', 1),
#  ('gruppo minihotels', 1),
#  ('relais christine', 1),
#  ('suite west', 1),
#  ('portobello house', 1),
#  ('phine bonaparte', 1),
#  ('vaugirard montparnasse', 1),
#  ('inn hackney', 1),
#  ('boundary rooms', 1),
#  ('new linden', 1),
#  ('hotels baviera', 1),
#  ('louvre montana', 1),
#  ('boutique duomo', 1),
#  ('ana westbahn', 1),
#  ('kingsway hall', 1),
#  ('primero primera', 1),
#  ('house wimbledon', 1),
#  ('towers paddington', 1),
#  ('aparthotel arai', 1),
#  ('atrium palace', 1),
#  ('beletage design', 1),
#  ('ans montparnasse', 1),
#  ('9hotel republique', 1),
#  ('montparnasse raspail', 1),
#  ('sunotel central', 1),
#  ('monceau raffles', 1),
#  ('les bains', 1),
#  ('white hall', 1),
#  ('buckingham gate', 1),
#  ('school renaissance', 1),
#  ('sup adults', 1),
#  ('arcotel kaiserwasser', 1),
#  ('grange langham', 1),
#  ('plus amedia', 1),
#  ('plus epping', 1),
#  ('hollmann beletage', 1),
#  ('linea uno', 1),
#  ('johann strauss', 1),
#  ('montcalm royal', 1),
#  ('beim museumsquartier', 1),
#  ('lane mews', 1),
#  ('monsieur cadet', 1),
#  ('western amiral', 1),
#  ('und appartements', 1),
#  ('epping forest', 1),
#  ('west india', 1),
#  ('laietana palace', 1),
#  ('cotton house', 1),
#  ('zentrum schottenfeld', 1),
#  ('western blue', 1),
#  ('design secret', 1),
#  ('sacre coeur', 1),
#  ('camperio house', 1),
#  ('monhotel lounge', 1),
#  ('premier marais', 1),
#  ('westcord art', 1),
#  ('eurostars angli', 1),
#  ('hilton diagonal', 1),
#  ('auteuil tour', 1),
#  ('diagonal zero', 1),
#  ('corendon vitality', 1),
#  ('mercer house', 1),
#  ('westbourne hyde', 1),
#  ('and come', 1),
#  ('grange holborn', 1),
#  ('threadneedles autograph', 1),
#  ('urban lodge', 1),
#  ('prinz eugen', 1),
#  ('derag livinghotel', 1),
#  ('millennium copthorne', 1),
#  ('diva opera', 1),
#  ('strandhotel alte', 1),
#  ('wittmore adults', 1),
#  ('diagonal centro', 1),
#  ('pestana chelsea', 1),
#  ('henley house', 1),
#  ('corte del', 1),
#  ('square louvois', 1),
#  ('westside arc', 1),
#  ('grosvenor square', 1),
#  ('martins lane', 1),
#  ('bastopol astotel', 1),
#  ('hotels king', 1),
#  ('mercure tour', 1),
#  ('peres esprit', 1),
#  ('pershing hall', 1),
#  ('avenida palace', 1),
#  ('sansi diputacio', 1),
#  ('franz joseph', 1),
#  ('trinit haussmann', 1),
#  ('starhotels tourist', 1),
#  ('casa bonay', 1),
#  ('terminus nord', 1),
#  ('westminster bridge', 1),
#  ('monceau wagram', 1),
#  ('karma sanctum', 1),
#  ('palais royal', 1),
#  ('h10 itaca', 1),
#  ('ham yard', 1),
#  ('onix liceo', 1),
#  ('victoire germain', 1),
#  ('bloomsbury street', 1),
#  ('das triest', 1),
#  ('montmartre mon', 1),
#  ('silken gran', 1),
#  ('thistle trafalgar', 1),
#  ('parcour gruppo', 1),
#  ('blu style', 1),
#  ('petit palais', 1),
#  ('hcc regente', 1),
#  ('baker street', 1),
#  ('sloane square', 1),
#  ('arbor hyde', 1),
#  ('chigwell prince', 1),
#  ('opera drouot', 1),
#  ('chelsea bridge', 1),
#  ('seven one', 1),
#  ('canal residence', 1),
#  ('business palace', 1),
#  ('linate aeroporto', 1),
#  ('buddha bar', 1),
#  ('villa haussmann', 1),
#  ('ridien etoile', 1),
#  ('mar adults', 1),
#  ('henry viii', 1),
#  ('windsor opera', 1),
#  ('sainte beuve', 1),
#  ('western madison', 1),
#  ('rathaus wein', 1),
#  ('erzherzog rainer', 1),
#  ('premier louvre', 1),
#  ('former warwick', 1),
#  ('citizenm tower', 1),
#  ('urban hotels', 1),
#  ('victoires opera', 1),
#  ('forte brown', 1),
#  ('magna pars', 1),
#  ('rocco forte', 1)]

# %%
hotelNames = ['Best Western', 'Mercure', 'Hilton','Novotel', 'Marriott', 
'Holiday Inn', 'Luxury Collection', 'NH Collection', 'Starhotels', 
'IH Hotels', 'Autograph Collection', 'Radisson Blu']

hotelNames = [i.lower() for i in hotelNames]

# %%
ctyDF = pd.DataFrame(index=hotelNames, columns=['Bad', 'Average','Good', 'Excellent'])

for h in hotelNames:
    hns = list(hotelReviews['Hotel_Name'])
    hns = [True if h in hn else False for hn in hns]
    hotelMat = hotelReviews[hns]
    hotelMat = hotelMat[['Hotel_Name', 'Reviewer_Score']]
    reviews = hotelMat['Reviewer_Score']
    binRevs = []
    for r in reviews:
        if 0.0 < r <= 4:
            binRevs.append(0)
        elif 4 < r <= 6:
            binRevs.append(1)
        elif 6 < r <= 8:
            binRevs.append(2)
        elif 8 < r <= 10.0:
            binRevs.append(3)
            
    rArr = np.array(np.array(binRevs))
    badR = 1.0 * sum(rArr == 0)
    avgR = 1.0 * sum(rArr == 1)
    goodR = 1.0 * sum(rArr == 2)
    excR = 1.0 * sum(rArr  == 3)

        #binRevs = [ np.round(10000 * badR / rArr.shape[0]) / 100, 
        #            np.round(10000 * avgR / rArr.shape[0]) / 100,
        #            np.round(10000 * goodR / rArr.shape[0]) / 100,
        #            np.round(10000 * excR / rArr.shape[0]) / 100]

    binRevs = [ np.round(100 * badR / rArr.shape[0]),
                np.round(100 * avgR / rArr.shape[0]),
                np.round(100 * goodR / rArr.shape[0]),
                np.round(100 * excR / rArr.shape[0])]


    ctyDF['Bad'][h] = binRevs[0]
    ctyDF['Average'][h] = binRevs[1]
    ctyDF['Good'][h] = binRevs[2]
    ctyDF['Excellent'][h] = binRevs[3]
        
        
    #hotelMat['Review_Labels'] = binRevs
    #hotelMat['Hotel_Name']
    #print h, hotelMat.shape

# %%
fig_size = plt.rcParams["figure.figsize"]
 
fig_size[0] = 15
fig_size[1] = 15
ctyDF.plot.bar()

plt.savefig('Franchise Hotel Review Distributions')
plt.show()
