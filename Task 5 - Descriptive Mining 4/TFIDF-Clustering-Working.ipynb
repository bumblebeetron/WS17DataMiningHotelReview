# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.sparse as sps
import itertools
from sklearn.metrics.pairwise import cosine_similarity
import langid
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
#from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from PIL import Image
import gmaps

# %%
# Change this to whichever CSV YOU WANT. But In the 2nd week, I constructed a csv file that also has the 'City' name column.
# I'm using this csv for simplicity. You can construct the same by following my code in 2nd week.
hotelReviews = pd.read_csv('C:/Users/deniz/Documents/HotelReviewsCountryCity.csv')
cities = ['Paris', 'Amsterdam', 'London', 'Milan', 'Barcelona', 'Vienna']

# %%
def myTokenizer(word, stop_words = stopwords.words('English'), wordLengthThreshold = 1):
    tks = word.split()
    s = []
    for tok in tks:
        if tok not in stop_words and len(tok) > wordLengthThreshold:
            s.append(tok)
    tokens = list(s)
    for i in range(len(s)-1):
        tokens.append(s[i] + ' ' + s[i+1])
    for i in range(len(s)-2):
        tokens.append(s[i] + ' ' + s[i+1] + ' ' + s[i+2])
    return tokens

def myTokenizerIncludingReversed(word, stop_words = stopwords.words('English'), wordLengthThreshold = 1):
    tks = word.split()
    s = []
    for tok in tks:
        if tok not in stop_words and len(tok) > wordLengthThreshold:
            s.append(tok)
    tokens = list(s)
    for i in range(len(s)-1):
        tokens.append(s[i] + ' ' + s[i+1])
        tokens.append(s[i+1] + ' ' + s[i])
    for i in range(len(s)-2):
        tokens.append(s[i] + ' ' + s[i+1] + ' ' + s[i+2])
        tokens.append(s[i] + ' ' + s[i+2] + ' ' + s[i+1])
        tokens.append(s[i+1] + ' ' + s[i] + ' ' + s[i+2])
        tokens.append(s[i+1] + ' ' + s[i+2] + ' ' + s[i])
        tokens.append(s[i+2] + ' ' + s[i] + ' ' + s[i+1])
        tokens.append(s[i+2] + ' ' + s[i+1] + ' ' + s[i])
    return tokens

def myTokenizerWeird(word):
    if word == 'No Positive' or word == 'No Negative':
        return ['']
    stop_words = stopwords.words('English')
    s = [item for sublist in [word.split() for f in re.findall('\d+|\D+',word.lower())] for item in sublist]
    s = [x for x in s if x not in stop_words]
    #tokens = list(s)
    #for i in range(len(s)-1):
    #    tokens.append(s[i] + ' ' + s[i+1])
        #tokens.append(s[i+1] + ' ' + s[i])
    for i in range(len(s)-2):
        tokens.append(s[i] + ' ' + s[i+1] + ' ' + s[i+2])
        #tokens.append(s[i] + ' ' + s[i+2] + ' ' + s[i+1])
        #tokens.append(s[i+1] + ' ' + s[i] + ' ' + s[i+2])
        #tokens.append(s[i+1] + ' ' + s[i+2] + ' ' + s[i])
        #tokens.append(s[i+2] + ' ' + s[i] + ' ' + s[i+1])
        #tokens.append(s[i+2] + ' ' + s[i+1] + ' ' + s[i])
    return tokens

# %%
def getSimilarIndices(cosSim, simThreshold = .8, displayProgress = False):
    simRevs = []

    i = 1
    for index in range(cosSim.shape[0]):
        if i % (cosSim.shape[0]/10) == 0 and displayProgress:
            print '    ', 100 * (1.0 * i / cosSim.shape[0]), '% finished'
        i+=1
        i_0 = np.array(cosSim[index].todense())[0]
        sims = []
        for where in np.argwhere(i_0 > simThreshold):
            if where[0] != index:
                #print where[0], lAPR[where[0]]
                sims.append(where[0])
        simRevs.append([index, sims])
    return simRevs

def getSimilarIndices2(cosSim, simThreshold = .8, displayProgress = False):
    simRevs = []

    i = 1
    for index in range(cosSim.shape[0]):
        if i % (cosSim.shape[0]/10) == 0 and displayProgress:
            print '    ', 100 * (1.0 * i / cosSim.shape[0]), '% finished'
        i+=1
        i_0 = np.array(cosSim[index].todense())[0]
        sims = [index]
        for where in np.argwhere(i_0 > simThreshold):
            if where[0] != index:
                #print where[0], lAPR[where[0]]
                sims.append(where[0])
        simRevs.append(list(np.sort(sims)))
    return simRevs

# %%
def getConnectionMatrix(simRevs, displayProgress = False):
    connectionMatrix = sps.lil_matrix((len(simRevs),len(simRevs))).astype(np.bool)
    i = 1
    for s in simRevs:
        if i % ((len(simRevs))/10) == 0 and displayProgress:
            print '    ', 100 * (1.0 * i / len(simRevs)), '% finished'
        i+=1
        connectionMatrix[np.ones(len(s[1]))*s[0],s[1]] = 1
    return connectionMatrix

def getConnectionMatrix2(simRevs, nMax, displayProgress = False):
    connectionMatrix = sps.lil_matrix((nMax,nMax)).astype(np.bool)
    i = 1
    for s in simRevs:
        if i % ((len(simRevs))/10) == 0 and displayProgress:
            print '    ', 100 * (1.0 * i / len(simRevs)), '% finished'
        i+=1
        for ind in range(len(s)):
            for j in range(ind+1, len(s)-1):
                connectionMatrix[s[ind],s[j]] = 1
                connectionMatrix[s[j],s[ind]] = 1
    return connectionMatrix

# %%
def extractClustersSingleDegree(graphMat, minClusterSize = -1,  displayProgress = False):
    conM = graphMat.copy()
    clusters = []
    iteration = 0
    conSum = conM.sum()
    lastClusterSize = np.inf
    
    while conSum > 0 and lastClusterSize > minClusterSize:
        if displayProgress:
            print "iteration: ", iteration, " conM.sum():", conSum

        maxIndex = np.argmax(np.array(conM.sum(axis=0))[0])
        clusterIndices = np.sort(np.insert(conM[maxIndex,:].nonzero()[1], 0, maxIndex))
        
        cluster = []
        
        for index in clusterIndices:
            cluster.append(np.sort(np.insert(conM[index,:].nonzero()[1], 0, index)))
            
        cluster = np.array(list(set([item for sublist in cluster for item in sublist])))
        clusters.append(cluster)
        conM[cluster,:] = 0
        conM[:,cluster] = 0
        
        iteration += 1
        conSum = conM.sum()
        lastClusterSize = cluster.shape[0]
        
    return clusters

def extractClustersSingleDegree2(graphMat, minClusterSize = -1,  displayProgress = False):
    conM = graphMat.copy()
    clusters = []
    iteration = 0
    conSum = conM.sum()
    lastClusterSize = np.inf
    
    while conSum > 0 and lastClusterSize > minClusterSize:
        if displayProgress:
            print "iteration: ", iteration, " conM.sum():", conSum
            iteration += 1
            
        maxIndex = np.argmax(np.array(conM.sum(axis=0))[0])
        cluster = np.sort(np.insert(conM[maxIndex,:].nonzero()[1], 0, maxIndex))
        
        presize = 0
        
        while presize < cluster.shape[0]:
            presize = cluster.shape[0]
            clsList = list(cluster)
            for c in clsList:
                cluster = np.array(list(set(list(np.hstack([cluster, conM[c,:].nonzero()[1]])))))
                
            conM[cluster,:] = 0
            conM[:,cluster] = 0
            
        clusters.append(cluster)
        conSum = conM.sum()
        lastClusterSize = cluster.shape[0]
    return clusters

# %%
def printGraphImage(graph, fname = 'Image.bmp', sort = False):
    if sort:
        elems = np.array(graph.sum(axis=0))[0]
        sortedIndices = np.argsort(elems)[::-1]
        sortedConG = graph.tocsc()[:,sortedIndices]
        sottedConG = sortedConG.tocsr()[sortedIndices,:]
        sortedConG = sortedConG.tocsc()[:,sortedIndices]
        sortedConG = sortedConG.tolil()
        
    else:
        sortedConG = graph

    dcImg = Image.new('1', sortedConG.shape, color=1)
    pixels = dcImg.load()

    nzs = sortedConG.nonzero()

    for i in range(len(nzs[0])):
        pixels[nzs[0][i], nzs[1][i]] = 0
        
    dcImg.save(fname)

# %%
def clustering(reviews, simThreshold = 0.8, fName1 = 'image1.bmp', fName2='image2.bmp'):

    #featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'), tokenizer=myTokenizer, lowercase=True).fit_transform(allPosRevs)
    #featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'), tokenizer=myTokenizerIncludingReversed, lowercase=True).fit_transform(allPosRevs)
    featureMatrix = TfidfVectorizer(stop_words=None, tokenizer=myTokenizerWeird, lowercase=True).fit_transform(reviews)
    cosSim = cosine_similarity(featureMatrix, Y=None, dense_output=False)
    simRevs = getSimilarIndices(cosSim, simThreshold=simThreshold, displayProgress=True)
    connectionMatrix = getConnectionMatrix(simRevs, displayProgress=True)
    clusters = extractClustersSingleDegree2(connectionMatrix, minClusterSize = 5, displayProgress=True)

    clusterSizes = np.argsort([c.shape[0] for c in clusters])[::-1]
    sortedClusters = [clusters[cls] for cls in clusterSizes]
    sortIndex = np.array([item for sublist in sortedClusters for item in sublist])
    pltP = connectionMatrix[sortIndex,:]
    pltP = pltP[:,sortIndex]
    printGraphImage(pltP, fName1)

    preSorted = np.sort([item for sublist in clusters for item in sublist])
    pltP = connectionMatrix[preSorted,:]
    pltP = pltP[:,preSorted]
    printGraphImage(pltP, fName2)

    return clusters

# %%
clusters = clustering(allPosRevs, simThreshold = 0.5)
# Out:
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
# iteration:  0  conM.sum(): 1079278
# iteration:  1  conM.sum(): 147088
# iteration:  2  conM.sum(): 56186
# iteration:  3  conM.sum(): 45056
# iteration:  4  conM.sum(): 40288
# iteration:  5  conM.sum(): 34754
# iteration:  6  conM.sum(): 29550
# iteration:  7  conM.sum(): 25602
# iteration:  8  conM.sum(): 23050
# iteration:  9  conM.sum(): 21328
# iteration:  10  conM.sum(): 20412
# iteration:  11  conM.sum(): 18772
# iteration:  12  conM.sum(): 17932
# iteration:  13  conM.sum(): 17050
# iteration:  14  conM.sum(): 16238
# iteration:  15  conM.sum(): 15482
# iteration:  16  conM.sum(): 15028
# iteration:  17  conM.sum(): 14428
# iteration:  18  conM.sum(): 13876
# iteration:  19  conM.sum(): 13582
# iteration:  20  conM.sum(): 13076
# iteration:  21  conM.sum(): 12570
# iteration:  22  conM.sum(): 12122
# iteration:  23  conM.sum(): 11660
# iteration:  24  conM.sum(): 11316
# iteration:  25  conM.sum(): 10896
# iteration:  26  conM.sum(): 10652
# iteration:  27  conM.sum(): 10262
# iteration:  28  conM.sum(): 9896
# iteration:  29  conM.sum(): 9662
# iteration:  30  conM.sum(): 9356
# iteration:  31  conM.sum(): 9066
# iteration:  32  conM.sum(): 8878
# iteration:  33  conM.sum(): 8606
# iteration:  34  conM.sum(): 8334
# iteration:  35  conM.sum(): 8180
# iteration:  36  conM.sum(): 8004
# iteration:  37  conM.sum(): 7794
# iteration:  38  conM.sum(): 7640
# iteration:  39  conM.sum(): 7480
# iteration:  40  conM.sum(): 7304
# iteration:  41  conM.sum(): 7122
# iteration:  42  conM.sum(): 6940
# iteration:  43  conM.sum(): 6778
# iteration:  44  conM.sum(): 6650
# iteration:  45  conM.sum(): 6494
# iteration:  46  conM.sum(): 6386
# iteration:  47  conM.sum(): 6180
# iteration:  48  conM.sum(): 6062
# iteration:  49  conM.sum(): 5972
# iteration:  50  conM.sum(): 5842
# iteration:  51  conM.sum(): 5674
# iteration:  52  conM.sum(): 5618
# iteration:  53  conM.sum(): 5520
# iteration:  54  conM.sum(): 5474
# iteration:  55  conM.sum(): 5414
# iteration:  56  conM.sum(): 5324
# iteration:  57  conM.sum(): 5228
# iteration:  58  conM.sum(): 5112
# iteration:  59  conM.sum(): 5042
# iteration:  60  conM.sum(): 4970
# iteration:  61  conM.sum(): 4910
# iteration:  62  conM.sum(): 4828
# iteration:  63  conM.sum(): 4768
# iteration:  64  conM.sum(): 4708
# iteration:  65  conM.sum(): 4646
# iteration:  66  conM.sum(): 4608
# iteration:  67  conM.sum(): 4560
# iteration:  68  conM.sum(): 4490
# iteration:  69  conM.sum(): 4432
# iteration:  70  conM.sum(): 4412
# iteration:  71  conM.sum(): 4372
# iteration:  72  conM.sum(): 4306
# iteration:  73  conM.sum(): 4254
# iteration:  74  conM.sum(): 4210
# iteration:  75  conM.sum(): 4130
# iteration:  76  conM.sum(): 4076
# iteration:  77  conM.sum(): 4018
# iteration:  78  conM.sum(): 3986
# iteration:  79  conM.sum(): 3910
# iteration:  80  conM.sum(): 3866
# iteration:  81  conM.sum(): 3794
# iteration:  82  conM.sum(): 3768
# iteration:  83  conM.sum(): 3726
# iteration:  84  conM.sum(): 3670
# iteration:  85  conM.sum(): 3628
# iteration:  86  conM.sum(): 3590
# iteration:  87  conM.sum(): 3528
# iteration:  88  conM.sum(): 3486
# iteration:  89  conM.sum(): 3450
# iteration:  90  conM.sum(): 3418
# iteration:  91  conM.sum(): 3372
# iteration:  92  conM.sum(): 3342
# iteration:  93  conM.sum(): 3312
# iteration:  94  conM.sum(): 3284
# iteration:  95  conM.sum(): 3260
# iteration:  96  conM.sum(): 3248
# iteration:  97  conM.sum(): 3222
# iteration:  98  conM.sum(): 3186
# iteration:  99  conM.sum(): 3154
# iteration:  100  conM.sum(): 3126
# iteration:  101  conM.sum(): 3096
# iteration:  102  conM.sum(): 3064
# iteration:  103  conM.sum(): 3034
# iteration:  104  conM.sum(): 3004
# iteration:  105  conM.sum(): 2974
# iteration:  106  conM.sum(): 2944
# iteration:  107  conM.sum(): 2912
# iteration:  108  conM.sum(): 2882
# iteration:  109  conM.sum(): 2856
# iteration:  110  conM.sum(): 2832
# iteration:  111  conM.sum(): 2802
# iteration:  112  conM.sum(): 2768
# iteration:  113  conM.sum(): 2740
# iteration:  114  conM.sum(): 2716
# iteration:  115  conM.sum(): 2686
# iteration:  116  conM.sum(): 2666
# iteration:  117  conM.sum(): 2646
# iteration:  118  conM.sum(): 2628
# iteration:  119  conM.sum(): 2598
# iteration:  120  conM.sum(): 2570
# iteration:  121  conM.sum(): 2548
# iteration:  122  conM.sum(): 2536
# iteration:  123  conM.sum(): 2512
# iteration:  124  conM.sum(): 2500
# iteration:  125  conM.sum(): 2488
# iteration:  126  conM.sum(): 2468
# iteration:  127  conM.sum(): 2448
# iteration:  128  conM.sum(): 2428
# iteration:  129  conM.sum(): 2414
# iteration:  130  conM.sum(): 2394

# %%
clusterSizes = np.argsort([c.shape[0] for c in clusters])[::-1]
sortedClusters = [clusters[cls] for cls in clusterSizes]

# %%
for s in sortedClusters[6]:
    print list(allPosRevs)[s]
# Out:
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  everything
#  Everything
#  everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  everything
#  everything
#  Everything
#  Everything
#  Everything
#  everything
#  Everything
#  everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  EVERYTHING
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything
#  Everything

# %%
def connectionMatrix(reviews, simThreshold = 0.8):

    #featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'), tokenizer=myTokenizer, lowercase=True).fit_transform(allPosRevs)
    #featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'), tokenizer=myTokenizerIncludingReversed, lowercase=True).fit_transform(allPosRevs)
    featureMatrix = TfidfVectorizer(stop_words=None, tokenizer=myTokenizerWeird, lowercase=True).fit_transform(reviews)
    cosSim = cosine_similarity(featureMatrix, Y=None, dense_output=False)
    simRevs = getSimilarIndices(cosSim, simThreshold=simThreshold, displayProgress=True)
    connectionMatrix = getConnectionMatrix(simRevs, displayProgress=True)
    return connectionMatrix.tocsr()

# %%
# For this, I've used Only UK reviews on Barcelona. Change it as you wish.
# Don't use more than 30000 texts with the function tho. Because it gets impossible to construct the cos similarity matrix.

#allPosRevs = hotelReviews.loc[(hotelReviews['City'] == 'Barcelona') & (hotelReviews['Reviewer_Nationality'] == ' United Kingdom ') & (hotelReviews['Positive_Review'] != 'No Positive')]['Positive_Review']
allPosRevs = hotelReviews.loc[(hotelReviews['City'] == 'Barcelona') & (hotelReviews['Reviewer_Nationality'] == ' United Kingdom ')]['Positive_Review']

#allPosRevs = hotelReviews['Positive_Review']
#allPosWords = hotelReviews.loc[hotelReviews['Positive_Review'] != 'No Positive']['Positive_Review']
#allReviews = hotelReviews.loc[(hotelReviews['Positive_Review'] != 'No Positive') & (hotelReviews['Negative_Review'] != 'No Negative')][['Positive_Review', 'Negative_Review']]

# %%
allNegRevs = hotelReviews.loc[(hotelReviews['City'] == 'Barcelona') & (hotelReviews['Reviewer_Nationality'] == ' United Kingdom ')]['Negative_Review']

# %%
posConMat = connectionMatrix(allPosRevs, simThreshold=0.5)
# Out:
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished

# %%
sps.save_npz('posConMat05', posConMat)

# %%
negConMat = connectionMatrix(allNegRevs, simThreshold=0.5)
# Out:
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished

# %%
sps.save_npz('negConMat05', negConMat)

# %%
negNonZero = np.vstack([negConMat.nonzero()[0], negConMat.nonzero()[1]]).T
posNonZero = np.vstack([posConMat.nonzero()[0], posConMat.nonzero()[1]]).T

negNonZero.sort(axis = 1)
posNonZero.sort(axis = 1)

# %%
pcmU = posConMat.astype(np.uint8)
ncmU = negConMat.astype(np.uint8)
addition = pcmU + ncmU
row, col, val = sps.find(addition)
r_, c_, v_ = row[val == 2], col[val==2], val[val==2] / 2

# %%
intersMat = sps.lil_matrix(negConMat.shape)
intersMat[r_, c_] = v_

# %%
clusters = extractClustersSingleDegree2(intersMat, minClusterSize = 5, displayProgress=True)
# Out:
# iteration:  0  conM.sum(): 8656.0
# iteration:  1  conM.sum(): 6004.0
# iteration:  2  conM.sum(): 3842.0
# iteration:  3  conM.sum(): 3160.0
# iteration:  4  conM.sum(): 2458.0
# iteration:  5  conM.sum(): 2000.0
# iteration:  6  conM.sum(): 1760.0
# iteration:  7  conM.sum(): 1494.0
# iteration:  8  conM.sum(): 1416.0
# iteration:  9  conM.sum(): 1364.0
# iteration:  10  conM.sum(): 1308.0
# iteration:  11  conM.sum(): 1270.0
# iteration:  12  conM.sum(): 1228.0
# iteration:  13  conM.sum(): 1186.0
# iteration:  14  conM.sum(): 1146.0
# iteration:  15  conM.sum(): 1104.0
# iteration:  16  conM.sum(): 1074.0
# iteration:  17  conM.sum(): 1044.0
# iteration:  18  conM.sum(): 1014.0
# iteration:  19  conM.sum(): 984.0
# iteration:  20  conM.sum(): 954.0
# iteration:  21  conM.sum(): 930.0
# iteration:  22  conM.sum(): 908.0
# iteration:  23  conM.sum(): 886.0

# %%
clusters = extractClustersSingleDegree2(intersMat, minClusterSize = 5, displayProgress=True)

clusterSizes = np.argsort([c.shape[0] for c in clusters])[::-1]
sortedClusters = [clusters[cls] for cls in clusterSizes]
sortIndex = np.array([item for sublist in sortedClusters for item in sublist])
pltP = intersMat[sortIndex,:]
pltP = pltP[:,sortIndex]
printGraphImage(pltP, 'IntersectionSorted05.bmp')

preSorted = np.sort([item for sublist in clusters for item in sublist])
pltP = intersMat[preSorted,:]
pltP = pltP[:,preSorted]
printGraphImage(pltP, 'IntersectionUnSorted05.bmp')
# Out:
# iteration:  0  conM.sum(): 8656.0
# iteration:  1  conM.sum(): 6004.0
# iteration:  2  conM.sum(): 3842.0
# iteration:  3  conM.sum(): 3160.0
# iteration:  4  conM.sum(): 2458.0
# iteration:  5  conM.sum(): 2000.0
# iteration:  6  conM.sum(): 1760.0
# iteration:  7  conM.sum(): 1494.0
# iteration:  8  conM.sum(): 1416.0
# iteration:  9  conM.sum(): 1364.0
# iteration:  10  conM.sum(): 1308.0
# iteration:  11  conM.sum(): 1270.0
# iteration:  12  conM.sum(): 1228.0
# iteration:  13  conM.sum(): 1186.0
# iteration:  14  conM.sum(): 1146.0
# iteration:  15  conM.sum(): 1104.0
# iteration:  16  conM.sum(): 1074.0
# iteration:  17  conM.sum(): 1044.0
# iteration:  18  conM.sum(): 1014.0
# iteration:  19  conM.sum(): 984.0
# iteration:  20  conM.sum(): 954.0
# iteration:  21  conM.sum(): 930.0
# iteration:  22  conM.sum(): 908.0
# iteration:  23  conM.sum(): 886.0

# %%
clid = -4
print len(sortedClusters[clid])
for s in sortedClusters[clid]:
    print list(allPosRevs)[s], '\t\t', list(allNegRevs)[s]
# Out:
# 6
# No Positive 		 No tea or coffee in the room
# No Positive 		 No tea or coffee in the room
# No Positive 		 No tea coffee in room
# No Positive 		 No tea or coffee in the room
# No Positive 		 No tea and coffee in the room
# No Positive 		 Was expecting tea coffee in room

# %%
allRatings = hotelReviews.loc[(hotelReviews['City'] == 'Barcelona') & (hotelReviews['Reviewer_Nationality'] == ' United Kingdom ')]['Reviewer_Score']

# %%
allLocations = hotelReviews.loc[(hotelReviews['City'] == 'Barcelona') & (hotelReviews['Reviewer_Nationality'] == ' United Kingdom ')][['lat','lng']]

# %%
scoreMeans = []
scoreStds = []
for i in range(len(sortedClusters)):
    mean = np.mean(np.array(allRatings)[sortedClusters[i]])
    std = np.std(np.array(allRatings)[sortedClusters[i]])
    scoreMeans.append(mean)
    scoreStds.append(std)

# %%
len(scoreMeans)
# Out:
# 24

# %%
for i in range(len(scoreMeans)):
    print i, '\t', np.round(scoreMeans[i],3),'\t', np.round(scoreStds[i],3)
# Out:
# 0 	9.842 	0.463
# 1 	8.709 	1.083
# 2 	9.195 	0.782
# 3 	9.259 	0.805
# 4 	9.77 	0.572
# 5 	9.421 	0.553
# 6 	9.461 	0.456
# 7 	9.281 	0.775
# 8 	9.4 	0.564
# 9 	9.075 	0.779
# 10 	9.7 	0.332
# 11 	9.7 	0.387
# 12 	9.75 	0.397
# 13 	9.229 	0.726
# 14 	9.6 	0.478
# 15 	7.914 	1.688
# 16 	8.571 	0.565
# 17 	9.117 	1.175
# 18 	9.25 	0.61
# 19 	8.15 	1.198
# 20 	7.633 	1.291
# 21 	9.733 	0.442
# 22 	9.667 	0.427
# 23 	8.76 	1.454

# %%
allLoc = np.array(allLocations)
clusterMap = []
for s in sortedClusters[2]:
    if not np.isnan(allLoc[s][0]) and not np.isnan(allLoc[s][1]):
        clusterMap.append(allLoc[s])

# %%
gmaps.configure(api_key="AIzaSyArnYbqE3btwnUDKiUWfFujTGKkjH2bbCY")

fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(clusterMap, max_intensity = 1, point_radius=15))
fig
# Out:
# Figure()

# %%
posClusters = clustering(allPosRevs, fName1='Positive_Clustered.bmp', fName2='Positive_UnClustered.bmp')
# Out:
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
# iteration:  0  conM.sum(): 1079278
# iteration:  1  conM.sum(): 147088
# iteration:  2  conM.sum(): 56186
# iteration:  3  conM.sum(): 45056
# iteration:  4  conM.sum(): 40288
# iteration:  5  conM.sum(): 34754
# iteration:  6  conM.sum(): 29550
# iteration:  7  conM.sum(): 25602
# iteration:  8  conM.sum(): 23050
# iteration:  9  conM.sum(): 21328
# iteration:  10  conM.sum(): 20412
# iteration:  11  conM.sum(): 18772
# iteration:  12  conM.sum(): 17932
# iteration:  13  conM.sum(): 17050
# iteration:  14  conM.sum(): 16238
# iteration:  15  conM.sum(): 15482
# iteration:  16  conM.sum(): 15028
# iteration:  17  conM.sum(): 14428
# iteration:  18  conM.sum(): 13876
# iteration:  19  conM.sum(): 13582
# iteration:  20  conM.sum(): 13076
# iteration:  21  conM.sum(): 12570
# iteration:  22  conM.sum(): 12122
# iteration:  23  conM.sum(): 11660
# iteration:  24  conM.sum(): 11316
# iteration:  25  conM.sum(): 10896
# iteration:  26  conM.sum(): 10652
# iteration:  27  conM.sum(): 10262
# iteration:  28  conM.sum(): 9896
# iteration:  29  conM.sum(): 9662
# iteration:  30  conM.sum(): 9356
# iteration:  31  conM.sum(): 9066
# iteration:  32  conM.sum(): 8878
# iteration:  33  conM.sum(): 8606
# iteration:  34  conM.sum(): 8334
# iteration:  35  conM.sum(): 8180
# iteration:  36  conM.sum(): 8004
# iteration:  37  conM.sum(): 7794
# iteration:  38  conM.sum(): 7640
# iteration:  39  conM.sum(): 7480
# iteration:  40  conM.sum(): 7304
# iteration:  41  conM.sum(): 7122
# iteration:  42  conM.sum(): 6940
# iteration:  43  conM.sum(): 6778
# iteration:  44  conM.sum(): 6650
# iteration:  45  conM.sum(): 6494
# iteration:  46  conM.sum(): 6386
# iteration:  47  conM.sum(): 6180
# iteration:  48  conM.sum(): 6062
# iteration:  49  conM.sum(): 5972
# iteration:  50  conM.sum(): 5842
# iteration:  51  conM.sum(): 5674
# iteration:  52  conM.sum(): 5618
# iteration:  53  conM.sum(): 5520
# iteration:  54  conM.sum(): 5474
# iteration:  55  conM.sum(): 5414
# iteration:  56  conM.sum(): 5324
# iteration:  57  conM.sum(): 5228
# iteration:  58  conM.sum(): 5112
# iteration:  59  conM.sum(): 5042
# iteration:  60  conM.sum(): 4970
# iteration:  61  conM.sum(): 4910
# iteration:  62  conM.sum(): 4828
# iteration:  63  conM.sum(): 4768
# iteration:  64  conM.sum(): 4708
# iteration:  65  conM.sum(): 4646
# iteration:  66  conM.sum(): 4608
# iteration:  67  conM.sum(): 4560
# iteration:  68  conM.sum(): 4490
# iteration:  69  conM.sum(): 4432
# iteration:  70  conM.sum(): 4412
# iteration:  71  conM.sum(): 4372
# iteration:  72  conM.sum(): 4306
# iteration:  73  conM.sum(): 4254
# iteration:  74  conM.sum(): 4210
# iteration:  75  conM.sum(): 4130
# iteration:  76  conM.sum(): 4076
# iteration:  77  conM.sum(): 4018
# iteration:  78  conM.sum(): 3986
# iteration:  79  conM.sum(): 3910
# iteration:  80  conM.sum(): 3866
# iteration:  81  conM.sum(): 3794
# iteration:  82  conM.sum(): 3768
# iteration:  83  conM.sum(): 3726
# iteration:  84  conM.sum(): 3670
# iteration:  85  conM.sum(): 3628
# iteration:  86  conM.sum(): 3590
# iteration:  87  conM.sum(): 3528
# iteration:  88  conM.sum(): 3486
# iteration:  89  conM.sum(): 3450
# iteration:  90  conM.sum(): 3418
# iteration:  91  conM.sum(): 3372
# iteration:  92  conM.sum(): 3342
# iteration:  93  conM.sum(): 3312
# iteration:  94  conM.sum(): 3284
# iteration:  95  conM.sum(): 3260
# iteration:  96  conM.sum(): 3248
# iteration:  97  conM.sum(): 3222
# iteration:  98  conM.sum(): 3186
# iteration:  99  conM.sum(): 3154
# iteration:  100  conM.sum(): 3126
# iteration:  101  conM.sum(): 3096
# iteration:  102  conM.sum(): 3064
# iteration:  103  conM.sum(): 3034
# iteration:  104  conM.sum(): 3004
# iteration:  105  conM.sum(): 2974
# iteration:  106  conM.sum(): 2944
# iteration:  107  conM.sum(): 2912
# iteration:  108  conM.sum(): 2882
# iteration:  109  conM.sum(): 2856
# iteration:  110  conM.sum(): 2832
# iteration:  111  conM.sum(): 2802
# iteration:  112  conM.sum(): 2768
# iteration:  113  conM.sum(): 2740
# iteration:  114  conM.sum(): 2716
# iteration:  115  conM.sum(): 2686
# iteration:  116  conM.sum(): 2666
# iteration:  117  conM.sum(): 2646
# iteration:  118  conM.sum(): 2628
# iteration:  119  conM.sum(): 2598
# iteration:  120  conM.sum(): 2570
# iteration:  121  conM.sum(): 2548
# iteration:  122  conM.sum(): 2536
# iteration:  123  conM.sum(): 2512
# iteration:  124  conM.sum(): 2500
# iteration:  125  conM.sum(): 2488
# iteration:  126  conM.sum(): 2468
# iteration:  127  conM.sum(): 2448
# iteration:  128  conM.sum(): 2428
# iteration:  129  conM.sum(): 2414
# iteration:  130  conM.sum(): 2394

# %%
negClusters = clustering(allNegRevs, fName1='Negative_Clustered.bmp', fName2='Negative_UnClustered.bmp')
# Out:
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-bb8754a9ed39> in <module>()
# ----> 1 negClusters = clustering(allNegRevs, fName1='Negative_Clustered.bmp', fName2='Negative_UnClustered.bmp')
#
# <ipython-input-8-163e940c8b9b> in clustering(reviews, fName1, fName2)
#       6     cosSim = cosine_similarity(featureMatrix, Y=None, dense_output=False)
#       7     simRevs = getSimilarIndices(cosSim, simThreshold=0.5, displayProgress=True)
# ----> 8     connectionMatrix = getConnectionMatrix(simRevs, displayProgress=True)
#       9     clusters = extractClustersSingleDegree2(connectionMatrix, minClusterSize = 5, displayProgress=True)
#      10
#
# <ipython-input-5-649ac4618d2b> in getConnectionMatrix(simRevs, displayProgress)
#       8         ind = s[0]
#       9         for j in s[1]:
# ---> 10             connectionMatrix[ind,j] = 1
#      11     return connectionMatrix
#      12
#
# C:\ProgramData\Anaconda2\lib\site-packages\scipy\sparse\lil.py in __setitem__(self, index, x)
#     340             # with fancy indexing.
#     341             if ((isinstance(i, int) or isinstance(i, np.integer)) and
# --> 342                     (isinstance(j, int) or isinstance(j, np.integer))):
#     343                 x = self.dtype.type(x)
#     344                 if x.size > 1:
#
# KeyboardInterrupt:

# %%
reviews = allNegRevs
featureMatrix = TfidfVectorizer(stop_words=None, tokenizer=myTokenizerWeird, lowercase=True).fit_transform(reviews)
cosSim = cosine_similarity(featureMatrix, Y=None, dense_output=False)

# %%
simRevs = getSimilarIndices(cosSim, simThreshold=0.8, displayProgress=True)
# Out:
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished

# %%
connectionMatrix = getConnectionMatrix(simRevs, displayProgress=True)
# Out:
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished

# %%
unifiedclusters = extractClustersSingleDegree2(connectionMatrix*connectionMatrixPos, minClusterSize = 5, displayProgress=True)
# Out:
# iteration:  0  conM.sum(): 16322195
# C:\ProgramData\Anaconda2\lib\site-packages\scipy\sparse\compressed.py:774: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   SparseEfficiencyWarning)

# %%
connectionMatrix*connectionMatrixPos
# Out:
# <20803x20803 sparse matrix of type '<type 'numpy.bool_'>'
# 	with 16322195 stored elements in Compressed Sparse Row format>

# %%
connectionMatrix
# Out:
# <20803x20803 sparse matrix of type '<type 'numpy.bool_'>'
# 	with 28869734 stored elements in LInked List format>

# %%
connectionMatrixPos
# Out:
# <20803x20803 sparse matrix of type '<type 'numpy.bool_'>'
# 	with 1057578 stored elements in LInked List format>

# %%
reviews = allPosRevs

# %%
featureMatrixPos = TfidfVectorizer(stop_words=None, tokenizer=myTokenizerWeird, lowercase=True).fit_transform(reviews)

# %%
cosSimPos = cosine_similarity(featureMatrixPos, Y=None, dense_output=False)

# %%
simRevsPos = getSimilarIndices(cosSimPos, simThreshold=0.8, displayProgress=True)
# Out:
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished

# %%
def getConnectionMatrix3(simRevs, displayProgress = False):
    connectionMatrix = sps.lil_matrix((len(simRevs),len(simRevs))).astype(np.bool)
    i = 1
    for s in simRevs:
        if i % ((len(simRevs))/10) == 0 and displayProgress:
            print '    ', 100 * (1.0 * i / len(simRevs)), '% finished'
        i+=1
        connectionMatrix[np.ones(len(s[1]))*s[0],s[1]] = 1
    return connectionMatrix

# %% [markdown]
# # LIMIT HERE!

# %%
clusters = extractClustersSingleDegree2(connectionMatrix, minClusterSize = 5, displayProgress=True)

# %%
clusterSizes = np.argsort([c.shape[0] for c in clusters])[::-1]
sortedClusters = [clusters[cls] for cls in clusterSizes]
sortIndex = np.array([item for sublist in sortedClusters for item in sublist])
pltP = connectionMatrix[sortIndex,:]
pltP = pltP[:,sortIndex]
printGraphImage(pltP, fName1)

preSorted = np.sort([item for sublist in clusters for item in sublist])
pltP = connectionMatrix[preSorted,:]
pltP = pltP[:,preSorted]
printGraphImage(pltP, fName2)

# %%
kMeansClusters = [[] for i in range(K)]
kSimilarities = cosine_similarity(featureMatrix, kMeans)
relClusters = np.argmax(kSimilarities,axis = 1)
revIndex = 0
for r in relClusters:
    kMeansClusters[r].append(revIndex)
    revIndex += 1

kMeans = []
for cluster in kMeansClusters:
    kMeans.append(np.array(featureMatrix[cluster,:].sum(axis = 0))[0])
    
for k in kMeansClusters:
    print len(k)
# Out:
# 1015
# 876
# 519
# 1205
# 290
# 593
# 691
# 370
# 732
# 856
# 290
# 363
# 226
# 331
# 558
# 1873
# 844
# 983
# 248
# 575
# 774
# 1477
# 1195
# 414
# 308
# 76
# 210
# 391
# 58
# 286
# 289
# 25
# 346
# 158
# 1358

# %%
clusterSizes = np.argsort([len(c) for c in kMeansClusters])[::-1]
sortedClusters = [kMeansClusters[cls] for cls in clusterSizes]
sortIndex = np.array([item for sublist in sortedClusters for item in sublist])
pltP = featureMatrix[sortIndex,:]
pltP = pltP[:,sortIndex]
printGraphImage(pltP, 'kMEans_clustered_3Shingle_MinS10.bmp')

# %%
for s in kMeansClusters[0]:
    print list(allPosRevs)[s]
# Out:
# No Positive
#  Only positive I can think of is the location
# No Positive
#
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  We didn t
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Everythink
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Being there
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Genuine staff who wanted to be there and were happy to be on hand to help Lovely atmosphere around the hotel relaxed and positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  All
# No Positive
# No Positive
# No Positive
# No Positive
#  Well the biggest positive is their location It s at Eixample which is at a stone s throw away from Plaza Catalonya and that means you are at a walking distance from every major place inside the city whether it s the Ramblas or the marina Their breakfast spread was quite decent and the staff managing the cafeteria are very pleasant
# No Positive
#  Everthing
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Unhygienic uncomfortable and disgusting
#  the
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  There were varieties of fruits and brown breads
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  All of it
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  The loocation
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  N a
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  It was oerfect
# No Positive
#  All of it
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  evertything
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  all
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  All of it
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Won der ful
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#
#
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Ch
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Locatiom
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  I
#  georgeous
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  the functionality
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  The sevice
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  All
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Jaquzi
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Lo ation
#
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  all
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Everythink
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  All of it
# No Positive
# No Positive
# No Positive
# No Positive
#  All
# No Positive
# No Positive
# No Positive
#  only sweming poole
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Locaation
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  All
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#
# No Positive
#  N A
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  All of it
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Evriting
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  Everthing
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
#  The staff were so welcoming ready to help always positive
# No Positive
# No Positive
# No Positive
# No Positive
#  The only positive thing about this hotel was the water in the fridge
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive
# No Positive

# %%
def getConnectivityGraph(reviews, simThreshold = .8, displayProgress = False, wordLengthThreshold = 3, stopWordList = stopwords.words('English'), getTFIDFMatrix = False):
    if displayProgress:
        print "Extracting Important Texts"
    rwl = reviewWordList(reviews, wordLengthThreshold = 3, stopWordList = stopwords.words('English'), displayProgress=displayProgress)
    
    if displayProgress:
        print "Constructing Feature Matrix"
    featureMatrix = TfidfVectorizer(stop_words=stopwords.words('English'), vocabulary=rwl).fit_transform(reviews)
    
    if displayProgress:
        print "Constructing Cosine Similarity Matrix"
    cosSim = cosine_similarity(featureMatrix, Y=None, dense_output=False)
    
    if displayProgress:
        print "Extracting Similar Reviews"
    simRevs = getSimilarIndices(cosSim, simThreshold=simThreshold, displayProgress=displayProgress)
    
    if displayProgress:
        print "Constructing Connectivity Graph"
        connectionMatrix = getConnectionMatrix(simRevs, displayProgress=displayProgress)
        
    return connectionMatrix

# %%
def extractClusters(graphMat, displayProgress = False):
    conM = graphMat.copy()
    clusters = []
    iteration = 0
    conSum = conM.sum()
    while conSum > 0:
        if displayProgress:
            print "iteration: ", iteration, " conM.sum():", conSum

        index = np.argmax(np.array(conM.sum(axis=0))[0])
        cluster = np.sort(np.insert(conM[index,:].nonzero()[1], 0, index))
        clusters.append(cluster)
        conM[cluster,:] = 0
        conM[:,cluster] = 0
        iteration += 1
        conSum = conM.sum()
        
    return clusters

# %%
def extractClustersExtensive(graphMat, minClusterSize = -1,  displayProgress = False):
    conM = graphMat.copy()
    clusters = []
    iteration = 0
    conSum = conM.sum()
    lastClusterSize = np.inf
    
    while conSum > 0 and lastClusterSize > minClusterSize:
        if displayProgress:
            print "iteration: ", iteration, " conM.sum():", conSum

        connectionSums = np.array(conM.sum(axis=0))[0]
        maxCon = np.max(connectionSums)
        indices = np.where(connectionSums == maxCon)
        
        cluster = []
        
        for index in indices:
            cluster.append(np.sort(np.insert(conM[index,:].nonzero()[1], 0, index)))
            
        cluster = np.array(list(set([item for sublist in cluster for item in sublist])))
        clusters.append(cluster)
        conM[cluster,:] = 0
        conM[:,cluster] = 0
        
        iteration += 1
        conSum = conM.sum()
        lastClusterSize = cluster.shape[0]
        
    return clusters

# %%
def extractClustersExtensive(graphMat, minClusterSize = -1,  displayProgress = False):
    conM = graphMat.copy()
    clusters = []
    iteration = 0
    conSum = conM.sum()
    lastClusterSize = np.inf
    
    while conSum > 0 and lastClusterSize > minClusterSize:
        if displayProgress:
            print "iteration: ", iteration, " conM.sum():", conSum

        connectionSums = np.array(conM.sum(axis=0))[0]
        maxCon = np.max(connectionSums)
        indices = np.where(connectionSums == maxCon)
        
        cluster = []
        
        for index in indices:
            cluster.append(np.sort(np.insert(conM[index,:].nonzero()[1], 0, index)))
            
        cluster = np.array(list(set([item for sublist in cluster for item in sublist])))
        clusters.append(cluster)
        conM[cluster,:] = 0
        conM[:,cluster] = 0
        
        iteration += 1
        conSum = conM.sum()
        lastClusterSize = cluster.shape[0]
        
    return clusters

# %%
connectivityGraph = getConnectivityGraph(allPosRevs, simThreshold = .8, displayProgress=True)
# Out:
# Extracting Important Texts
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
# Constructing Feature Matrix
# Constructing Cosine Similarity Matrix
# Extracting Similar Reviews
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished
# Constructing Connectivity Graph
#      9.9985579003 % finished
#      19.9971158006 % finished
#      29.9956737009 % finished
#      39.9942316012 % finished
#      49.9927895015 % finished
#      59.9913474018 % finished
#      69.9899053021 % finished
#      79.9884632024 % finished
#      89.9870211027 % finished
#      99.985579003 % finished

# %%
clusters = extractClustersSingleDegree(connectivityGraph, minClusterSize = 5, displayProgress=True)
# Out:
# iteration:  0  conM.sum(): 1154692
# iteration:  1  conM.sum(): 222502
# iteration:  2  conM.sum(): 115246
# iteration:  3  conM.sum(): 96178
# iteration:  4  conM.sum(): 75238
# iteration:  5  conM.sum(): 60552
# iteration:  6  conM.sum(): 48630
# iteration:  7  conM.sum(): 42290
# iteration:  8  conM.sum(): 38612
# iteration:  9  conM.sum(): 36062
# iteration:  10  conM.sum(): 34012
# iteration:  11  conM.sum(): 32152
# iteration:  12  conM.sum(): 30366
# iteration:  13  conM.sum(): 28884
# iteration:  14  conM.sum(): 27582
# iteration:  15  conM.sum(): 26172
# iteration:  16  conM.sum(): 25196
# iteration:  17  conM.sum(): 24348
# iteration:  18  conM.sum(): 23390
# iteration:  19  conM.sum(): 22602
# iteration:  20  conM.sum(): 21764
# iteration:  21  conM.sum(): 20920
# iteration:  22  conM.sum(): 20050
# iteration:  23  conM.sum(): 19246
# iteration:  24  conM.sum(): 18432
# iteration:  25  conM.sum(): 17754
# iteration:  26  conM.sum(): 17104
# iteration:  27  conM.sum(): 16588
# iteration:  28  conM.sum(): 15934
# iteration:  29  conM.sum(): 15388
# iteration:  30  conM.sum(): 14824
# iteration:  31  conM.sum(): 14154
# iteration:  32  conM.sum(): 13614
# iteration:  33  conM.sum(): 13104
# iteration:  34  conM.sum(): 12628
# iteration:  35  conM.sum(): 12290
# iteration:  36  conM.sum(): 11964
# iteration:  37  conM.sum(): 11458
# iteration:  38  conM.sum(): 11038
# iteration:  39  conM.sum(): 10756
# iteration:  40  conM.sum(): 10402
# iteration:  41  conM.sum(): 10016
# iteration:  42  conM.sum(): 9666
# iteration:  43  conM.sum(): 9290
# iteration:  44  conM.sum(): 9052
# iteration:  45  conM.sum(): 8788
# iteration:  46  conM.sum(): 8542
# iteration:  47  conM.sum(): 8336
# iteration:  48  conM.sum(): 8100
# iteration:  49  conM.sum(): 7854
# iteration:  50  conM.sum(): 7654
# iteration:  51  conM.sum(): 7486
# iteration:  52  conM.sum(): 7270
# iteration:  53  conM.sum(): 7060
# iteration:  54  conM.sum(): 6924
# iteration:  55  conM.sum(): 6770
# iteration:  56  conM.sum(): 6634
# iteration:  57  conM.sum(): 6516
# iteration:  58  conM.sum(): 6320
# iteration:  59  conM.sum(): 6168
# iteration:  60  conM.sum(): 6044
# iteration:  61  conM.sum(): 5938
# iteration:  62  conM.sum(): 5836
# iteration:  63  conM.sum(): 5774
# iteration:  64  conM.sum(): 5684
# iteration:  65  conM.sum(): 5568
# iteration:  66  conM.sum(): 5490
# iteration:  67  conM.sum(): 5412
# iteration:  68  conM.sum(): 5312
# iteration:  69  conM.sum(): 5220
# iteration:  70  conM.sum(): 5138
# iteration:  71  conM.sum(): 5048
# iteration:  72  conM.sum(): 4982
# iteration:  73  conM.sum(): 4850
# iteration:  74  conM.sum(): 4778
# iteration:  75  conM.sum(): 4696
# iteration:  76  conM.sum(): 4646
# iteration:  77  conM.sum(): 4556
# iteration:  78  conM.sum(): 4496
# iteration:  79  conM.sum(): 4438
# iteration:  80  conM.sum(): 4362
# iteration:  81  conM.sum(): 4256
# iteration:  82  conM.sum(): 4182
# iteration:  83  conM.sum(): 4112
# iteration:  84  conM.sum(): 4048
# iteration:  85  conM.sum(): 3986
# iteration:  86  conM.sum(): 3916
# iteration:  87  conM.sum(): 3878
# iteration:  88  conM.sum(): 3822
# iteration:  89  conM.sum(): 3758
# iteration:  90  conM.sum(): 3728
# iteration:  91  conM.sum(): 3674
# iteration:  92  conM.sum(): 3636
# iteration:  93  conM.sum(): 3596
# iteration:  94  conM.sum(): 3544
# iteration:  95  conM.sum(): 3488
# iteration:  96  conM.sum(): 3426
# iteration:  97  conM.sum(): 3372
# iteration:  98  conM.sum(): 3336
# iteration:  99  conM.sum(): 3312
# iteration:  100  conM.sum(): 3284
# iteration:  101  conM.sum(): 3240
# iteration:  102  conM.sum(): 3184
# iteration:  103  conM.sum(): 3142
# iteration:  104  conM.sum(): 3106
# iteration:  105  conM.sum(): 3060
# iteration:  106  conM.sum(): 3020
# iteration:  107  conM.sum(): 2984
# iteration:  108  conM.sum(): 2946
# iteration:  109  conM.sum(): 2914
# iteration:  110  conM.sum(): 2872
# iteration:  111  conM.sum(): 2834
# iteration:  112  conM.sum(): 2806
# iteration:  113  conM.sum(): 2774
# iteration:  114  conM.sum(): 2742
# iteration:  115  conM.sum(): 2720
# iteration:  116  conM.sum(): 2680
# iteration:  117  conM.sum(): 2656
# iteration:  118  conM.sum(): 2620
# iteration:  119  conM.sum(): 2592
# iteration:  120  conM.sum(): 2558
# iteration:  121  conM.sum(): 2528
# iteration:  122  conM.sum(): 2500
# iteration:  123  conM.sum(): 2456
# iteration:  124  conM.sum(): 2434
# iteration:  125  conM.sum(): 2404
# iteration:  126  conM.sum(): 2374
# iteration:  127  conM.sum(): 2344
# iteration:  128  conM.sum(): 2320
# iteration:  129  conM.sum(): 2296
# iteration:  130  conM.sum(): 2274
# iteration:  131  conM.sum(): 2246
# iteration:  132  conM.sum(): 2218
# iteration:  133  conM.sum(): 2192
# iteration:  134  conM.sum(): 2166
# iteration:  135  conM.sum(): 2136
# iteration:  136  conM.sum(): 2108
# iteration:  137  conM.sum(): 2092
# iteration:  138  conM.sum(): 2064
# iteration:  139  conM.sum(): 2040
# iteration:  140  conM.sum(): 2002
# iteration:  141  conM.sum(): 1986
# iteration:  142  conM.sum(): 1968
# iteration:  143  conM.sum(): 1944
# iteration:  144  conM.sum(): 1922
# iteration:  145  conM.sum(): 1902
# iteration:  146  conM.sum(): 1878
# iteration:  147  conM.sum(): 1852

# %%
clusterSizes = np.argsort([c.shape[0] for c in clusters])[::-1]
sortedClusters = [clusters[cls] for cls in clusterSizes]
sortIndex = np.array([item for sublist in sortedClusters for item in sublist])
pltP = connectivityGraph[sortIndex,:]
pltP = pltP[:,sortIndex]
printGraphImage(pltP, 'clustered_single_deg_08.bmp')

# %%
l1 = [i for i in range(connectivityGraph.shape[0])]
l3 = np.array(list(set(l1) - set(sortIndex)))
displayIndices = np.hstack([sortIndex,l3])
pltP = connectivityGraph[displayIndices,:]
pltP = pltP[:,displayIndices]
printGraphImage(pltP, 'clustered_single_deg_allSamples_05.bmp')
