# %%
#chart100/0 transit

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('0', '1-2', '2-4', '4-6', '6-8', '8-10', '12-14', '14-16', '16-18', '18-20')
y_pos = np.arange(len(objects))
performance = [8.49, 8.47,8.42,8.32,8.64,8.93,8.13,8.27,8.58,8.64]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.xlabel('Number of Transits')
plt.ylabel('Average Score of Reviewers')
plt.title('Bar chart for Reviewers Score per Transit bin (100 meters)')
plt.ylim((7,9))
 
plt.show()

# %%
labels = '0 transits', '1-2 transits', '2-4 transits', '4-6 transits', '6-8 transits', '8-20 transits'
sizes = [562,526,258,75,38,18]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','silver','lightblue']
explode =(0,0,0,0,0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Pie Chart for Hotels per Transit bin (100 meters)')
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('0', '1-2', '2-4', '4-6', '6-8', '8-10', '12-14', '14-16', '16-18', '18-20')
y_pos = np.arange(len(objects))
performance = [190814,176877,98424,22505,12519,4643,2101,109,314,92]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.xlabel('Number of Transits')
plt.ylabel('Number of Reviews')
plt.title('Bar chart for Number of Reviews per Transit bin (100 meters)')
plt.ylim()
 
plt.show()

# %%
#chart50/0 transit

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('0', '1-2', '2-4', '4-6', '8-10')
y_pos = np.arange(len(objects))
performance = [8.47,8.45,8.42,8.71,8.27]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.xlabel('Number of Transits')
plt.ylabel('Average Score of Reviewers')
plt.title('Bar chart for Reviewers Score per Transit bin (50 meters)')
plt.ylim((7,9))
 
plt.show()

# %%
labels = '0 transits', '1-2 transits', '2-4 transits', '4-10 transits'
sizes = [1103,294,70,10]
colors = ['gold', 'yellowgreen', 'lightcoral']
explode =(0,0,0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Pie Chart for Hotels per Transit bin (50 meters)')
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('0', '1-2', '2-4', '4-6', '8-10')
y_pos = np.arange(len(objects))
performance = [373741,111467,21132,1949,109]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.xlabel('Number of Transits')
plt.ylabel('Number of Reviews')
plt.title('Bar chart for Number of Reviews per Transit bin (50 meters)')
plt.ylim()
 
plt.show()

# %%
#chartLandmark/0 transit

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('0', '1-2', '2-4', '4-6', '6-8', '8-10')
y_pos = np.arange(len(objects))
performance = [8.29,8.38,8.52,8.49,8.54,8.52]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.xlabel('Number of Landmarks')
plt.ylabel('Average Score of Reviewers')
plt.title('Bar chart for Reviewers Score per Landmark bin')
plt.ylim((7,9))
 
plt.show()

# %%
labels = '0 landmarks', '1-2 landmarks', '2-4 landmarks', '4-6 landmarks', '6-8 landmarks', '8-10 landmarks'
sizes = [58,404,366,293,163,193]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','silver','lightblue']
explode =(0,0,0,0,0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Pie Chart for Hotels per Landmark bin')
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('0', '1-2', '2-4', '4-6', '6-8', '8-10')
y_pos = np.arange(len(objects))
performance = [18883,145320,127940,109262,57510,49483]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.xlabel('Number of Landmarks')
plt.ylabel('Number of Reviews')
plt.title('Bar chart for Number of Reviews per Landmark bin')
plt.ylim()
 
plt.show()

# %%
#Landmark/tfidf

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('room', 'small', 'hotel', 'breakfast', 'bed', 'staff', 'nothing', 'bathroom', 'could', 'would')
y_pos = np.arange(len(objects))
performance = [1.26,0.58,0.51,0.48,0.43,0.43,0.41,0.40,0.40,0.40]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('Common words')
plt.xlabel('Frequency of Occurence')
plt.title('Bar chart for most common words in Negative Reviews of London hotels for 0 landmarks')
plt.ylim()
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('room', 'small', 'nothing', 'breakfast', 'hotel', 'bit', 'staff', 'little', 'bed', 'could')
y_pos = np.arange(len(objects))
performance = [0.89,0.55,0.55,0.51,0.48,0.44,0.39,0.38,0.38,0.38]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('Common words')
plt.xlabel('Frequency of Occurence')
plt.title('Bar chart for most common words in Negative Reviews of Paris hotels for 0 landmarks')
plt.ylim()
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('room', 'breakfast', 'hotel', 'nothing', 'small', 'staff', 'could', 'bit', 'like', 'work')
y_pos = np.arange(len(objects))
performance = [0.81,0.58,0.55,0.46,0.41,0.39,0.38,0.38,0.36,0.36]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('Common words')
plt.xlabel('Frequency of Occurence')
plt.title('Bar chart for most common words in Negative Reviews of Milan hotels for 0 landmarks')
plt.ylim()
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('nothing', 'room', 'coffee', 'open', 'would', 'hotel', 'tea', 'breakfast', 'facility', 'window')
y_pos = np.arange(len(objects))
performance = [0.80,0.80,0.47,0.44,0.44,0.42,0.42,0.42,0.39,0.39]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('Common words')
plt.xlabel('Frequency of Occurence')
plt.title('Bar chart for most common words in Negative Reviews of Vienna hotels for 0 landmarks')
plt.ylim()
 
plt.show()

# %%
#Transit tf/idf

import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('room', 'small', 'hotel', 'breakfast', 'nothing', 'staff', 'bit', 'could', 'bathroom', 'would')
y_pos = np.arange(len(objects))
performance = [1,0.55,0.54,0.52,0.45,0.40,0.37,0.37,0.37,0.36]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('Common words')
plt.xlabel('Frequency of Occurence')
plt.title('Bar chart for most common words in Negative Reviews of Paris hotels for 0 transits')
plt.ylim()
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('room', 'hotel', 'breakfast', 'nothing', 'staff', 'small', 'could', 'would', 'bed', 'pool')
y_pos = np.arange(len(objects))
performance = [0.90,0.58,0.46,0.44,0.41,0.41,0.40,0.39,0.39,0.38]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('Common words')
plt.xlabel('Frequency of Occurence')
plt.title('Bar chart for most common words in Negative Reviews of Barcelona hotels for 0 transits')
plt.ylim()
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('room', 'hotel', 'breakfast', 'nothing', 'small', 'staff', 'bit', 'could', 'one', 'like')
y_pos = np.arange(len(objects))
performance = [0.86,0.59,0.54,0.44,0.42,0.42,0.38,0.38,0.36,0.36]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('Common words')
plt.xlabel('Frequency of Occurence')
plt.title('Bar chart for most common words in Negative Reviews of Milan hotels for 0 transits')
plt.ylim()
 
plt.show()

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
 
objects = ('room', 'hotel', 'breakfast', 'nothing', 'staff', 'small', 'bed', 'bit', 'one', 'could')
y_pos = np.arange(len(objects))
performance = [0.87,0.58,0.50,0.44,0.41,0.38,0.38,0.37,0.37,0.37]
 
plt.barh(y_pos, performance, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.ylabel('Common words')
plt.xlabel('Frequency of Occurence')
plt.title('Bar chart for most common words in Negative Reviews of Vienna hotels for 0 transits')
plt.ylim()
 
plt.show()
